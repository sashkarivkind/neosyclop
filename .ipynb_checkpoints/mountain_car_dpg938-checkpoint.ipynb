# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '4'  # or any {'0', '1', '2'}
from imagenet_dataset import get_dataset
from retina_env import RetinaEnv, calculate_retinal_filter
from rl_networks import create_actor_model, create_critic_model, policy
from rl_core import Buffer, update_target
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

import types
config = types.SimpleNamespace()
config.batch_size = 32
config.margin = 20
config.image_h = 224
config.image_w = 224
config.image_hm = config.image_h+2*config.margin
config.image_wm = config.image_w+2*config.margin
config.foveate = None
config.do_grayscale = True
config.history_length = 16
config.t_ignore = 16
config.t_max =50
config.motion_mode = 'velocity'
config.use_dones = True

config.gym_mode = False
t_vec = np.linspace(0,150,16)

balanced_filter = calculate_retinal_filter(t_vec, R=1.0)
config.filter = balanced_filter.reshape([1,1,-1,1])
config.min_freq = 1
config.max_freq = 13
config.action_upper_bound = np.array([2.0, 2.0])

dataset_dir = '/home/bnapp/datasets/tensorflow_datasets/imagenet2012/5.0.0/'

def epsilon_scheduler(episode, floor_episode=200, epsilon_floor=0.1):
    if episode < floor_episode:
        return 1.-(1.-epsilon_floor)*episode/floor_episode
    else:
        return epsilon_floor

dataset = get_dataset(dataset_dir, 
                                     'validation', 
                                     config.batch_size, 
                                     image_h = config.image_hm,
                                     image_w = config.image_wm,
                                     deterministic=True,
                                     NUM_DATA_WORKERS=1,
                                     preprocessing='identity',
                                     rggb_mode=False,
                                     central_squeeze_and_pad_factor=-1)

for images,_ in dataset:
    break

env = RetinaEnv(config)

if config.gym_mode:
    num_states = env.observation_space.shape[0]
    num_actions = env.action_space.shape[0]

    upper_bound = env.action_space.high[0]
    lower_bound = env.action_space.low[0]
else:
    num_states = env.observation_size
    num_actions = env.action_size
    upper_bound = env.action_upper_bound
    lower_bound = env.action_lower_bound

# You might want to adjust the hyperparameters
actor_lr = 0.0001
critic_lr = 0.001
gamma = 0.99
tau = 0.005

buffer_capacity = 10000



# Create actor and critic networks
actor_model = create_actor_model(env.image_h, env.image_w, env.spectral_density_size, env.location_history_size, env.timestep_size, env.action_size)
critic_model = create_critic_model(env.image_h, env.image_w, env.spectral_density_size, env.location_history_size, env.timestep_size, env.action_size)

# Create target actor and critic networks
target_actor = create_actor_model(env.image_h, env.image_w, env.spectral_density_size, env.location_history_size, env.timestep_size, env.action_size)
target_critic = create_critic_model(env.image_h, env.image_w, env.spectral_density_size, env.location_history_size, env.timestep_size, env.action_size)

# Making the weights equal initially
target_actor.set_weights(actor_model.get_weights())
target_critic.set_weights(critic_model.get_weights())

# Learning rate for actor-critic models
critic_optimizer = tf.keras.optimizers.Adam(critic_lr)
actor_optimizer = tf.keras.optimizers.Adam(actor_lr)

# Experience replay buffer
buffer = Buffer(buffer_capacity, config.batch_size, num_states=num_states, num_actions=num_actions,
                state_reshape_fn=env.unflatten_observation, use_dones=config.use_dones)
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.3.0 and strictly below 2.6.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.6.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# Training loop
reward_records = []
epsilon_records = []
action_mean_records = []
action_var_records = []
episodes = 10000
for ep in range(episodes):
    prev_state = env.reset(images=images)
    episodic_reward = 0
    epsilon = epsilon_scheduler(ep, floor_episode=1000)

    while True:
        # tf_prev_state = tf.expand_dims(tf.convert_to_tensor(prev_state), 0)
        
        deterministic_action = policy(env.unflatten_observation(prev_state), actor_model, lower_bound, upper_bound)
        random_action = -2+4*np.random.uniform(size=(config.batch_size,2))

        if env.warmup_done:
            action = epsilon*random_action + (1-epsilon)*deterministic_action
        else:
            action = random_action

        # Recieve state and reward from environment
        state, reward, done, info = env.step(action)
        
        if env.warmup_done:
            if config.use_dones:
                buffer.record((prev_state, action, reward, state, done))
            else:   
                buffer.record((prev_state, action, reward, state))
                
            episodic_reward += reward

            buffer.learn(actor_model, target_actor, critic_model, target_critic, actor_optimizer, critic_optimizer, gamma, tau)
            update_target(target_actor.variables, actor_model.variables, tau)
            update_target(target_critic.variables, critic_model.variables, tau)
            
            action_mean_records.append(deterministic_action.numpy().mean(axis=0))
            action_var_records.append(deterministic_action.numpy().var(axis=0))
        # End this episode when `done` is True
        if done:
            break

        #prev_state = state avoid assingment by reference:
        prev_state = np.copy(state)
#         print('debug action: ', action[0])

    print(f"Episode * {ep} * exploration epsilon {epsilon} * Episodic Reward is ==> {episodic_reward.numpy().mean()}")
    print("action means and variances at step -10:", action_mean_records[-10],action_var_records[-10])
    print("action means and variances at step -5:", action_mean_records[-5],action_var_records[-5])
    reward_records.append(episodic_reward.numpy().mean())
    epsilon_records.append(epsilon)
# Out:
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 0 * exploration epsilon 1.0 * Episodic Reward is ==> -12.085285186767578
# action means and variances at step -10: [ 0.1957888 -0.4297591] [0.00220437 0.00051978]
# action means and variances at step -5: [ 0.18302326 -0.5028217 ] [0.00221128 0.0005898 ]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 1 * exploration epsilon 0.9991 * Episodic Reward is ==> -11.289146423339844
# action means and variances at step -10: [-0.3747945 -0.5470153] [0.00062857 0.00033525]
# action means and variances at step -5: [-0.47265172 -0.52397805] [0.00052581 0.00020283]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 2 * exploration epsilon 0.9982 * Episodic Reward is ==> -11.516767501831055
# action means and variances at step -10: [-0.59991205 -0.74750835] [0.00025864 0.00034701]
# action means and variances at step -5: [-0.63800186 -0.76517045] [0.0002392 0.0003766]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 3 * exploration epsilon 0.9973 * Episodic Reward is ==> -12.017725944519043
# action means and variances at step -10: [-0.7687416 -0.9391137] [0.00036351 0.00055186]
# action means and variances at step -5: [-0.7992165  -0.96925086] [0.00036453 0.00045022]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4 * exploration epsilon 0.9964 * Episodic Reward is ==> -11.583961486816406
# action means and variances at step -10: [-0.93491256 -1.1365638 ] [0.00059784 0.00074537]
# action means and variances at step -5: [-0.9642369 -1.1616578] [0.00092542 0.00122372]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5 * exploration epsilon 0.9955 * Episodic Reward is ==> -11.442394256591797
# action means and variances at step -10: [-1.1300516 -1.3646643] [0.00092266 0.00120229]
# action means and variances at step -5: [-1.1591177 -1.4003706] [0.00102213 0.00125883]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 6 * exploration epsilon 0.9946 * Episodic Reward is ==> -11.751457214355469
# action means and variances at step -10: [-1.3449442 -1.6177734] [0.00208065 0.00255543]
# action means and variances at step -5: [-1.3718394 -1.6574079] [0.00175503 0.00204855]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 7 * exploration epsilon 0.9937 * Episodic Reward is ==> -11.868924140930176
# action means and variances at step -10: [-1.5200992 -1.8487833] [0.00107004 0.00135519]
# action means and variances at step -5: [-1.5469041 -1.8806442] [0.00147127 0.00185745]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 8 * exploration epsilon 0.9928 * Episodic Reward is ==> -11.54893684387207
# action means and variances at step -10: [-1.7465622 -1.9963844] [0.00170298 0.00016263]
# action means and variances at step -5: [-1.7693793 -1.999936 ] [1.2128711e-03 1.2691889e-07]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 9 * exploration epsilon 0.9919 * Episodic Reward is ==> -11.90390396118164
# action means and variances at step -10: [-1.8904215 -2.       ] [0.00140275 0.        ]
# action means and variances at step -5: [-1.9168968 -2.       ] [0.00144921 0.        ]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 10 * exploration epsilon 0.991 * Episodic Reward is ==> -11.096485137939453
# action means and variances at step -10: [-1.997647 -2.      ] [5.1828207e-05 0.0000000e+00]
# action means and variances at step -5: [-1.9986241 -2.       ] [5.8689202e-05 0.0000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 11 * exploration epsilon 0.9901 * Episodic Reward is ==> -11.332443237304688
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 12 * exploration epsilon 0.9892 * Episodic Reward is ==> -11.828108787536621
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 13 * exploration epsilon 0.9883 * Episodic Reward is ==> -12.222797393798828
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 14 * exploration epsilon 0.9874 * Episodic Reward is ==> -11.855291366577148
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 15 * exploration epsilon 0.9865 * Episodic Reward is ==> -12.241090774536133
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 16 * exploration epsilon 0.9856 * Episodic Reward is ==> -11.727266311645508
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 17 * exploration epsilon 0.9847 * Episodic Reward is ==> -11.993698120117188
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 18 * exploration epsilon 0.9838 * Episodic Reward is ==> -11.47765827178955
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 19 * exploration epsilon 0.9829 * Episodic Reward is ==> -11.764754295349121
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 20 * exploration epsilon 0.982 * Episodic Reward is ==> -11.477373123168945
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 21 * exploration epsilon 0.9811 * Episodic Reward is ==> -11.79902458190918
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 22 * exploration epsilon 0.9802 * Episodic Reward is ==> -12.23430061340332
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 23 * exploration epsilon 0.9793 * Episodic Reward is ==> -12.105917930603027
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 24 * exploration epsilon 0.9784 * Episodic Reward is ==> -11.667516708374023
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 25 * exploration epsilon 0.9775 * Episodic Reward is ==> -11.95588207244873
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 26 * exploration epsilon 0.9766 * Episodic Reward is ==> -11.734184265136719
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 27 * exploration epsilon 0.9757 * Episodic Reward is ==> -11.680295944213867
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 28 * exploration epsilon 0.9748 * Episodic Reward is ==> -11.81047248840332
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 29 * exploration epsilon 0.9739 * Episodic Reward is ==> -11.415375709533691
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 30 * exploration epsilon 0.973 * Episodic Reward is ==> -11.276077270507812
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 31 * exploration epsilon 0.9721 * Episodic Reward is ==> -11.657783508300781
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 32 * exploration epsilon 0.9712 * Episodic Reward is ==> -11.416488647460938
# action means and variances at step -10: [-1.9760498 -2.       ] [0.00028783 0.        ]
# action means and variances at step -5: [-1.9827304 -2.       ] [0.00022144 0.        ]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 33 * exploration epsilon 0.9703 * Episodic Reward is ==> -11.283655166625977
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 34 * exploration epsilon 0.9694 * Episodic Reward is ==> -12.105091094970703
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 35 * exploration epsilon 0.9685 * Episodic Reward is ==> -11.543885231018066
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 36 * exploration epsilon 0.9676 * Episodic Reward is ==> -12.195247650146484
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 37 * exploration epsilon 0.9667 * Episodic Reward is ==> -11.67061710357666
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 38 * exploration epsilon 0.9658 * Episodic Reward is ==> -11.701221466064453
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-1.9184496 -2.       ] [0.00014739 0.        ]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 39 * exploration epsilon 0.9649 * Episodic Reward is ==> -11.399066925048828
# action means and variances at step -10: [-1.8295978 -2.       ] [0.00012622 0.        ]
# action means and variances at step -5: [-1.869118 -2.      ] [0.00011195 0.        ]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 40 * exploration epsilon 0.964 * Episodic Reward is ==> -11.506904602050781
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 41 * exploration epsilon 0.9631 * Episodic Reward is ==> -11.744879722595215
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 42 * exploration epsilon 0.9621999999999999 * Episodic Reward is ==> -12.10190200805664
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 43 * exploration epsilon 0.9613 * Episodic Reward is ==> -11.580575942993164
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 44 * exploration epsilon 0.9604 * Episodic Reward is ==> -11.589498519897461
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 45 * exploration epsilon 0.9595 * Episodic Reward is ==> -11.528635025024414
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 46 * exploration epsilon 0.9586 * Episodic Reward is ==> -11.785164833068848
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 47 * exploration epsilon 0.9577 * Episodic Reward is ==> -11.654634475708008
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 48 * exploration epsilon 0.9568 * Episodic Reward is ==> -11.993685722351074
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 49 * exploration epsilon 0.9559 * Episodic Reward is ==> -11.244789123535156
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 50 * exploration epsilon 0.955 * Episodic Reward is ==> -11.583224296569824
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 51 * exploration epsilon 0.9541 * Episodic Reward is ==> -11.703874588012695
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 52 * exploration epsilon 0.9532 * Episodic Reward is ==> -11.700263977050781
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 53 * exploration epsilon 0.9523 * Episodic Reward is ==> -11.548986434936523
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 54 * exploration epsilon 0.9514 * Episodic Reward is ==> -11.211820602416992
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 55 * exploration epsilon 0.9505 * Episodic Reward is ==> -11.544827461242676
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 56 * exploration epsilon 0.9496 * Episodic Reward is ==> -11.676017761230469
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 57 * exploration epsilon 0.9487 * Episodic Reward is ==> -12.20804214477539
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 58 * exploration epsilon 0.9478 * Episodic Reward is ==> -12.33089542388916
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 59 * exploration epsilon 0.9469 * Episodic Reward is ==> -11.385875701904297
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 60 * exploration epsilon 0.946 * Episodic Reward is ==> -11.866575241088867
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 61 * exploration epsilon 0.9451 * Episodic Reward is ==> -11.232211112976074
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 62 * exploration epsilon 0.9442 * Episodic Reward is ==> -11.796602249145508
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 63 * exploration epsilon 0.9433 * Episodic Reward is ==> -11.55838394165039
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 64 * exploration epsilon 0.9424 * Episodic Reward is ==> -11.680901527404785
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 65 * exploration epsilon 0.9415 * Episodic Reward is ==> -11.86729621887207
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 66 * exploration epsilon 0.9406 * Episodic Reward is ==> -11.876285552978516
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 67 * exploration epsilon 0.9397 * Episodic Reward is ==> -11.514693260192871
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 68 * exploration epsilon 0.9388 * Episodic Reward is ==> -11.69601058959961
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 69 * exploration epsilon 0.9379 * Episodic Reward is ==> -12.046571731567383
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 70 * exploration epsilon 0.937 * Episodic Reward is ==> -11.715580940246582
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 71 * exploration epsilon 0.9361 * Episodic Reward is ==> -11.844799041748047
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 72 * exploration epsilon 0.9352 * Episodic Reward is ==> -11.811332702636719
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 73 * exploration epsilon 0.9343 * Episodic Reward is ==> -11.816896438598633
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 74 * exploration epsilon 0.9334 * Episodic Reward is ==> -11.015264511108398
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 75 * exploration epsilon 0.9325 * Episodic Reward is ==> -11.589380264282227
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 76 * exploration epsilon 0.9316 * Episodic Reward is ==> -11.382553100585938
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 77 * exploration epsilon 0.9307 * Episodic Reward is ==> -11.634934425354004
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 78 * exploration epsilon 0.9298 * Episodic Reward is ==> -12.051168441772461
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 79 * exploration epsilon 0.9289 * Episodic Reward is ==> -11.841567993164062
# action means and variances at step -10: [-2. -2.] [0. 0.]
# action means and variances at step -5: [-1.9831263 -2.       ] [4.3477725e-05 0.0000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 80 * exploration epsilon 0.928 * Episodic Reward is ==> -11.65380573272705
# action means and variances at step -10: [ 0.4646382 -2.       ] [0.00115012 0.        ]
# action means and variances at step -5: [ 0.07062024 -2.        ] [0.00084175 0.        ]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 81 * exploration epsilon 0.9271 * Episodic Reward is ==> -11.542587280273438
# action means and variances at step -10: [ 0.21410435 -2.        ] [0.00036546 0.        ]
# action means and variances at step -5: [ 0.18046577 -2.        ] [0.00025166 0.        ]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 82 * exploration epsilon 0.9262 * Episodic Reward is ==> -11.881750106811523
# action means and variances at step -10: [ 0.20149583 -2.        ] [4.90694e-05 0.00000e+00]
# action means and variances at step -5: [ 0.17604108 -2.        ] [5.3323893e-05 0.0000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 83 * exploration epsilon 0.9253 * Episodic Reward is ==> -11.794414520263672
# action means and variances at step -10: [ 0.15093483 -2.        ] [3.377411e-05 0.000000e+00]
# action means and variances at step -5: [ 0.14448167 -2.        ] [2.018524e-05 0.000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 84 * exploration epsilon 0.9244 * Episodic Reward is ==> -11.213653564453125
# action means and variances at step -10: [ 0.09344492 -2.        ] [2.389341e-05 0.000000e+00]
# action means and variances at step -5: [ 0.09683453 -2.        ] [1.2031482e-05 0.0000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 85 * exploration epsilon 0.9235 * Episodic Reward is ==> -11.744485855102539
# action means and variances at step -10: [ 0.11169791 -2.        ] [3.6582333e-05 0.0000000e+00]
# action means and variances at step -5: [ 0.10644925 -2.        ] [2.3570816e-05 0.0000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 86 * exploration epsilon 0.9226 * Episodic Reward is ==> -11.656399726867676
# action means and variances at step -10: [ 0.04399235 -2.        ] [1.96178e-05 0.00000e+00]
# action means and variances at step -5: [ 0.05560682 -2.        ] [2.0604604e-05 0.0000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 87 * exploration epsilon 0.9217 * Episodic Reward is ==> -11.522330284118652
# action means and variances at step -10: [ 0.05299662 -2.        ] [8.828745e-06 0.000000e+00]
# action means and variances at step -5: [ 0.04248764 -2.        ] [1.0314303e-05 0.0000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 88 * exploration epsilon 0.9208 * Episodic Reward is ==> -11.452474594116211
# action means and variances at step -10: [ 0.03298045 -2.        ] [2.0144988e-05 0.0000000e+00]
# action means and variances at step -5: [ 0.0949224 -2.       ] [7.476223e-06 0.000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 89 * exploration epsilon 0.9198999999999999 * Episodic Reward is ==> -11.574450492858887
# action means and variances at step -10: [ 0.02240251 -2.        ] [2.5663436e-05 0.0000000e+00]
# action means and variances at step -5: [ 0.00799531 -2.        ] [2.330365e-05 0.000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 90 * exploration epsilon 0.919 * Episodic Reward is ==> -11.663267135620117
# action means and variances at step -10: [ 0.01512686 -2.        ] [4.062711e-06 0.000000e+00]
# action means and variances at step -5: [ 0.03317048 -2.        ] [6.2189088e-06 0.0000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 91 * exploration epsilon 0.9181 * Episodic Reward is ==> -11.468844413757324
# action means and variances at step -10: [ 0.11865172 -2.        ] [8.743059e-06 0.000000e+00]
# action means and variances at step -5: [ 0.13158108 -2.        ] [5.7367524e-06 0.0000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 92 * exploration epsilon 0.9172 * Episodic Reward is ==> -11.594446182250977
# action means and variances at step -10: [ 0.11171199 -2.        ] [1.42146555e-05 0.00000000e+00]
# action means and variances at step -5: [ 0.10576548 -2.        ] [7.694689e-06 0.000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 93 * exploration epsilon 0.9163 * Episodic Reward is ==> -12.070732116699219
# action means and variances at step -10: [ 0.10670608 -2.        ] [1.1067865e-05 0.0000000e+00]
# action means and variances at step -5: [ 0.08271744 -2.        ] [6.2387107e-06 0.0000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 94 * exploration epsilon 0.9154 * Episodic Reward is ==> -12.032159805297852
# action means and variances at step -10: [ 0.12368842 -2.        ] [1.5259864e-05 0.0000000e+00]
# action means and variances at step -5: [ 0.09346273 -2.        ] [1.7844586e-05 0.0000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 95 * exploration epsilon 0.9145 * Episodic Reward is ==> -11.968996047973633
# action means and variances at step -10: [ 0.0472313 -2.       ] [1.36920335e-05 0.00000000e+00]
# action means and variances at step -5: [ 0.02969651 -2.        ] [1.1826303e-05 0.0000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 96 * exploration epsilon 0.9136 * Episodic Reward is ==> -11.935005187988281
# action means and variances at step -10: [ 0.07363541 -2.        ] [7.412141e-06 0.000000e+00]
# action means and variances at step -5: [ 0.06756343 -2.        ] [4.7034027e-06 0.0000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 97 * exploration epsilon 0.9127 * Episodic Reward is ==> -12.0078125
# action means and variances at step -10: [ 0.00294037 -2.        ] [2.3734012e-06 0.0000000e+00]
# action means and variances at step -5: [ 0.0222546 -2.       ] [2.7851218e-06 0.0000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 98 * exploration epsilon 0.9117999999999999 * Episodic Reward is ==> -11.736030578613281
# action means and variances at step -10: [-0.03411237 -2.        ] [7.925783e-06 0.000000e+00]
# action means and variances at step -5: [ 0.04804508 -2.        ] [1.0702231e-05 0.0000000e+00]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# ...
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5048 * exploration epsilon 0.1 * Episodic Reward is ==> -15.442919731140137
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5049 * exploration epsilon 0.1 * Episodic Reward is ==> -15.754854202270508
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5050 * exploration epsilon 0.1 * Episodic Reward is ==> -15.418018341064453
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5051 * exploration epsilon 0.1 * Episodic Reward is ==> -15.408163070678711
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5052 * exploration epsilon 0.1 * Episodic Reward is ==> -15.394601821899414
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5053 * exploration epsilon 0.1 * Episodic Reward is ==> -15.493385314941406
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5054 * exploration epsilon 0.1 * Episodic Reward is ==> -15.596126556396484
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5055 * exploration epsilon 0.1 * Episodic Reward is ==> -15.081588745117188
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5056 * exploration epsilon 0.1 * Episodic Reward is ==> -15.576950073242188
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5057 * exploration epsilon 0.1 * Episodic Reward is ==> -15.38762378692627
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5058 * exploration epsilon 0.1 * Episodic Reward is ==> -15.76279354095459
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5059 * exploration epsilon 0.1 * Episodic Reward is ==> -15.584037780761719
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5060 * exploration epsilon 0.1 * Episodic Reward is ==> -15.982931137084961
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5061 * exploration epsilon 0.1 * Episodic Reward is ==> -15.717248916625977
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5062 * exploration epsilon 0.1 * Episodic Reward is ==> -15.63641357421875
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5063 * exploration epsilon 0.1 * Episodic Reward is ==> -15.522187232971191
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5064 * exploration epsilon 0.1 * Episodic Reward is ==> -15.431245803833008
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5065 * exploration epsilon 0.1 * Episodic Reward is ==> -15.764019012451172
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5066 * exploration epsilon 0.1 * Episodic Reward is ==> -15.187171936035156
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5067 * exploration epsilon 0.1 * Episodic Reward is ==> -15.424558639526367
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5068 * exploration epsilon 0.1 * Episodic Reward is ==> -15.65575122833252
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5069 * exploration epsilon 0.1 * Episodic Reward is ==> -15.601919174194336
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5070 * exploration epsilon 0.1 * Episodic Reward is ==> -15.514447212219238
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5071 * exploration epsilon 0.1 * Episodic Reward is ==> -15.645041465759277
# action means and variances at step -10: [ 2. -2.] [0. 0.]
# action means and variances at step -5: [ 2. -2.] [0. 0.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4178856/286770537.py in <module>
#      32             episodic_reward += reward
#      33
# ---> 34             buffer.learn(actor_model, target_actor, critic_model, target_critic, actor_optimizer, critic_optimizer, gamma, tau)
#      35             update_target(target_actor.variables, actor_model.variables, tau)
#      36             update_target(target_critic.variables, critic_model.variables, tau)
#
# /home/bnapp/arivkindNet/neosyclop/rl_core.py in learn(self, actor_model, target_actor, critic_model, target_critic, actor_optimizer, critic_optimizer, gamma, tau)
#      84
#      85         # Convert to tensors
# ---> 86         state_batch = tf.convert_to_tensor(self.state_buffer[batch_indices])
#      87         action_batch = tf.convert_to_tensor(self.action_buffer[batch_indices])
#      88         reward_batch = tf.convert_to_tensor(self.reward_buffer[batch_indices])
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#    1428     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#    1429   """
# -> 1430   return convert_to_tensor_v2(
#    1431       value, dtype=dtype, dtype_hint=dtype_hint, name=name)
#    1432
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1434 def convert_to_tensor_v2(value, dtype=None, dtype_hint=None, name=None):
#    1435   """Converts the given `value` to a `Tensor`."""
# -> 1436   return convert_to_tensor(
#    1437       value=value,
#    1438       dtype=dtype,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1564
#    1565     if ret is None:
# -> 1566       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1567
#    1568     if ret is NotImplemented:
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     269     ValueError: if called on a symbolic tensor.
#     270   """
# --> 271   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     272                         allow_broadcast=True)
#     273
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     281       with trace.Trace("tf.constant"):
#     282         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 283     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     284
#     285   g = ops.get_default_graph()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     306 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     307   """Creates a constant on the current device."""
# --> 308   t = convert_to_eager_tensor(value, ctx, dtype)
#     309   if shape is None:
#     310     return t
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     104       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     105   ctx.ensure_initialized()
# --> 106   return ops.EagerTensor(value, ctx.device_name, dtype)
#     107
#     108
#
# KeyboardInterrupt:

# %%
plt.plot(reward_records)

# %%
import misc

# %%
plt.plot(reward_records)
plt.plot(misc.smooth(reward_records,100))
plt.grid()

# %%
plt.plot(reward_records)
plt.plot(misc.smooth(reward_records,1000))
plt.grid()

# %%
plt.plot(buffer.critic_loss_buffer[100:])
plt.plot(misc.smooth(buffer.critic_loss_buffer[100:],100))

# %%
plt.plot(buffer.critic_loss_buffer[:10])

# %%
plt.plot(misc.smooth(buffer.critic_loss_buffer[100:],1))
plt.plot(misc.smooth(buffer.critic_loss_buffer[100:],100))
plt.plot(misc.smooth(buffer.critic_loss_buffer[100:],1000))
plt.ylim([0,0.05])
plt.grid()

# %%
plt.plot(misc.smooth(buffer.critic_loss_buffer[100:],1))
plt.plot(misc.smooth(buffer.critic_loss_buffer[100:],100))
plt.plot(misc.smooth(buffer.critic_loss_buffer[100:],1000))
plt.grid()

# %%
plt.plot(misc.smooth(buffer.critic_loss_buffer[-500:],1))
plt.plot(misc.smooth(buffer.critic_loss_buffer[-500:],100))
plt.plot(misc.smooth(buffer.critic_loss_buffer[-500:],1000))
plt.grid()

# %%
## Debugging Nan values in action

# %%
plt.plot(buffer.actor_loss_buffer[100:])

# %%
deterministic_action.numpy()

# %%
reward

# %%
env.reset()
for ii in range(55):
    random_action = -2+4*np.random.uniform(size=(config.batch_size,2))
    state, reward, done, info = env.step(random_action)
    print('----------')
    print(reward.numpy()[:5])
    print(critic_model([env.unflatten_observation(state),
                          deterministic_action]).numpy()[:5].T)
    print(critic_model([env.unflatten_observation(state),
                          random_action]).numpy()[:5].T)

# %%
plt.imshow(env.unflatten_observation(state)[0].numpy()[0])

# %%
env.unflatten_observation(state)[1].numpy()[0]

# %%
env.unflatten_observation(state)[2].numpy()[0]

# %%
env.unflatten_observation(state)[3].numpy()[0]

# %%
random_action

# %%
critic_model([env.unflatten_observation(state),
                          random_action])

# %%
deterministic_action

# %%
actor_model(env.unflatten_observation(state))

# %%
actor_model.weights

# %%
critic_model.weights
