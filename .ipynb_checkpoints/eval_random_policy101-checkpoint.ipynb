# %%
from imagenet_dataset import get_dataset
from retina_env import RetinaEnv, calculate_retinal_filter
from rl_networks import create_actor_model, create_critic_model, policy
from rl_core import Buffer, update_target
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

import types
config = types.SimpleNamespace()
config.batch_size = 32
config.margin = 20
config.image_h = 224
config.image_w = 224
config.image_hm = config.image_h+2*config.margin
config.image_wm = config.image_w+2*config.margin
config.foveate = None
config.do_grayscale = True
config.history_length = 16
config.t_ignore = 16
config.t_max =50
config.motion_mode = 'velocity'

config.gym_mode = False
t_vec = np.linspace(0,150,16)

balanced_filter = calculate_retinal_filter(t_vec, R=1.0)
config.filter = balanced_filter.reshape([1,1,-1,1])
config.min_freq = 1
config.max_freq = 13
config.action_upper_bound = np.array([2.0, 2.0])

dataset_dir = '/home/bnapp/datasets/tensorflow_datasets/imagenet2012/5.0.0/'

dataset = get_dataset(dataset_dir,
                                     'validation',
                                     config.batch_size,
                                     image_h = config.image_hm,
                                     image_w = config.image_wm,
                                     preprocessing='identity',
                                     rggb_mode=False,
                                     central_squeeze_and_pad_factor=-1)

env = RetinaEnv(config, image_generator=dataset)

if config.gym_mode:
    num_states = env.observation_space.shape[0]
    num_actions = env.action_space.shape[0]

    upper_bound = env.action_space.high[0]
    lower_bound = env.action_space.low[0]
else:
    num_states = env.observation_size
    num_actions = env.action_size
    upper_bound = env.action_upper_bound
    lower_bound = env.action_lower_bound

# You might want to adjust the hyperparameters
actor_lr = 0.0001
critic_lr = 0.0002
gamma = 0.99
tau = 0.005

buffer_capacity = 100000
batch_size = 64



# Create actor and critic networks
actor_model = create_actor_model(env.image_h, env.image_w, env.spectral_density_size, env.location_history_size, env.timestep_size, env.action_size)
critic_model = create_critic_model(env.image_h, env.image_w, env.spectral_density_size, env.location_history_size, env.timestep_size, env.action_size)

# Create target actor and critic networks
target_actor = create_actor_model(env.image_h, env.image_w, env.spectral_density_size, env.location_history_size, env.timestep_size, env.action_size)
target_critic = create_critic_model(env.image_h, env.image_w, env.spectral_density_size, env.location_history_size, env.timestep_size, env.action_size)

# Making the weights equal initially
target_actor.set_weights(actor_model.get_weights())
target_critic.set_weights(critic_model.get_weights())

# Learning rate for actor-critic models
critic_optimizer = tf.keras.optimizers.Adam(critic_lr)
actor_optimizer = tf.keras.optimizers.Adam(actor_lr)

# Experience replay buffer
buffer = Buffer(buffer_capacity, config.batch_size, num_states=num_states, num_actions=num_actions,
                state_reshape_fn=env.unflatten_observation)
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.3.0 and strictly below 2.6.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.6.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# WARNING:tensorflow:From /home/bnapp/arivkindNet/neosyclop/imagenet_dataset.py:103: map_and_batch (from tensorflow.python.data.experimental.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map(map_func, num_parallel_calls)` followed by `tf.data.Dataset.batch(batch_size, drop_remainder)`. Static tf.data optimizations will take care of using the fused implementation.
# 2023-06-05 12:24:17.426839: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1917] Ignoring visible gpu device (device: 1, name: NVIDIA GeForce GT 730, pci bus id: 0000:65:00.0, compute capability: 3.5) with core count: 2. The minimum required count is 8. You can adjust this requirement with the env var TF_MIN_GPU_MULTIPROCESSOR_COUNT.
# 2023-06-05 12:24:17.832108: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10247 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:17:00.0, compute capability: 6.1
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.

# %%
# Training loop
episodes = 100
for ep in range(episodes):
    prev_state = env.reset()
    episodic_reward = 0

    while True:
        # tf_prev_state = tf.expand_dims(tf.convert_to_tensor(prev_state), 0)

        action = -2+4*np.random.uniform(size=(config.batch_size,2))
#         policy(env.unflatten_observation(prev_state), actor_model, lower_bound, upper_bound)
        # Recieve state and reward from environment
        state, reward, done, info = env.step(action)

#         buffer.record((prev_state, action, reward, state))
        episodic_reward += reward

#         buffer.learn(actor_model, target_actor, critic_model, target_critic, actor_optimizer, critic_optimizer, gamma, tau)
#         update_target(target_actor.variables, actor_model.variables, tau)
#         update_target(target_critic.variables, critic_model.variables, tau)

        # End this episode when `done` is True
        if done:
            break

        #prev_state = state avoid assingment by reference:
        prev_state = np.copy(state)
#         print('debug action: ', action[0])

    print(f"Random Episode * {ep} * Episodic Reward is ==> {episodic_reward.numpy().mean()}")
# Out:
# 2023-06-05 12:24:20.099605: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-06-05 12:24:30.221090: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:175] Filling up shuffle buffer (this may take a while): 6733 of 8192
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# 2023-06-05 12:24:32.513434: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:228] Shuffle buffer filled.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 0 * Episodic Reward is ==> -13.22378921508789
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 1 * Episodic Reward is ==> -11.389315605163574
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 2 * Episodic Reward is ==> -11.464044570922852
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 3 * Episodic Reward is ==> -11.750917434692383
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 4 * Episodic Reward is ==> -13.567131042480469
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 5 * Episodic Reward is ==> -13.175684928894043
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 6 * Episodic Reward is ==> -12.028297424316406
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 7 * Episodic Reward is ==> -11.35920524597168
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 8 * Episodic Reward is ==> -12.4442138671875
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 9 * Episodic Reward is ==> -11.588963508605957
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 10 * Episodic Reward is ==> -12.886977195739746
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 11 * Episodic Reward is ==> -12.552186012268066
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 12 * Episodic Reward is ==> -11.318717956542969
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 13 * Episodic Reward is ==> -11.534812927246094
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 14 * Episodic Reward is ==> -10.583988189697266
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 15 * Episodic Reward is ==> -11.068572044372559
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 16 * Episodic Reward is ==> -12.476190567016602
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 17 * Episodic Reward is ==> -13.504068374633789
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 18 * Episodic Reward is ==> -11.66757583618164
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 19 * Episodic Reward is ==> -13.709341049194336
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 20 * Episodic Reward is ==> -12.002010345458984
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Random Episode * 21 * Episodic Reward is ==> -12.128517150878906
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_17867/2105737574.py in <module>
#      11 #         policy(env.unflatten_observation(prev_state), actor_model, lower_bound, upper_bound)
#      12         # Recieve state and reward from environment
# ---> 13         state, reward, done, info = env.step(action)
#      14
#      15 #         buffer.record((prev_state, action, reward, state))
#
# /home/bnapp/arivkindNet/neosyclop/retina_env.py in step(self, action)
#     110         # compute spectral density
#     111         if self.timestep > self.config.t_ignore:
# --> 112             this_spectral_density = spectral_power_half(self.retinal_view)[:,
#     113                                      self.config.min_freq:self.config.max_freq]
#     114             a = self.timestep - self.config.t_ignore
#
# /home/bnapp/arivkindNet/neosyclop/retina_env.py in spectral_power_half(images, convert_to_grayscale)
#     238 #returns a batch of 1D power spectra
#     239 def spectral_power_half(images, convert_to_grayscale=False):
# --> 240     power = spectral_power(images, convert_to_grayscale)
#     241     power_half = power[:,:power.shape[1]//2]
#     242     return power_half
#
# /home/bnapp/arivkindNet/neosyclop/retina_env.py in spectral_power(images, convert_to_grayscale)
#     222     images = np.squeeze(images)
#     223     #compute fft
# --> 224     fft = np.fft.fft2(images)
#     225     #compute power spectra
#     226     power = np.abs(fft)**2
#
# <__array_function__ internals> in fft2(*args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/numpy/fft/_pocketfft.py in fft2(a, s, axes, norm)
#     942     """
#     943
# --> 944     return _raw_fftnd(a, s, axes, fft, norm)
#     945
#     946
#
# /usr/local/lib/python3.8/dist-packages/numpy/fft/_pocketfft.py in _raw_fftnd(a, s, axes, function, norm)
#     650     itl.reverse()
#     651     for ii in itl:
# --> 652         a = function(a, n=s[ii], axis=axes[ii], norm=norm)
#     653     return a
#     654
#
# <__array_function__ internals> in fft(*args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/numpy/fft/_pocketfft.py in fft(a, n, axis, norm)
#     183     if norm is not None and _unitary(norm):
#     184         inv_norm = sqrt(n)
# --> 185     output = _raw_fft(a, n, axis, False, True, inv_norm)
#     186     return output
#     187
#
# /usr/local/lib/python3.8/dist-packages/numpy/fft/_pocketfft.py in _raw_fft(a, n, axis, is_real, is_forward, inv_norm)
#      75     else:
#      76         a = swapaxes(a, axis, -1)
# ---> 77         r = pfi.execute(a, is_real, is_forward, fct)
#      78         r = swapaxes(r, axis, -1)
#      79     return r
#
# KeyboardInterrupt:
