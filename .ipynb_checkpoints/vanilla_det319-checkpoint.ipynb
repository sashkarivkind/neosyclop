# %%
'''in this version we always use the same batch of images'''
# Out:
# 'in this version we always use the same batch of images'

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # or any {'0', '1', '2'}
from imagenet_dataset import get_dataset
from retina_env import RetinaEnv, calculate_retinal_filter
from rl_networks import create_actor_model, create_critic_model, policy
from rl_core import Buffer, update_target
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from pg_core import GaussianPolicyAgent

import types
config = types.SimpleNamespace()
config.batch_size = 4
config.margin = 20
config.image_h = 224
config.image_w = 224
config.image_hm = config.image_h+2*config.margin
config.image_wm = config.image_w+2*config.margin
config.foveate = None
config.do_grayscale = True
config.history_length = 16
config.t_ignore = 16
config.t_max =50
config.motion_mode = 'velocity'
config.use_dones = False

config.gym_mode = False
t_vec = np.linspace(0,150,16)

balanced_filter = calculate_retinal_filter(t_vec, R=1.0)
config.filter = balanced_filter.reshape([1,1,-1,1])
config.min_freq = 1
config.max_freq = 13
config.action_upper_bound = np.array([2.0, 2.0])
actor_lr = 1e-4
dataset_dir = '/home/bnapp/datasets/tensorflow_datasets/imagenet2012/5.0.0/'

def epsilon_scheduler(episode, floor_episode=200, epsilon_floor=0.1):
    if episode < floor_episode:
        return 1.-(1.-epsilon_floor)*episode/floor_episode
    else:
        return epsilon_floor

dataset = get_dataset(dataset_dir,
                                     'validation',
                                     config.batch_size,
                                     image_h = config.image_hm,
                                     image_w = config.image_wm,
                                     preprocessing='identity',
                                     rggb_mode=False,
                                     central_squeeze_and_pad_factor=-1)

# env = RetinaEnv(config, image_generator=dataset)
env = RetinaEnv(config) #freezing on first batch
for images,_ in dataset:
    break
    
if config.gym_mode:
    num_states = env.observation_space.shape[0]
    num_actions = env.action_space.shape[0]

    upper_bound = env.action_space.high[0]
    lower_bound = env.action_space.low[0]
else:
    num_states = env.observation_size
    num_actions = env.action_size
    upper_bound = env.action_upper_bound
    lower_bound = env.action_lower_bound


actor_model = create_actor_model(env.image_h, env.image_w,
                                 env.spectral_density_size, env.location_history_size,
                                 env.timestep_size, env.action_size)
actor_optimizer = tf.keras.optimizers.Adam(actor_lr)
actor_model.optimizer = actor_optimizer
agent = GaussianPolicyAgent(std_deviation=1.0,model=actor_model)
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.3.0 and strictly below 2.6.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.6.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# WARNING:tensorflow:From /home/bnapp/arivkindNet/neosyclop/imagenet_dataset.py:124: map_and_batch (from tensorflow.python.data.experimental.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map(map_func, num_parallel_calls)` followed by `tf.data.Dataset.batch(batch_size, drop_remainder)`. Static tf.data optimizations will take care of using the fused implementation.

# %%
# Training loop
reward_records = []
epsilon_records = []
action_mean_records = []
action_var_records = []
action_statmean_records = []
action_statvar_records = []
episodes = 10000
for ep in range(episodes):
    prev_state = env.reset(images=images)
    episodic_reward = 0
    states, actions, rewards = [], [], []

#     epsilon = epsilon_scheduler(ep, floor_episode=1000)

    while True:

        deterministic_action, means,stdevs = agent.get_action(env.unflatten_observation(prev_state),
                                               return_stats=True)
        action = deterministic_action #hook in order to add noise if neccessary
        state, reward, done, info = env.step(action)
        
        if env.warmup_done:
            states.append(prev_state)
            actions.append(action)
            rewards.append(reward)
                
            episodic_reward += reward
           
            action_mean_records.append(deterministic_action.mean(axis=0))
            action_var_records.append(deterministic_action.var(axis=0))
            action_statmean_records.append(means)
            action_statvar_records.append(stdevs)
        # End this episode when `done` is True
        if done:
            break

        prev_state = np.copy(state)
    
    agent.train(np.array(states), np.array(actions), np.array(rewards),shaper_fn=env.unflatten_observation_v2,
                max_iteration=1000)
    reward_records.append(episodic_reward)
    print(f"Episode * {ep} * Episodic Reward is ==> {episodic_reward.numpy().mean()}")
#     print(f"Episode * {ep} * exploration epsilon {epsilon} * Episodic Reward is ==> {episodic_reward.numpy().mean()}")
    print("action means and variances at step -10:", action_mean_records[-10],action_var_records[-10])
    print("action means and variances at step -5:", action_mean_records[-5],action_var_records[-5])
    print("action statmeans and variances at step -10:", action_statmean_records[-10][0],action_statvar_records[-10][0])
    print("action statmeans and variances at step -5:", action_statmean_records[-5][0],action_statvar_records[-5][0])
# Out:
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 0 * Episodic Reward is ==> -10.964290618896484
# action means and variances at step -10: [-0.15058485 -0.09012962] [0.52509935 0.1819034 ]
# action means and variances at step -5: [-1.05882841  0.52024642] [0.81927502 0.51394756]
# action statmeans and variances at step -10: [0.03368756 0.04733242] [1. 1.]
# action statmeans and variances at step -5: [0.03506514 0.03819551] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 1 * Episodic Reward is ==> -10.859689712524414
# action means and variances at step -10: [ 0.79677529 -0.02863712] [1.26289664 0.79741916]
# action means and variances at step -5: [-0.46815709 -0.47861383] [0.19369815 0.20393413]
# action statmeans and variances at step -10: [0.017446   0.04422269] [1. 1.]
# action statmeans and variances at step -5: [0.013884   0.04805709] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 2 * Episodic Reward is ==> -11.151540756225586
# action means and variances at step -10: [-0.65328655  0.41984694] [1.22752083 0.36194837]
# action means and variances at step -5: [0.10106197 0.61523638] [0.70617954 0.12940783]
# action statmeans and variances at step -10: [0.0097249  0.04675892] [1. 1.]
# action statmeans and variances at step -5: [0.0078674  0.04727373] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 3 * Episodic Reward is ==> -11.071852684020996
# action means and variances at step -10: [-0.04621543 -0.01990964] [0.39911678 0.69597623]
# action means and variances at step -5: [ 0.46712928 -0.23246582] [0.92487768 0.64772362]
# action statmeans and variances at step -10: [-0.00889373  0.07294555] [1. 1.]
# action statmeans and variances at step -5: [-0.00989036  0.07795982] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4 * Episodic Reward is ==> -8.959330558776855
# action means and variances at step -10: [0.27632171 0.36053941] [1.47708569 0.20426998]
# action means and variances at step -5: [0.54590066 0.21405928] [0.9313834  0.24835623]
# action statmeans and variances at step -10: [-0.00608517  0.07958525] [1. 1.]
# action statmeans and variances at step -5: [-0.00812986  0.08388042] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5 * Episodic Reward is ==> -10.79633903503418
# action means and variances at step -10: [-0.35774402  0.62755331] [0.34360189 0.46204431]
# action means and variances at step -5: [0.32363678 1.44718836] [0.69013405 0.07314799]
# action statmeans and variances at step -10: [3.5302219e-07 9.1765285e-02] [1. 1.]
# action statmeans and variances at step -5: [0.01594313 0.09383541] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 6 * Episodic Reward is ==> -11.74322509765625
# action means and variances at step -10: [-0.53738972 -0.36117867] [0.30979849 0.27325327]
# action means and variances at step -5: [0.50505931 0.0099847 ] [0.09116858 0.03354612]
# action statmeans and variances at step -10: [-0.00716195  0.07864394] [1. 1.]
# action statmeans and variances at step -5: [0.0060103  0.07803421] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 7 * Episodic Reward is ==> -10.30380630493164
# action means and variances at step -10: [ 0.34042369 -0.38299297] [0.01332702 0.90150472]
# action means and variances at step -5: [ 0.44239427 -0.19692595] [1.0260527  0.62569708]
# action statmeans and variances at step -10: [0.01298355 0.07492799] [1. 1.]
# action statmeans and variances at step -5: [0.01362554 0.08900665] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 8 * Episodic Reward is ==> -10.56259822845459
# action means and variances at step -10: [-0.43387239  0.53725985] [0.0853226  0.48821244]
# action means and variances at step -5: [ 0.04125155 -0.63400096] [0.31684731 0.13387602]
# action statmeans and variances at step -10: [0.00279152 0.10768867] [1. 1.]
# action statmeans and variances at step -5: [-0.00501233  0.10985687] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 9 * Episodic Reward is ==> -11.123108863830566
# action means and variances at step -10: [-0.77029684  1.29541715] [0.84520519 1.05318367]
# action means and variances at step -5: [0.12976984 0.1747115 ] [0.19847624 0.97551589]
# action statmeans and variances at step -10: [0.01255052 0.11744764] [1. 1.]
# action statmeans and variances at step -5: [0.00060798 0.10913108] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 10 * Episodic Reward is ==> -10.214363098144531
# action means and variances at step -10: [0.18712495 0.39623518] [1.82803259 0.45732862]
# action means and variances at step -5: [0.24740341 0.27686362] [2.09251298 1.30965758]
# action statmeans and variances at step -10: [0.02892346 0.12318825] [1. 1.]
# action statmeans and variances at step -5: [0.02758458 0.11531431] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 11 * Episodic Reward is ==> -9.738497734069824
# action means and variances at step -10: [ 0.88885699 -0.68465527] [0.52425332 0.42884651]
# action means and variances at step -5: [ 0.71778626 -0.14625268] [0.52374945 0.80469103]
# action statmeans and variances at step -10: [0.02004238 0.11053234] [1. 1.]
# action statmeans and variances at step -5: [0.01163679 0.1082685 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 12 * Episodic Reward is ==> -10.77349853515625
# action means and variances at step -10: [ 1.65022231 -0.79766059] [0.35446096 0.47546614]
# action means and variances at step -5: [-0.89801218  1.11704914] [0.02255599 1.00971084]
# action statmeans and variances at step -10: [0.04828971 0.10138679] [1. 1.]
# action statmeans and variances at step -5: [0.03514786 0.08618318] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 13 * Episodic Reward is ==> -10.850076675415039
# action means and variances at step -10: [-0.36773585  0.47429443] [0.36862455 1.12591473]
# action means and variances at step -5: [-0.05583641  0.07020741] [0.12552027 2.39678033]
# action statmeans and variances at step -10: [0.01986763 0.10181554] [1. 1.]
# action statmeans and variances at step -5: [0.01726485 0.1083632 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 14 * Episodic Reward is ==> -10.70034122467041
# action means and variances at step -10: [0.65348  0.423616] [0.7075478  3.06431546]
# action means and variances at step -5: [ 0.37327846 -0.12033976] [0.2206148  0.66112251]
# action statmeans and variances at step -10: [0.02507041 0.09684706] [1. 1.]
# action statmeans and variances at step -5: [0.03033201 0.08460717] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 15 * Episodic Reward is ==> -10.72451400756836
# action means and variances at step -10: [-0.42310488 -0.04208829] [0.33038305 0.36834544]
# action means and variances at step -5: [-0.17140128 -0.25885961] [0.09799164 2.56414077]
# action statmeans and variances at step -10: [0.02518391 0.10629977] [1. 1.]
# action statmeans and variances at step -5: [0.01967609 0.10196432] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 16 * Episodic Reward is ==> -10.590703010559082
# action means and variances at step -10: [-0.58088839 -0.90481976] [0.27697924 2.28080423]
# action means and variances at step -5: [ 0.6193833  -0.26751239] [1.16668817 0.91287871]
# action statmeans and variances at step -10: [0.04505456 0.08056082] [1. 1.]
# action statmeans and variances at step -5: [0.0379861  0.08105922] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 17 * Episodic Reward is ==> -10.789730072021484
# action means and variances at step -10: [0.56274097 0.33733673] [0.4830088  1.27426141]
# action means and variances at step -5: [0.03545176 0.70896041] [0.59509073 0.20832399]
# action statmeans and variances at step -10: [0.02252112 0.1179776 ] [1. 1.]
# action statmeans and variances at step -5: [0.01975741 0.11573148] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 18 * Episodic Reward is ==> -9.128971099853516
# action means and variances at step -10: [0.35931851 0.18441431] [0.8233963  1.32137865]
# action means and variances at step -5: [ 0.46101351 -1.03778961] [0.15225373 1.06936974]
# action statmeans and variances at step -10: [0.0286936  0.11474597] [1. 1.]
# action statmeans and variances at step -5: [0.01476808 0.115703  ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 19 * Episodic Reward is ==> -9.957162857055664
# action means and variances at step -10: [ 0.06628383 -0.11071463] [0.96844595 1.55517455]
# action means and variances at step -5: [-1.25176093 -0.65445483] [1.17349152 0.05779121]
# action statmeans and variances at step -10: [0.0367323  0.11574134] [1. 1.]
# action statmeans and variances at step -5: [0.03325057 0.12050949] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 20 * Episodic Reward is ==> -10.564064025878906
# action means and variances at step -10: [ 0.11741208 -0.29787667] [1.11437717 1.38256026]
# action means and variances at step -5: [-0.26462469  0.23846325] [0.73237478 0.72187498]
# action statmeans and variances at step -10: [0.03182566 0.10874033] [1. 1.]
# action statmeans and variances at step -5: [0.0452098  0.11120749] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 21 * Episodic Reward is ==> -10.134471893310547
# action means and variances at step -10: [-1.0184926   0.96249913] [0.26081727 0.34126781]
# action means and variances at step -5: [ 1.09431359 -0.59625642] [1.10747412 1.06307141]
# action statmeans and variances at step -10: [0.03151311 0.10943469] [1. 1.]
# action statmeans and variances at step -5: [0.03306545 0.11158088] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 22 * Episodic Reward is ==> -9.528810501098633
# action means and variances at step -10: [-0.14036142  0.63879253] [0.28767384 1.46328233]
# action means and variances at step -5: [0.28400563 0.30473608] [0.29280399 0.53634051]
# action statmeans and variances at step -10: [0.02783662 0.0488128 ] [1. 1.]
# action statmeans and variances at step -5: [0.03750925 0.06669285] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 23 * Episodic Reward is ==> -11.782757759094238
# action means and variances at step -10: [0.39003861 0.27121625] [0.5656775  0.55191607]
# action means and variances at step -5: [ 0.38291968 -0.47787953] [0.50701985 1.53034986]
# action statmeans and variances at step -10: [0.03804224 0.12853715] [1. 1.]
# action statmeans and variances at step -5: [0.02556119 0.13578849] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 24 * Episodic Reward is ==> -11.184375762939453
# action means and variances at step -10: [-0.17533477  0.40020511] [0.96603957 1.70901723]
# action means and variances at step -5: [-0.3804848  -0.09840397] [0.56921791 0.40091669]
# action statmeans and variances at step -10: [0.02244197 0.09104207] [1. 1.]
# action statmeans and variances at step -5: [0.02317522 0.08786119] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 25 * Episodic Reward is ==> -10.173280715942383
# action means and variances at step -10: [ 0.18696838 -0.05898248] [2.86204238 0.27281418]
# action means and variances at step -5: [ 0.49624179 -0.97464206] [0.13351882 0.67852731]
# action statmeans and variances at step -10: [0.03633785 0.13997024] [1. 1.]
# action statmeans and variances at step -5: [0.04526693 0.11412033] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 26 * Episodic Reward is ==> -10.050813674926758
# action means and variances at step -10: [0.92862317 0.43251443] [0.61302247 0.83773609]
# action means and variances at step -5: [ 0.27233555 -0.28183899] [1.55453751 1.84916953]
# action statmeans and variances at step -10: [0.02879749 0.13378975] [1. 1.]
# action statmeans and variances at step -5: [0.02317979 0.13827892] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 27 * Episodic Reward is ==> -9.963733673095703
# action means and variances at step -10: [0.98622665 0.82179593] [0.46506603 1.72650785]
# action means and variances at step -5: [0.47373726 0.46413614] [0.51827451 1.53465514]
# action statmeans and variances at step -10: [0.02043455 0.04878377] [1. 1.]
# action statmeans and variances at step -5: [0.03595211 0.08774292] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 28 * Episodic Reward is ==> -9.889876365661621
# action means and variances at step -10: [-0.00570762 -0.37493576] [0.97411507 2.22940815]
# action means and variances at step -5: [0.3948826 0.6203397] [0.54483111 0.6452521 ]
# action statmeans and variances at step -10: [0.0428855  0.14033712] [1. 1.]
# action statmeans and variances at step -5: [0.04685238 0.13336578] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 29 * Episodic Reward is ==> -10.342822074890137
# action means and variances at step -10: [0.15509633 0.46943984] [0.06645754 1.25784521]
# action means and variances at step -5: [-0.69844389  0.34728408] [0.13650414 0.19444274]
# action statmeans and variances at step -10: [0.04729942 0.13344131] [1. 1.]
# action statmeans and variances at step -5: [0.02463556 0.12098942] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 30 * Episodic Reward is ==> -10.888615608215332
# action means and variances at step -10: [1.14611432 0.14096292] [0.3397428  0.52564727]
# action means and variances at step -5: [0.70578791 0.17752231] [0.73520183 0.25745428]
# action statmeans and variances at step -10: [0.04629863 0.12706132] [1. 1.]
# action statmeans and variances at step -5: [0.04450491 0.1338922 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 31 * Episodic Reward is ==> -10.690386772155762
# action means and variances at step -10: [0.32807377 0.28233657] [0.468372   1.98702009]
# action means and variances at step -5: [0.08556435 0.5853492 ] [0.82014017 0.39843629]
# action statmeans and variances at step -10: [0.05339584 0.13996136] [1. 1.]
# action statmeans and variances at step -5: [0.05080882 0.13058169] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 32 * Episodic Reward is ==> -10.041826248168945
# action means and variances at step -10: [ 0.30450846 -0.12963166] [0.1070568  0.45381217]
# action means and variances at step -5: [-0.12173399  0.5563225 ] [0.46986512 0.9604863 ]
# action statmeans and variances at step -10: [0.0708887  0.12606612] [1. 1.]
# action statmeans and variances at step -5: [0.06820516 0.12801313] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 33 * Episodic Reward is ==> -9.909518241882324
# action means and variances at step -10: [-0.08756422 -0.57630876] [1.60424207 0.35451667]
# action means and variances at step -5: [0.20562305 0.27906309] [0.77124216 0.32910863]
# action statmeans and variances at step -10: [0.05592972 0.10462405] [1. 1.]
# action statmeans and variances at step -5: [0.06269574 0.1074257 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 34 * Episodic Reward is ==> -11.492663383483887
# action means and variances at step -10: [-0.34014892 -0.53957015] [0.00596712 1.56791487]
# action means and variances at step -5: [0.96944933 0.04336228] [0.20555533 1.03715941]
# action statmeans and variances at step -10: [0.07077383 0.05047561] [1. 1.]
# action statmeans and variances at step -5: [0.07388744 0.0421642 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 35 * Episodic Reward is ==> -10.207763671875
# action means and variances at step -10: [-0.52575717 -0.60937415] [1.82447835 0.10716008]
# action means and variances at step -5: [ 0.23455455 -0.41803984] [2.19997784 0.34511231]
# action statmeans and variances at step -10: [0.07570461 0.10009202] [1. 1.]
# action statmeans and variances at step -5: [0.05462631 0.08487508] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 36 * Episodic Reward is ==> -10.540301322937012
# action means and variances at step -10: [ 0.25783109 -0.73099405] [1.18691121 0.51483266]
# action means and variances at step -5: [ 0.25542317 -1.12122519] [3.97682859 0.40602487]
# action statmeans and variances at step -10: [0.07432102 0.09259041] [1. 1.]
# action statmeans and variances at step -5: [0.07348631 0.10251632] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 37 * Episodic Reward is ==> -10.057787895202637
# action means and variances at step -10: [0.44458752 1.00591836] [0.51188772 0.73625598]
# action means and variances at step -5: [-0.41067766  0.36068122] [0.81597975 0.10065932]
# action statmeans and variances at step -10: [0.10538089 0.10410547] [1. 1.]
# action statmeans and variances at step -5: [0.09850173 0.10726646] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 38 * Episodic Reward is ==> -9.700736045837402
# action means and variances at step -10: [0.54065133 0.01010959] [0.29746398 0.05541694]
# action means and variances at step -5: [0.52946786 0.22026988] [1.19765733 0.50605991]
# action statmeans and variances at step -10: [0.07245257 0.10182355] [1. 1.]
# action statmeans and variances at step -5: [0.07613295 0.09143757] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 39 * Episodic Reward is ==> -9.746908187866211
# action means and variances at step -10: [-0.23301253 -0.53132317] [0.66551539 0.69522173]
# action means and variances at step -5: [0.25845925 0.34712419] [0.10349815 0.50763167]
# action statmeans and variances at step -10: [0.09771553 0.07412271] [1. 1.]
# action statmeans and variances at step -5: [0.08284742 0.07832389] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 40 * Episodic Reward is ==> -10.86338996887207
# action means and variances at step -10: [-0.68200145  0.35032104] [0.8320154  0.58249722]
# action means and variances at step -5: [0.16035103 0.06390651] [2.09089286 1.71288274]
# action statmeans and variances at step -10: [0.08451416 0.05936854] [1. 1.]
# action statmeans and variances at step -5: [0.10883839 0.06687818] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 41 * Episodic Reward is ==> -9.915870666503906
# action means and variances at step -10: [0.3833138  0.18523826] [0.36105813 0.11370762]
# action means and variances at step -5: [-0.26793894  0.50437309] [0.32307136 0.19262157]
# action statmeans and variances at step -10: [0.08791032 0.09403463] [1. 1.]
# action statmeans and variances at step -5: [0.09591244 0.08781971] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 42 * Episodic Reward is ==> -10.678658485412598
# action means and variances at step -10: [ 0.16862371 -0.56708979] [0.48394865 1.24365977]
# action means and variances at step -5: [-0.52222911 -0.55138532] [0.31600021 1.74696432]
# action statmeans and variances at step -10: [0.0803832  0.06819481] [1. 1.]
# action statmeans and variances at step -5: [0.0706703  0.07125168] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 43 * Episodic Reward is ==> -10.516454696655273
# action means and variances at step -10: [ 0.35091206 -0.29153076] [0.62891642 0.98114866]
# action means and variances at step -5: [-0.01717884  0.01862147] [0.68202632 1.48256503]
# action statmeans and variances at step -10: [0.08831301 0.00615171] [1. 1.]
# action statmeans and variances at step -5: [0.09341858 0.00882125] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 44 * Episodic Reward is ==> -11.043281555175781
# action means and variances at step -10: [1.02964958 0.25528968] [0.60659129 2.10622028]
# action means and variances at step -5: [-0.191465    0.02295927] [0.66965961 0.56677474]
# action statmeans and variances at step -10: [0.09218213 0.01542987] [1. 1.]
# action statmeans and variances at step -5: [0.12102371 0.02721383] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 45 * Episodic Reward is ==> -9.65185832977295
# action means and variances at step -10: [-0.54696557 -0.70244132] [0.68657321 0.17545949]
# action means and variances at step -5: [1.22106873 0.54584767] [0.20710195 0.83587491]
# action statmeans and variances at step -10: [0.09445091 0.04959275] [1. 1.]
# action statmeans and variances at step -5: [0.09267905 0.0501967 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 46 * Episodic Reward is ==> -10.821621894836426
# action means and variances at step -10: [0.54302243 0.33639622] [0.6797505  0.09574534]
# action means and variances at step -5: [ 0.25105963 -0.06785105] [0.15680945 1.50836117]
# action statmeans and variances at step -10: [0.13101855 0.05161213] [1. 1.]
# action statmeans and variances at step -5: [0.12201992 0.0352967 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 47 * Episodic Reward is ==> -11.227824211120605
# action means and variances at step -10: [0.35303639 0.83161051] [1.46071089 0.06073732]
# action means and variances at step -5: [0.70481578 0.52778038] [1.27452525 0.43642406]
# action statmeans and variances at step -10: [0.10988899 0.03031663] [1. 1.]
# action statmeans and variances at step -5: [0.11724384 0.04087374] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 48 * Episodic Reward is ==> -11.112667083740234
# action means and variances at step -10: [-0.21916902  1.03564325] [0.68701662 0.37833688]
# action means and variances at step -5: [ 0.72470677 -0.83376752] [1.9742543  0.26730067]
# action statmeans and variances at step -10: [0.11002956 0.03528417] [1. 1.]
# action statmeans and variances at step -5: [0.10638533 0.03430298] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 49 * Episodic Reward is ==> -11.151716232299805
# action means and variances at step -10: [ 0.24965393 -0.82384159] [1.72137412 0.30200081]
# action means and variances at step -5: [-0.08747226 -0.12401913] [0.28705049 0.1640962 ]
# action statmeans and variances at step -10: [0.13717881 0.05095951] [1. 1.]
# action statmeans and variances at step -5: [0.1337789  0.04161145] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 50 * Episodic Reward is ==> -9.331095695495605
# action means and variances at step -10: [-0.76059646 -0.41187717] [0.38154568 0.40525865]
# action means and variances at step -5: [0.0524035  0.38812056] [0.2777787  0.99746323]
# action statmeans and variances at step -10: [0.14000115 0.00473357] [1. 1.]
# action statmeans and variances at step -5: [0.11752084 0.00903123] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 51 * Episodic Reward is ==> -10.264267921447754
# action means and variances at step -10: [-0.25258567 -0.8779651 ] [0.22672048 1.00484353]
# action means and variances at step -5: [ 0.31006431 -0.23357759] [0.71032597 1.38805094]
# action statmeans and variances at step -10: [0.10287914 0.03979144] [1. 1.]
# action statmeans and variances at step -5: [0.11206352 0.04818109] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 52 * Episodic Reward is ==> -10.249558448791504
# action means and variances at step -10: [-1.14405612 -0.27406208] [0.14120784 0.73413339]
# action means and variances at step -5: [0.10640019 0.46977022] [0.09697733 0.56991908]
# action statmeans and variances at step -10: [0.12379957 0.03724161] [1. 1.]
# action statmeans and variances at step -5: [0.10471603 0.04093174] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 53 * Episodic Reward is ==> -10.6690092086792
# action means and variances at step -10: [1.14925623 0.37521923] [2.80161615 0.37033981]
# action means and variances at step -5: [-0.43104699 -0.53056171] [0.71586765 1.14151033]
# action statmeans and variances at step -10: [0.12541333 0.02008849] [1. 1.]
# action statmeans and variances at step -5: [0.14366254 0.02434462] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 54 * Episodic Reward is ==> -10.29628849029541
# action means and variances at step -10: [0.58599734 0.02268457] [0.19488127 1.63578698]
# action means and variances at step -5: [ 0.60592611 -1.03808948] [0.44476131 0.57555959]
# action statmeans and variances at step -10: [ 0.13536638 -0.00618168] [1. 1.]
# action statmeans and variances at step -5: [0.15801103 0.00519491] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 55 * Episodic Reward is ==> -9.890965461730957
# action means and variances at step -10: [ 0.31551827 -0.12509475] [1.41384216 0.26456002]
# action means and variances at step -5: [0.20410073 0.42277439] [1.90280491 0.43124651]
# action statmeans and variances at step -10: [0.13846883 0.0513604 ] [1. 1.]
# action statmeans and variances at step -5: [0.13596676 0.04934206] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 56 * Episodic Reward is ==> -11.009734153747559
# action means and variances at step -10: [-0.00231918  0.59792515] [1.18764727 0.19011024]
# action means and variances at step -5: [0.25780395 0.06338285] [0.8659025  1.92708333]
# action statmeans and variances at step -10: [0.13800015 0.0105012 ] [1. 1.]
# action statmeans and variances at step -5: [0.1362569  0.02931161] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 57 * Episodic Reward is ==> -10.617365837097168
# action means and variances at step -10: [0.81467283 0.22328468] [0.5176042  0.52328339]
# action means and variances at step -5: [-0.88690803 -0.43886246] [0.24432045 2.37899745]
# action statmeans and variances at step -10: [0.14063829 0.02461336] [1. 1.]
# action statmeans and variances at step -5: [0.14256872 0.04020413] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 58 * Episodic Reward is ==> -11.00615119934082
# action means and variances at step -10: [0.00144564 0.67718793] [0.25027325 0.47064217]
# action means and variances at step -5: [-0.34932693 -0.76744805] [0.82442288 1.18295034]
# action statmeans and variances at step -10: [0.15543875 0.01350644] [1. 1.]
# action statmeans and variances at step -5: [0.13707678 0.02583257] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 59 * Episodic Reward is ==> -10.578290939331055
# action means and variances at step -10: [-0.72987433  0.41764795] [1.10378967 0.17253816]
# action means and variances at step -5: [-0.46052161  0.52130581] [0.99429225 1.11741154]
# action statmeans and variances at step -10: [0.13560584 0.0244814 ] [1. 1.]
# action statmeans and variances at step -5: [0.14155008 0.02448139] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 60 * Episodic Reward is ==> -9.248147964477539
# action means and variances at step -10: [ 0.04481979 -0.35976186] [0.48113147 0.24072193]
# action means and variances at step -5: [ 0.55342236 -0.19096771] [0.25259873 0.58218435]
# action statmeans and variances at step -10: [ 0.13780555 -0.00412375] [1. 1.]
# action statmeans and variances at step -5: [ 0.12456914 -0.00117783] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 61 * Episodic Reward is ==> -10.014422416687012
# action means and variances at step -10: [ 0.59632237 -0.0909723 ] [0.56695268 0.88519632]
# action means and variances at step -5: [-0.28295872 -0.84595011] [0.35244365 0.68798946]
# action statmeans and variances at step -10: [0.14620218 0.01042237] [1. 1.]
# action statmeans and variances at step -5: [0.13284017 0.00887173] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 62 * Episodic Reward is ==> -10.792757034301758
# action means and variances at step -10: [ 0.53514142 -0.38130215] [1.37248827 0.6047909 ]
# action means and variances at step -5: [-0.10824972  0.23209067] [0.49711798 0.97235607]
# action statmeans and variances at step -10: [ 0.12619166 -0.01948142] [1. 1.]
# action statmeans and variances at step -5: [ 0.12058927 -0.0201363 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 63 * Episodic Reward is ==> -9.456740379333496
# action means and variances at step -10: [-0.07759686  0.04924469] [0.84234951 0.34137523]
# action means and variances at step -5: [0.28029125 0.06453785] [0.29974282 0.13270698]
# action statmeans and variances at step -10: [ 0.15330215 -0.00489065] [1. 1.]
# action statmeans and variances at step -5: [0.1495018  0.00225864] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 64 * Episodic Reward is ==> -11.683123588562012
# action means and variances at step -10: [ 1.22098782 -0.08224895] [0.09313431 0.40018018]
# action means and variances at step -5: [ 0.39580917 -0.56411731] [0.44115429 0.4490461 ]
# action statmeans and variances at step -10: [ 0.14713411 -0.02793064] [1. 1.]
# action statmeans and variances at step -5: [ 0.13856605 -0.03159875] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 65 * Episodic Reward is ==> -11.417257308959961
# action means and variances at step -10: [ 0.20384666 -0.44846306] [1.94136655 1.1908464 ]
# action means and variances at step -5: [0.18546169 0.48864251] [0.28023548 2.26692439]
# action statmeans and variances at step -10: [ 0.12332533 -0.03498733] [1. 1.]
# action statmeans and variances at step -5: [ 0.13549164 -0.03398067] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 66 * Episodic Reward is ==> -10.556764602661133
# action means and variances at step -10: [-0.28579509 -0.30315497] [1.51896524 0.2363188 ]
# action means and variances at step -5: [-0.40937118 -0.84031524] [0.48759741 0.80041949]
# action statmeans and variances at step -10: [ 0.14709747 -0.01262703] [1. 1.]
# action statmeans and variances at step -5: [ 0.14180025 -0.01310354] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 67 * Episodic Reward is ==> -11.283992767333984
# action means and variances at step -10: [ 0.81002347 -0.87340013] [1.06350889 1.62323378]
# action means and variances at step -5: [0.97462909 0.29066583] [1.17815655 0.61596074]
# action statmeans and variances at step -10: [ 0.13204463 -0.04098501] [1. 1.]
# action statmeans and variances at step -5: [ 0.11501519 -0.04671948] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 68 * Episodic Reward is ==> -10.912872314453125
# action means and variances at step -10: [-0.12039408  0.00071697] [0.03216307 0.18631605]
# action means and variances at step -5: [ 0.47227201 -0.30131345] [0.73363867 1.377709  ]
# action statmeans and variances at step -10: [ 0.15049826 -0.03596787] [1. 1.]
# action statmeans and variances at step -5: [ 0.14575022 -0.03548693] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 69 * Episodic Reward is ==> -11.42146110534668
# action means and variances at step -10: [ 0.51245881 -0.1313267 ] [0.74790165 1.85830051]
# action means and variances at step -5: [-0.16986907 -0.88474351] [0.09600676 0.2487972 ]
# action statmeans and variances at step -10: [ 0.16073734 -0.04794464] [1. 1.]
# action statmeans and variances at step -5: [ 0.16967376 -0.0454601 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 70 * Episodic Reward is ==> -10.557910919189453
# action means and variances at step -10: [-0.62728677 -0.5188759 ] [0.13475857 1.04158941]
# action means and variances at step -5: [ 0.09888095 -0.19927493] [1.03752889 0.46905219]
# action statmeans and variances at step -10: [ 0.12159153 -0.05501257] [1. 1.]
# action statmeans and variances at step -5: [ 0.10837588 -0.06585892] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 71 * Episodic Reward is ==> -11.507107734680176
# action means and variances at step -10: [ 0.47315238 -0.6031112 ] [1.5953668  0.91236019]
# action means and variances at step -5: [-0.21337178  0.53379294] [0.62350565 0.42617221]
# action statmeans and variances at step -10: [ 0.14885099 -0.07145656] [1. 1.]
# action statmeans and variances at step -5: [ 0.14355908 -0.07374429] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 72 * Episodic Reward is ==> -9.999588012695312
# action means and variances at step -10: [0.51474175 0.46733254] [0.88020148 0.4519003 ]
# action means and variances at step -5: [1.22814735 0.19232139] [0.61900179 0.33752247]
# action statmeans and variances at step -10: [ 0.1254186  -0.07229459] [1. 1.]
# action statmeans and variances at step -5: [ 0.12436825 -0.07671039] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 73 * Episodic Reward is ==> -10.334277153015137
# action means and variances at step -10: [ 0.54454364 -0.43115704] [0.26644774 0.68343852]
# action means and variances at step -5: [0.11997896 0.57400204] [0.26729833 1.29990966]
# action statmeans and variances at step -10: [ 0.13941659 -0.08069838] [1. 1.]
# action statmeans and variances at step -5: [ 0.12909082 -0.08050521] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# ...
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4684 * Episodic Reward is ==> -9.473152160644531
# action means and variances at step -10: [ 0.84167266 -0.56017927] [0.85130538 2.01235235]
# action means and variances at step -5: [-0.2816598   0.27653053] [1.11609985 0.43135332]
# action statmeans and variances at step -10: [-0.00752728 -0.00099519] [1. 1.]
# action statmeans and variances at step -5: [-0.00752728 -0.00099519] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4685 * Episodic Reward is ==> -11.226037979125977
# action means and variances at step -10: [-0.0466999  -0.12325908] [0.06210283 1.12745463]
# action means and variances at step -5: [0.04763594 0.65636011] [0.31053299 0.55431968]
# action statmeans and variances at step -10: [-0.00742379 -0.0009082 ] [1. 1.]
# action statmeans and variances at step -5: [-0.00742379 -0.0009082 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4686 * Episodic Reward is ==> -10.723342895507812
# action means and variances at step -10: [-0.67969382  0.052542  ] [0.16792598 0.10745894]
# action means and variances at step -5: [0.40687774 0.21053948] [0.20971662 0.24680521]
# action statmeans and variances at step -10: [-0.00732937 -0.00078465] [1. 1.]
# action statmeans and variances at step -5: [-0.00732937 -0.00078465] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4687 * Episodic Reward is ==> -9.903460502624512
# action means and variances at step -10: [0.8155501  0.01606403] [1.06931598 1.48188074]
# action means and variances at step -5: [0.00393332 0.10830304] [0.71366966 0.75643881]
# action statmeans and variances at step -10: [-0.00726136 -0.00068132] [1. 1.]
# action statmeans and variances at step -5: [-0.00726136 -0.00068132] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4688 * Episodic Reward is ==> -11.498491287231445
# action means and variances at step -10: [-0.24483539  0.16776162] [0.28713399 0.0493147 ]
# action means and variances at step -5: [0.20552217 0.3923923 ] [0.61876859 1.26367771]
# action statmeans and variances at step -10: [-0.00723111 -0.00057836] [1. 1.]
# action statmeans and variances at step -5: [-0.00723111 -0.00057836] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4689 * Episodic Reward is ==> -10.240269660949707
# action means and variances at step -10: [0.05339884 0.61137858] [0.53635347 0.56168803]
# action means and variances at step -5: [-0.32734977 -0.12656819] [0.65117764 0.5100199 ]
# action statmeans and variances at step -10: [-0.00721278 -0.00049267] [1. 1.]
# action statmeans and variances at step -5: [-0.00721278 -0.00049267] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4690 * Episodic Reward is ==> -10.46469497680664
# action means and variances at step -10: [ 0.65711708 -0.85266057] [0.18004084 0.67429019]
# action means and variances at step -5: [-0.02508746 -0.45976293] [0.20892649 0.55667117]
# action statmeans and variances at step -10: [-0.00718493 -0.00043891] [1. 1.]
# action statmeans and variances at step -5: [-0.00718493 -0.00043891] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4691 * Episodic Reward is ==> -10.26477336883545
# action means and variances at step -10: [0.02441135 0.28296845] [0.73991341 0.18983011]
# action means and variances at step -5: [0.00104198 0.19635859] [0.02965141 0.30069016]
# action statmeans and variances at step -10: [-0.00712376 -0.00042074] [1. 1.]
# action statmeans and variances at step -5: [-0.00712376 -0.00042074] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4692 * Episodic Reward is ==> -10.98218059539795
# action means and variances at step -10: [-0.9387261  -0.42816422] [1.43020501 1.30920741]
# action means and variances at step -5: [0.02685979 0.20198706] [0.89169415 0.51679232]
# action statmeans and variances at step -10: [-0.0070504  -0.00043166] [1. 1.]
# action statmeans and variances at step -5: [-0.0070504  -0.00043166] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4693 * Episodic Reward is ==> -11.371089935302734
# action means and variances at step -10: [ 1.04331828 -0.7115401 ] [0.57479143 0.86423264]
# action means and variances at step -5: [0.70964005 0.15314421] [1.14799471 0.35987042]
# action statmeans and variances at step -10: [-0.00698772 -0.00039178] [1. 1.]
# action statmeans and variances at step -5: [-0.00698772 -0.00039178] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4694 * Episodic Reward is ==> -11.154720306396484
# action means and variances at step -10: [-0.43503379 -0.6781048 ] [0.53665189 0.64816553]
# action means and variances at step -5: [0.3918069  0.07709898] [0.63773897 0.21813054]
# action statmeans and variances at step -10: [-0.00692109 -0.00036131] [1. 1.]
# action statmeans and variances at step -5: [-0.00692109 -0.00036131] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4695 * Episodic Reward is ==> -9.658023834228516
# action means and variances at step -10: [0.08567829 0.19984765] [0.1093335  0.80465191]
# action means and variances at step -5: [0.22080594 0.29015747] [1.14898748 0.30564908]
# action statmeans and variances at step -10: [-0.00683859 -0.00034292] [1. 1.]
# action statmeans and variances at step -5: [-0.00683859 -0.00034292] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4696 * Episodic Reward is ==> -10.51625919342041
# action means and variances at step -10: [-0.07505818 -0.36377298] [1.26671353 0.33191215]
# action means and variances at step -5: [-0.12042823 -0.63235227] [0.07668206 0.23380712]
# action statmeans and variances at step -10: [-0.00675669 -0.00030051] [1. 1.]
# action statmeans and variances at step -5: [-0.00675669 -0.00030051] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4697 * Episodic Reward is ==> -10.38879680633545
# action means and variances at step -10: [0.10585394 0.17882352] [0.47459493 0.19027409]
# action means and variances at step -5: [-0.38428625  0.90222377] [0.3250471 0.5515102]
# action statmeans and variances at step -10: [-0.00670199 -0.000294  ] [1. 1.]
# action statmeans and variances at step -5: [-0.00670199 -0.000294  ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4698 * Episodic Reward is ==> -10.132196426391602
# action means and variances at step -10: [-0.31421507  0.98062386] [0.21346153 1.07127334]
# action means and variances at step -5: [-0.06229082  0.81281056] [0.31372125 2.4116395 ]
# action statmeans and variances at step -10: [-0.006607   -0.00033781] [1. 1.]
# action statmeans and variances at step -5: [-0.006607   -0.00033781] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4699 * Episodic Reward is ==> -11.055829048156738
# action means and variances at step -10: [-1.08890366  0.17527043] [0.56054471 0.67119163]
# action means and variances at step -5: [-0.3434765   0.35671299] [0.23877584 0.23176996]
# action statmeans and variances at step -10: [-0.00649727 -0.00039921] [1. 1.]
# action statmeans and variances at step -5: [-0.00649727 -0.00039921] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4700 * Episodic Reward is ==> -10.772727966308594
# action means and variances at step -10: [ 0.13519035 -0.40948578] [0.46357366 0.06054823]
# action means and variances at step -5: [0.63907829 0.35711127] [0.70679777 0.20080157]
# action statmeans and variances at step -10: [-0.00642304 -0.00050064] [1. 1.]
# action statmeans and variances at step -5: [-0.00642304 -0.00050064] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4701 * Episodic Reward is ==> -9.703109741210938
# action means and variances at step -10: [ 0.01917215 -0.0314462 ] [0.49744663 0.10334501]
# action means and variances at step -5: [-0.02239857 -0.04581534] [1.00817871 0.56765255]
# action statmeans and variances at step -10: [-0.00637197 -0.0005891 ] [1. 1.]
# action statmeans and variances at step -5: [-0.00637197 -0.0005891 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4702 * Episodic Reward is ==> -10.43538761138916
# action means and variances at step -10: [0.67462353 0.23823122] [0.2802932  1.08490376]
# action means and variances at step -5: [-0.25514076  0.27600239] [1.53033471 0.52707626]
# action statmeans and variances at step -10: [-0.00630791 -0.00067141] [1. 1.]
# action statmeans and variances at step -5: [-0.00630791 -0.00067141] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4703 * Episodic Reward is ==> -10.542126655578613
# action means and variances at step -10: [-0.48736673 -0.2773817 ] [1.02604557 0.66787638]
# action means and variances at step -5: [-0.32090388 -0.32350193] [1.26522982 2.91455661]
# action statmeans and variances at step -10: [-0.00628217 -0.00072221] [1. 1.]
# action statmeans and variances at step -5: [-0.00628217 -0.00072221] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4704 * Episodic Reward is ==> -11.160164833068848
# action means and variances at step -10: [-0.49290751  0.80799844] [0.26281842 0.3247549 ]
# action means and variances at step -5: [-0.17278719  0.20300443] [0.42705699 0.64314643]
# action statmeans and variances at step -10: [-0.00625917 -0.00077364] [1. 1.]
# action statmeans and variances at step -5: [-0.00625917 -0.00077364] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4705 * Episodic Reward is ==> -11.810056686401367
# action means and variances at step -10: [0.4602669  0.04705111] [0.01618253 0.85129456]
# action means and variances at step -5: [0.01818557 0.07318772] [0.09228231 0.58687916]
# action statmeans and variances at step -10: [-0.00624172 -0.00083263] [1. 1.]
# action statmeans and variances at step -5: [-0.00624172 -0.00083263] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1711367/2770044457.py in <module>
#      40     agent.train(np.array(states), np.array(actions), np.array(rewards),shaper_fn=env.unflatten_observation_v2)
#      41     reward_records.append(episodic_reward)
# ---> 42     print(f"Episode * {ep} * Episodic Reward is ==> {episodic_reward.numpy().mean()}")
#      43 #     print(f"Episode * {ep} * exploration epsilon {epsilon} * Episodic Reward is ==> {episodic_reward.numpy().mean()}")
#      44     print("action means and variances at step -10:", action_mean_records[-10],action_var_records[-10])
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1092     """
#    1093     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1094     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1095     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1096
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1058   def _numpy(self):
#    1059     try:
# -> 1060       return self._numpy_internal()
#    1061     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1062       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
reward_records_=np.mean(reward_records, axis=1)

# %%
np.array(action_statmean_records).shape
# Out:
# (160038, 4, 2)

# %%
plt.plot(reward_records_)

# %%
plt.plot(rewards)
# Out:
# [<matplotlib.lines.Line2D at 0x7f3d81cc8700>,
#  <matplotlib.lines.Line2D at 0x7f3d804b2f10>,
#  <matplotlib.lines.Line2D at 0x7f3d804b22e0>,
#  <matplotlib.lines.Line2D at 0x7f3d804b2310>]

# %%
import misc

# %%
plt.plot(reward_records_)
plt.plot(misc.smooth(reward_records_,100))
plt.grid()

# %%
# plt.plot(reward_records)
plt.plot(misc.smooth(reward_records_,100))
plt.grid()
plt.ylim([-12,-10])
# Out:
# (-12.0, -10.0)

# %%
np.shape(action_statmean_records)
# Out:
# (160038, 4, 2)

# %%
plt.plot(np.array(action_statmean_records).reshape([-1,8])[:,0])

# %%
plt.plot(np.array(action_statmean_records).reshape([-1,8])[:,1])

# %%
_=plt.hist(np.array(action_statmean_records).reshape([-1,8])[:,1],bins=100)
