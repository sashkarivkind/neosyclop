# %%
'''in this version we always use the same batch of images'''
# Out:
# 'in this version we always use the same batch of images'

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # or any {'0', '1', '2'}
from imagenet_dataset import get_dataset
from retina_env import RetinaEnv, calculate_retinal_filter
from rl_networks import create_actor_model, create_critic_model, policy
from rl_core import Buffer, update_target
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from pg_core import GaussianPolicyAgent

import types
config = types.SimpleNamespace()
config.batch_size = 32
config.margin = 20
config.image_h = 224
config.image_w = 224
config.image_hm = config.image_h+2*config.margin
config.image_wm = config.image_w+2*config.margin
config.foveate = None
config.do_grayscale = True
config.history_length = 16
config.t_ignore = 16
config.t_max =50
config.motion_mode = 'velocity'
config.use_dones = False

config.gym_mode = False
t_vec = np.linspace(0,150,16)

balanced_filter = calculate_retinal_filter(t_vec, R=1.0)
config.filter = balanced_filter.reshape([1,1,-1,1])
config.min_freq = 1
config.max_freq = 13
config.action_upper_bound = np.array([2.0, 2.0])
actor_lr = 1e-4
dataset_dir = '/home/bnapp/datasets/tensorflow_datasets/imagenet2012/5.0.0/'

def epsilon_scheduler(episode, floor_episode=200, epsilon_floor=0.1):
    if episode < floor_episode:
        return 1.-(1.-epsilon_floor)*episode/floor_episode
    else:
        return epsilon_floor

dataset = get_dataset(dataset_dir,
                                     'validation',
                                     config.batch_size,
                                     image_h = config.image_hm,
                                     image_w = config.image_wm,
                                     preprocessing='identity',
                                     rggb_mode=False,
                                     central_squeeze_and_pad_factor=-1)

# env = RetinaEnv(config, image_generator=dataset)
env = RetinaEnv(config) #freezing on first batch
for images,_ in dataset:
    break
    
if config.gym_mode:
    num_states = env.observation_space.shape[0]
    num_actions = env.action_space.shape[0]

    upper_bound = env.action_space.high[0]
    lower_bound = env.action_space.low[0]
else:
    num_states = env.observation_size
    num_actions = env.action_size
    upper_bound = env.action_upper_bound
    lower_bound = env.action_lower_bound


actor_model = create_actor_model(env.image_h, env.image_w,
                                 env.spectral_density_size, env.location_history_size,
                                 env.timestep_size, env.action_size)
actor_optimizer = tf.keras.optimizers.Adam(actor_lr)
actor_model.optimizer = actor_optimizer
agent = GaussianPolicyAgent(std_deviation=1.0,model=actor_model)
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.3.0 and strictly below 2.6.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.6.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# WARNING:tensorflow:From /home/bnapp/arivkindNet/neosyclop/imagenet_dataset.py:124: map_and_batch (from tensorflow.python.data.experimental.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map(map_func, num_parallel_calls)` followed by `tf.data.Dataset.batch(batch_size, drop_remainder)`. Static tf.data optimizations will take care of using the fused implementation.

# %%
# Training loop
reward_records = []
epsilon_records = []
action_mean_records = []
action_var_records = []
action_statmean_records = []
action_statvar_records = []
episodes = 10000
for ep in range(episodes):
    prev_state = env.reset(images=images)
    episodic_reward = 0
    states, actions, rewards = [], [], []

#     epsilon = epsilon_scheduler(ep, floor_episode=1000)

    while True:

        deterministic_action, means,stdevs = agent.get_action(env.unflatten_observation(prev_state),
                                               return_stats=True)
        action = deterministic_action #hook in order to add noise if neccessary
        state, reward, done, info = env.step(action)
        
        if env.warmup_done:
            states.append(prev_state)
            actions.append(action)
            rewards.append(reward)
                
            episodic_reward += reward
           
            action_mean_records.append(deterministic_action.mean(axis=0))
            action_var_records.append(deterministic_action.var(axis=0))
            action_statmean_records.append(means)
            action_statvar_records.append(stdevs)
        # End this episode when `done` is True
        if done:
            break

        prev_state = np.copy(state)
    
    agent.train(np.array(states), np.array(actions), np.array(rewards),shaper_fn=env.unflatten_observation_v2,
                max_iterations=1000)
    reward_records.append(episodic_reward)
    print(f"Episode * {ep} * Episodic Reward is ==> {episodic_reward.numpy().mean()}")
#     print(f"Episode * {ep} * exploration epsilon {epsilon} * Episodic Reward is ==> {episodic_reward.numpy().mean()}")
    print("action means and variances at step -10:", action_mean_records[-10],action_var_records[-10])
    print("action means and variances at step -5:", action_mean_records[-5],action_var_records[-5])
    print("action statmeans and variances at step -10:", action_statmean_records[-10][0],action_statvar_records[-10][0])
    print("action statmeans and variances at step -5:", action_statmean_records[-5][0],action_statvar_records[-5][0])
# Out:
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 0 * Episodic Reward is ==> -12.132564544677734
# action means and variances at step -10: [-0.15901747 -0.28812323] [0.84417446 0.92579261]
# action means and variances at step -5: [ 0.12215304 -0.45225708] [1.23500105 1.33685371]
# action statmeans and variances at step -10: [ 0.02831126 -0.04708719] [1. 1.]
# action statmeans and variances at step -5: [ 0.04764225 -0.06465155] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 1 * Episodic Reward is ==> -12.42458438873291
# action means and variances at step -10: [-0.31938541 -0.26773713] [0.95141884 1.21909266]
# action means and variances at step -5: [-0.2559685  -0.06412307] [0.83256541 1.19486763]
# action statmeans and variances at step -10: [ 0.06362431 -0.01568945] [1. 1.]
# action statmeans and variances at step -5: [0.04504372 0.0029551 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 2 * Episodic Reward is ==> -12.836356163024902
# action means and variances at step -10: [-0.03237427 -0.08204322] [0.80074882 0.73616196]
# action means and variances at step -5: [-0.05781486 -0.20122746] [1.06927046 0.90269858]
# action statmeans and variances at step -10: [-0.00383643 -0.04577865] [1. 1.]
# action statmeans and variances at step -5: [-0.0467403   0.01823286] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 3 * Episodic Reward is ==> -12.664146423339844
# action means and variances at step -10: [-0.13556299  0.03398708] [0.96199089 0.97286001]
# action means and variances at step -5: [-0.37278545  0.05145026] [0.89157274 1.25761633]
# action statmeans and variances at step -10: [-0.08966194 -0.05457942] [1. 1.]
# action statmeans and variances at step -5: [-0.10211903 -0.07773821] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4 * Episodic Reward is ==> -12.317821502685547
# action means and variances at step -10: [-0.15237152 -0.08738928] [1.05134956 0.93693004]
# action means and variances at step -5: [-0.38897576  0.06493419] [0.79828361 1.4637921 ]
# action statmeans and variances at step -10: [-0.16065927 -0.05235238] [1. 1.]
# action statmeans and variances at step -5: [-0.15683356 -0.04310413] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5 * Episodic Reward is ==> -12.68082046508789
# action means and variances at step -10: [-0.00861679 -0.05810918] [1.31823287 0.97278274]
# action means and variances at step -5: [-0.08716241  0.01512429] [0.73573487 0.66239462]
# action statmeans and variances at step -10: [-0.17194068 -0.0546352 ] [1. 1.]
# action statmeans and variances at step -5: [-0.17409591 -0.0553585 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 6 * Episodic Reward is ==> -12.644922256469727
# action means and variances at step -10: [ 0.03699736 -0.17562126] [1.26417718 0.84240304]
# action means and variances at step -5: [-0.27963086  0.08316084] [0.63016841 1.04707435]
# action statmeans and variances at step -10: [-0.16784838 -0.07860453] [1. 1.]
# action statmeans and variances at step -5: [-0.16469865 -0.07461101] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 7 * Episodic Reward is ==> -12.367204666137695
# action means and variances at step -10: [-0.18484243  0.22812414] [0.823497   0.65535657]
# action means and variances at step -5: [-0.37075677 -0.43098637] [1.08778181 0.96661249]
# action statmeans and variances at step -10: [-0.16318518 -0.14898337] [1. 1.]
# action statmeans and variances at step -5: [-0.16360041 -0.1364451 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 8 * Episodic Reward is ==> -12.85474967956543
# action means and variances at step -10: [-0.38670136  0.03573608] [1.53358922 0.97557626]
# action means and variances at step -5: [-0.03820619 -0.3156571 ] [0.9478177  0.99719349]
# action statmeans and variances at step -10: [-0.1851993  -0.18484557] [1. 1.]
# action statmeans and variances at step -5: [-0.17496054 -0.1780678 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 9 * Episodic Reward is ==> -12.438390731811523
# action means and variances at step -10: [-0.12301883 -0.33512619] [0.84048671 0.66896467]
# action means and variances at step -5: [ 0.10345279 -0.13618777] [1.26773366 0.91583709]
# action statmeans and variances at step -10: [-0.15998301 -0.17555131] [1. 1.]
# action statmeans and variances at step -5: [-0.1642682  -0.18086965] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 10 * Episodic Reward is ==> -11.967639923095703
# action means and variances at step -10: [ 0.27281471 -0.24551458] [1.12921539 1.0062987 ]
# action means and variances at step -5: [-0.09860071 -0.18866391] [1.20669903 0.56436557]
# action statmeans and variances at step -10: [-0.10665874 -0.13613354] [1. 1.]
# action statmeans and variances at step -5: [-0.10998798 -0.13828275] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 11 * Episodic Reward is ==> -12.765172958374023
# action means and variances at step -10: [-0.23037621  0.11863417] [1.13411659 0.57032534]
# action means and variances at step -5: [-0.03122456 -0.16922029] [0.89594378 1.35646089]
# action statmeans and variances at step -10: [-0.06088211 -0.10547689] [1. 1.]
# action statmeans and variances at step -5: [-0.05594664 -0.10512516] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 12 * Episodic Reward is ==> -12.458988189697266
# action means and variances at step -10: [-0.04498848 -0.02110781] [0.81470837 0.73732375]
# action means and variances at step -5: [-0.13069479  0.01715451] [0.67253063 0.85490097]
# action statmeans and variances at step -10: [-0.08871563 -0.13720378] [1. 1.]
# action statmeans and variances at step -5: [-0.09009323 -0.13988678] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 13 * Episodic Reward is ==> -11.945358276367188
# action means and variances at step -10: [-0.06950313 -0.20568995] [0.74444668 1.08268659]
# action means and variances at step -5: [-0.2665169  -0.39100075] [0.74816248 1.47175054]
# action statmeans and variances at step -10: [-0.10715768 -0.08725495] [1. 1.]
# action statmeans and variances at step -5: [-0.10508545 -0.09181537] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 14 * Episodic Reward is ==> -12.276321411132812
# action means and variances at step -10: [0.22461156 0.0166428 ] [1.35900941 0.83422485]
# action means and variances at step -5: [0.03039798 0.17667545] [1.58439805 0.92405666]
# action statmeans and variances at step -10: [-0.07455233  0.02387384] [1. 1.]
# action statmeans and variances at step -5: [-0.07185914  0.01656764] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 15 * Episodic Reward is ==> -13.23038101196289
# action means and variances at step -10: [-0.20922066 -0.06555657] [0.93070817 0.94992076]
# action means and variances at step -5: [-0.29259733 -0.16009066] [1.28824854 1.12091796]
# action statmeans and variances at step -10: [-0.12376457  0.02201626] [1. 1.]
# action statmeans and variances at step -5: [-0.12074009  0.02434649] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 16 * Episodic Reward is ==> -12.390376091003418
# action means and variances at step -10: [ 0.36688547 -0.00759463] [1.28388058 0.90510767]
# action means and variances at step -5: [-0.39661614  0.07951055] [0.52838193 1.23862021]
# action statmeans and variances at step -10: [-0.10848819  0.05247463] [1. 1.]
# action statmeans and variances at step -5: [-0.10961837  0.053488  ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 17 * Episodic Reward is ==> -12.655052185058594
# action means and variances at step -10: [0.12067645 0.21797383] [1.16565829 1.14838838]
# action means and variances at step -5: [-0.45834508  0.0592104 ] [0.78008152 0.95422081]
# action statmeans and variances at step -10: [-0.088742    0.01947096] [1. 1.]
# action statmeans and variances at step -5: [-0.09477825  0.02534318] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 18 * Episodic Reward is ==> -12.8232421875
# action means and variances at step -10: [-0.43813266 -0.17310537] [0.84138649 0.98142151]
# action means and variances at step -5: [-0.11540013  0.12387957] [0.61693507 1.28881109]
# action statmeans and variances at step -10: [-0.08161259  0.0288809 ] [1. 1.]
# action statmeans and variances at step -5: [-0.0920909   0.03303918] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 19 * Episodic Reward is ==> -12.175861358642578
# action means and variances at step -10: [-0.09943167  0.55715653] [1.28877681 1.43868456]
# action means and variances at step -5: [-0.16831042  0.17052205] [1.24057432 0.75280638]
# action statmeans and variances at step -10: [-0.14130217  0.05757323] [1. 1.]
# action statmeans and variances at step -5: [-0.14226308  0.05857499] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 20 * Episodic Reward is ==> -12.398083686828613
# action means and variances at step -10: [-0.27568628  0.0634647 ] [0.73319562 0.95715806]
# action means and variances at step -5: [-0.07181444  0.18367361] [1.28862599 1.23431583]
# action statmeans and variances at step -10: [-0.12377439  0.05729566] [1. 1.]
# action statmeans and variances at step -5: [-0.12305097  0.05931355] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 21 * Episodic Reward is ==> -12.411534309387207
# action means and variances at step -10: [-0.32327496  0.00611764] [0.8377144  1.21344622]
# action means and variances at step -5: [ 0.03285368 -0.22082424] [0.99340468 0.70495477]
# action statmeans and variances at step -10: [-0.1469991   0.04078222] [1. 1.]
# action statmeans and variances at step -5: [-0.14863253  0.03791762] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 22 * Episodic Reward is ==> -12.63693904876709
# action means and variances at step -10: [-0.17541451  0.09554029] [1.47375437 1.27470799]
# action means and variances at step -5: [-0.17751565  0.45443281] [1.15911719 0.75448733]
# action statmeans and variances at step -10: [-0.15842405  0.04424705] [1. 1.]
# action statmeans and variances at step -5: [-0.1368325   0.07474412] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 23 * Episodic Reward is ==> -12.479438781738281
# action means and variances at step -10: [-0.11503593  0.13502562] [1.04443572 0.77156368]
# action means and variances at step -5: [-0.0772626  -0.01562634] [0.79454106 1.06012468]
# action statmeans and variances at step -10: [-0.24290445  0.06325322] [1. 1.]
# action statmeans and variances at step -5: [-0.23511812  0.06075469] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 24 * Episodic Reward is ==> -12.63528060913086
# action means and variances at step -10: [-0.57298228 -0.08178898] [1.00005603 1.52190766]
# action means and variances at step -5: [-0.21515905  0.05595253] [1.10285866 0.52422966]
# action statmeans and variances at step -10: [-0.24893184  0.05966183] [1. 1.]
# action statmeans and variances at step -5: [-0.25020343  0.07261661] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 25 * Episodic Reward is ==> -13.141706466674805
# action means and variances at step -10: [-0.45386326 -0.12082785] [0.9426662  0.45792081]
# action means and variances at step -5: [-0.42859567  0.07194234] [1.09658137 1.23141833]
# action statmeans and variances at step -10: [-0.3189973  -0.00589991] [1. 1.]
# action statmeans and variances at step -5: [-0.34375942 -0.03898785] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 26 * Episodic Reward is ==> -12.893726348876953
# action means and variances at step -10: [-0.27332374 -0.03935319] [0.74361263 1.09317819]
# action means and variances at step -5: [-0.37527313 -0.04276015] [1.1805605  0.71752467]
# action statmeans and variances at step -10: [-0.35162067  0.01610158] [1. 1.]
# action statmeans and variances at step -5: [-0.35735527  0.02708414] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 27 * Episodic Reward is ==> -13.245979309082031
# action means and variances at step -10: [-0.47013005 -0.01312306] [1.14581169 1.27988926]
# action means and variances at step -5: [-0.34928114  0.26016748] [0.86294904 0.79502979]
# action statmeans and variances at step -10: [-0.48450005  0.02951988] [1. 1.]
# action statmeans and variances at step -5: [-0.48677748  0.02942569] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 28 * Episodic Reward is ==> -12.738981246948242
# action means and variances at step -10: [-0.57574503  0.13904376] [0.98516283 1.12577102]
# action means and variances at step -5: [-0.38471745 -0.11727028] [0.76491909 0.74020611]
# action statmeans and variances at step -10: [-0.45231855  0.06770212] [1. 1.]
# action statmeans and variances at step -5: [-0.45343024  0.05956253] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 29 * Episodic Reward is ==> -12.983936309814453
# action means and variances at step -10: [-0.5524713   0.11176752] [1.1481185  0.76747078]
# action means and variances at step -5: [-0.69149807  0.01821951] [1.73075892 1.05680406]
# action statmeans and variances at step -10: [-0.40572178  0.08104692] [1. 1.]
# action statmeans and variances at step -5: [-0.4096469   0.08349832] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 30 * Episodic Reward is ==> -13.2214994430542
# action means and variances at step -10: [-0.65101504 -0.01480821] [1.1129466  1.08996114]
# action means and variances at step -5: [-0.53234994  0.0656408 ] [1.04855533 1.00392103]
# action statmeans and variances at step -10: [-0.41007608 -0.01263352] [1. 1.]
# action statmeans and variances at step -5: [-0.4102184  -0.03795289] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 31 * Episodic Reward is ==> -13.297199249267578
# action means and variances at step -10: [-0.69268559  0.06919397] [0.9746197  1.23723974]
# action means and variances at step -5: [-0.706675    0.14865863] [0.53005883 0.98531647]
# action statmeans and variances at step -10: [-0.5017187   0.04620593] [1. 1.]
# action statmeans and variances at step -5: [-0.49610162  0.04712768] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 32 * Episodic Reward is ==> -13.427797317504883
# action means and variances at step -10: [-0.56256407  0.11328336] [0.89927061 0.81316709]
# action means and variances at step -5: [-0.73054698 -0.15160177] [1.2172475  1.03808446]
# action statmeans and variances at step -10: [-0.5520298   0.11045729] [1. 1.]
# action statmeans and variances at step -5: [-0.55172086  0.10807294] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 33 * Episodic Reward is ==> -13.201824188232422
# action means and variances at step -10: [-0.51139348 -0.14401149] [0.46518243 0.76408737]
# action means and variances at step -5: [-0.77142091 -0.02384103] [1.25755334 0.92017647]
# action statmeans and variances at step -10: [-0.65787125  0.11889133] [1. 1.]
# action statmeans and variances at step -5: [-0.66058695  0.11734518] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 34 * Episodic Reward is ==> -13.918878555297852
# action means and variances at step -10: [-0.66946551  0.40913242] [0.71472312 0.57407603]
# action means and variances at step -5: [-0.86461956  0.13550342] [1.17010195 0.90360402]
# action statmeans and variances at step -10: [-0.77264374  0.18799224] [1. 1.]
# action statmeans and variances at step -5: [-0.7753968  0.1863084] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 35 * Episodic Reward is ==> -13.60767936706543
# action means and variances at step -10: [-0.95601543  0.43022308] [0.85334061 0.80735254]
# action means and variances at step -5: [-0.88054247  0.42989653] [0.93436224 1.09535661]
# action statmeans and variances at step -10: [-0.69112724  0.27945128] [1. 1.]
# action statmeans and variances at step -5: [-0.69591033  0.28203392] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 36 * Episodic Reward is ==> -13.18960189819336
# action means and variances at step -10: [-0.93784239  0.43365974] [1.2968374  1.00169862]
# action means and variances at step -5: [-0.61731282  0.53882138] [0.80958611 0.83521284]
# action statmeans and variances at step -10: [-0.60164315  0.35363862] [1. 1.]
# action statmeans and variances at step -5: [-0.60198575  0.3475325 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 37 * Episodic Reward is ==> -14.334224700927734
# action means and variances at step -10: [-0.48882539  0.46183329] [1.38152165 0.93743789]
# action means and variances at step -5: [-0.77370435  0.672686  ] [0.96288979 0.83503049]
# action statmeans and variances at step -10: [-0.6396017   0.44700408] [1. 1.]
# action statmeans and variances at step -5: [-0.6441156   0.45303345] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 38 * Episodic Reward is ==> -14.234424591064453
# action means and variances at step -10: [-0.64410559  0.6984169 ] [0.85495374 0.72756297]
# action means and variances at step -5: [-0.61246483  0.21718331] [0.73018499 0.93095311]
# action statmeans and variances at step -10: [-0.6311637  0.4921512] [1. 1.]
# action statmeans and variances at step -5: [-0.6306877   0.48840785] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 39 * Episodic Reward is ==> -13.128684997558594
# action means and variances at step -10: [-0.60346607  0.32418754] [0.93343978 1.18915362]
# action means and variances at step -5: [-0.34704051  0.18080896] [0.68725935 0.67401558]
# action statmeans and variances at step -10: [-0.5129436   0.38770765] [1. 1.]
# action statmeans and variances at step -5: [-0.51804984  0.3878566 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 40 * Episodic Reward is ==> -13.579527854919434
# action means and variances at step -10: [-0.46372301  0.77942749] [0.87340651 1.0178545 ]
# action means and variances at step -5: [-0.33891529  0.32509597] [1.0319387  0.93014341]
# action statmeans and variances at step -10: [-0.52060026  0.38585693] [1. 1.]
# action statmeans and variances at step -5: [-0.5128938   0.38145107] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 41 * Episodic Reward is ==> -13.333236694335938
# action means and variances at step -10: [-0.55829829  0.36266289] [0.8387257 1.1525805]
# action means and variances at step -5: [-0.57344725  0.26997309] [1.17813552 0.95052608]
# action statmeans and variances at step -10: [-0.48418486  0.35271168] [1. 1.]
# action statmeans and variances at step -5: [-0.45832008  0.33891103] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 42 * Episodic Reward is ==> -13.362066268920898
# action means and variances at step -10: [-0.68790386  0.47808112] [0.59186028 0.95655849]
# action means and variances at step -5: [-0.57814161  0.49487334] [0.8725691 1.0451745]
# action statmeans and variances at step -10: [-0.50306785  0.35362428] [1. 1.]
# action statmeans and variances at step -5: [-0.5100132   0.35447916] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 43 * Episodic Reward is ==> -13.494016647338867
# action means and variances at step -10: [-0.92441808 -0.00932534] [1.09614549 0.7378311 ]
# action means and variances at step -5: [-0.70794454  0.13920879] [1.17481719 1.32254871]
# action statmeans and variances at step -10: [-0.5723052   0.35676822] [1. 1.]
# action statmeans and variances at step -5: [-0.56348443  0.37082243] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 44 * Episodic Reward is ==> -14.944019317626953
# action means and variances at step -10: [-0.69291199  0.61001454] [0.97443488 0.76061558]
# action means and variances at step -5: [-0.46802625  0.7047537 ] [1.02862157 0.59971821]
# action statmeans and variances at step -10: [-0.63481545  0.46513087] [1. 1.]
# action statmeans and variances at step -5: [-0.63017184  0.46382806] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 45 * Episodic Reward is ==> -13.919179916381836
# action means and variances at step -10: [-0.58623944  0.4295284 ] [1.10396154 1.61531842]
# action means and variances at step -5: [-0.76040144  0.53659415] [0.96445252 1.22470485]
# action statmeans and variances at step -10: [-0.60773647  0.40694538] [1. 1.]
# action statmeans and variances at step -5: [-0.605741   0.4046889] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 46 * Episodic Reward is ==> -13.511510848999023
# action means and variances at step -10: [-0.87108829  0.19404024] [0.66824862 1.16119802]
# action means and variances at step -5: [-0.25411981  0.39753078] [0.98079357 1.29856076]
# action statmeans and variances at step -10: [-0.5992566   0.38866013] [1. 1.]
# action statmeans and variances at step -5: [-0.5947964   0.38794765] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 47 * Episodic Reward is ==> -13.334726333618164
# action means and variances at step -10: [-0.76579298  0.26251511] [1.00578751 0.60456543]
# action means and variances at step -5: [-0.85904129  0.58619009] [0.82933426 1.37208942]
# action statmeans and variances at step -10: [-0.61003894  0.3630684 ] [1. 1.]
# action statmeans and variances at step -5: [-0.6076356   0.35592014] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 48 * Episodic Reward is ==> -14.028100967407227
# action means and variances at step -10: [-0.74683506  0.29058365] [0.79126417 1.02686603]
# action means and variances at step -5: [-0.73635344  0.55438084] [1.04359438 0.87780506]
# action statmeans and variances at step -10: [-0.6745081   0.35518336] [1. 1.]
# action statmeans and variances at step -5: [-0.6809694   0.35532624] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 49 * Episodic Reward is ==> -13.535913467407227
# action means and variances at step -10: [-0.4860206   0.39272808] [0.71386282 0.97047083]
# action means and variances at step -5: [-1.01456333  0.41365522] [0.98875071 0.8039147 ]
# action statmeans and variances at step -10: [-0.7361868   0.36462086] [1. 1.]
# action statmeans and variances at step -5: [-0.73986435  0.3647481 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 50 * Episodic Reward is ==> -14.397819519042969
# action means and variances at step -10: [-0.89761632  0.57631467] [0.8331903  1.08604102]
# action means and variances at step -5: [-0.72429843  0.28291623] [1.0269272  1.46977068]
# action statmeans and variances at step -10: [-0.62497133  0.342108  ] [1. 1.]
# action statmeans and variances at step -5: [-0.63265234  0.33931974] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 51 * Episodic Reward is ==> -13.535429954528809
# action means and variances at step -10: [-0.6460388   0.29838023] [1.06308336 1.14179473]
# action means and variances at step -5: [-0.46430097  0.16181582] [1.09880114 0.90443291]
# action statmeans and variances at step -10: [-0.5725066  0.2902736] [1. 1.]
# action statmeans and variances at step -5: [-0.57630557  0.29410768] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 52 * Episodic Reward is ==> -13.184325218200684
# action means and variances at step -10: [-0.59823896  0.08571773] [0.77344481 0.74250895]
# action means and variances at step -5: [-0.28241168  0.24873471] [0.77842589 0.82795049]
# action statmeans and variances at step -10: [-0.45773065  0.26295257] [1. 1.]
# action statmeans and variances at step -5: [-0.47538507  0.26145774] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 53 * Episodic Reward is ==> -13.082478523254395
# action means and variances at step -10: [-0.4687216  0.1175503] [0.76540072 1.06356719]
# action means and variances at step -5: [-0.38319456  0.17275365] [1.30754983 0.73706855]
# action statmeans and variances at step -10: [-0.44211876  0.23923698] [1. 1.]
# action statmeans and variances at step -5: [-0.44834223  0.24302548] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 54 * Episodic Reward is ==> -13.66558837890625
# action means and variances at step -10: [-0.42759417  0.62009134] [0.95249219 1.26245808]
# action means and variances at step -5: [-0.50493825  0.12452998] [0.67773702 1.01783137]
# action statmeans and variances at step -10: [-0.46950293  0.29506472] [1. 1.]
# action statmeans and variances at step -5: [-0.46668747  0.28756747] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 55 * Episodic Reward is ==> -13.2276029586792
# action means and variances at step -10: [-0.35534479  0.42590119] [0.98242911 0.83014414]
# action means and variances at step -5: [-0.62421576  0.22924812] [0.69713714 1.45406662]
# action statmeans and variances at step -10: [-0.44660926  0.27212605] [1. 1.]
# action statmeans and variances at step -5: [-0.44423157  0.2758283 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 56 * Episodic Reward is ==> -13.417760848999023
# action means and variances at step -10: [-0.30389967  0.2891431 ] [0.87668606 1.38432863]
# action means and variances at step -5: [-0.56354175  0.19427733] [0.95993865 1.45811131]
# action statmeans and variances at step -10: [-0.4571892   0.25060278] [1. 1.]
# action statmeans and variances at step -5: [-0.4682346   0.25065416] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 57 * Episodic Reward is ==> -13.562494277954102
# action means and variances at step -10: [-0.44269783  0.39740838] [0.89468158 1.04106173]
# action means and variances at step -5: [-0.14233226  0.22459048] [0.99434281 1.14041586]
# action statmeans and variances at step -10: [-0.5378361   0.29300177] [1. 1.]
# action statmeans and variances at step -5: [-0.53335303  0.29136464] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 58 * Episodic Reward is ==> -13.3648099899292
# action means and variances at step -10: [-0.6538005   0.52244433] [0.96821298 1.26039869]
# action means and variances at step -5: [-0.64446364  0.45060074] [1.48664393 0.798788  ]
# action statmeans and variances at step -10: [-0.56171346  0.31389835] [1. 1.]
# action statmeans and variances at step -5: [-0.5611341   0.31377438] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 59 * Episodic Reward is ==> -13.901424407958984
# action means and variances at step -10: [-0.79704982  0.34796856] [1.09460258 0.98543283]
# action means and variances at step -5: [-0.90595405  0.58139704] [0.78448162 0.87482208]
# action statmeans and variances at step -10: [-0.6142022   0.31712618] [1. 1.]
# action statmeans and variances at step -5: [-0.6267896   0.32102275] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 60 * Episodic Reward is ==> -13.887828826904297
# action means and variances at step -10: [-0.93694759  0.19173248] [0.83247625 0.93879319]
# action means and variances at step -5: [-0.97861925  0.37316872] [0.51454206 1.27203595]
# action statmeans and variances at step -10: [-0.6571771   0.37913454] [1. 1.]
# action statmeans and variances at step -5: [-0.6634335   0.38130918] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 61 * Episodic Reward is ==> -13.601398468017578
# action means and variances at step -10: [-0.93497634  0.31719287] [0.67470581 0.89744191]
# action means and variances at step -5: [-0.85806786  0.19531985] [0.87096181 0.74036588]
# action statmeans and variances at step -10: [-0.69365734  0.34194383] [1. 1.]
# action statmeans and variances at step -5: [-0.70106363  0.34606752] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 62 * Episodic Reward is ==> -14.30223274230957
# action means and variances at step -10: [-0.53853942  0.4054272 ] [0.46234155 0.87077099]
# action means and variances at step -5: [-0.93689687  0.4086766 ] [0.97553307 0.68989463]
# action statmeans and variances at step -10: [-0.6928775  0.3359704] [1. 1.]
# action statmeans and variances at step -5: [-0.6922504  0.3334847] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 63 * Episodic Reward is ==> -13.58759880065918
# action means and variances at step -10: [-0.67514305  0.30266153] [1.15181025 0.79673634]
# action means and variances at step -5: [-0.70327397  0.11246529] [0.66542662 0.8545562 ]
# action statmeans and variances at step -10: [-0.5964918   0.28263384] [1. 1.]
# action statmeans and variances at step -5: [-0.5853957   0.28096554] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 64 * Episodic Reward is ==> -13.565271377563477
# action means and variances at step -10: [-0.65719661  0.33073936] [0.76289712 0.4989375 ]
# action means and variances at step -5: [-0.71755884  0.4249314 ] [1.17381549 1.00160664]
# action statmeans and variances at step -10: [-0.5601264  0.2461369] [1. 1.]
# action statmeans and variances at step -5: [-0.5607064   0.24601254] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 65 * Episodic Reward is ==> -13.89974594116211
# action means and variances at step -10: [-0.63407914  0.33759968] [1.02684626 1.08865429]
# action means and variances at step -5: [-0.834235    0.17322974] [0.75530655 1.04910734]
# action statmeans and variances at step -10: [-0.5590624   0.22045621] [1. 1.]
# action statmeans and variances at step -5: [-0.5650147   0.22390844] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 66 * Episodic Reward is ==> -13.52607536315918
# action means and variances at step -10: [-0.63573059  0.32391372] [1.13190339 1.20250165]
# action means and variances at step -5: [-0.55570095  0.37371815] [1.35783856 1.46139249]
# action statmeans and variances at step -10: [-0.64982516  0.2448628 ] [1. 1.]
# action statmeans and variances at step -5: [-0.6487249   0.24545392] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 67 * Episodic Reward is ==> -13.577177047729492
# action means and variances at step -10: [-0.5818094   0.27395813] [1.38968975 0.96294593]
# action means and variances at step -5: [-0.66639691  0.44198412] [0.84159121 1.07049618]
# action statmeans and variances at step -10: [-0.65519476  0.28832367] [1. 1.]
# action statmeans and variances at step -5: [-0.65546274  0.29120132] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 68 * Episodic Reward is ==> -14.594264030456543
# action means and variances at step -10: [-0.63855961  0.43831948] [1.34114006 0.79515771]
# action means and variances at step -5: [-0.92130114  0.45419199] [0.94203311 0.81825609]
# action statmeans and variances at step -10: [-0.6753219   0.35055333] [1. 1.]
# action statmeans and variances at step -5: [-0.6797618  0.3508733] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 69 * Episodic Reward is ==> -13.483317375183105
# action means and variances at step -10: [-0.83149982  0.22275509] [1.33629205 1.1351354 ]
# action means and variances at step -5: [-0.65063354  0.54683947] [0.86323486 1.01644117]
# action statmeans and variances at step -10: [-0.6010761   0.32036602] [1. 1.]
# action statmeans and variances at step -5: [-0.60546446  0.3208863 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 70 * Episodic Reward is ==> -14.307003021240234
# action means and variances at step -10: [-0.79210659  0.7059803 ] [0.99208149 1.05080171]
# action means and variances at step -5: [-0.616958    0.28064918] [0.63743114 0.44837884]
# action statmeans and variances at step -10: [-0.5816953   0.34777048] [1. 1.]
# action statmeans and variances at step -5: [-0.57942146  0.35003787] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 71 * Episodic Reward is ==> -13.697620391845703
# action means and variances at step -10: [-0.8219148   0.72013235] [1.03464365 0.68769004]
# action means and variances at step -5: [-0.52153363  0.16110027] [0.67835913 0.94245603]
# action statmeans and variances at step -10: [-0.68396276  0.35811636] [1. 1.]
# action statmeans and variances at step -5: [-0.68706733  0.3568507 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 72 * Episodic Reward is ==> -14.124479293823242
# action means and variances at step -10: [-0.58651135  0.28759146] [0.61062257 0.94517264]
# action means and variances at step -5: [-0.64679963  0.60130676] [0.86717048 1.19620417]
# action statmeans and variances at step -10: [-0.6009141   0.34946314] [1. 1.]
# action statmeans and variances at step -5: [-0.6135602  0.3521108] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 73 * Episodic Reward is ==> -13.869939804077148
# action means and variances at step -10: [-0.73842653  0.1993095 ] [1.08108634 1.22458816]
# action means and variances at step -5: [-0.38826157  0.38094008] [0.63518185 1.21505841]
# action statmeans and variances at step -10: [-0.6250987   0.29442167] [1. 1.]
# ...
# action statmeans and variances at step -10: [ 0.00228285 -0.05616083] [1. 1.]
# action statmeans and variances at step -5: [ 0.00228285 -0.05616083] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4686 * Episodic Reward is ==> -12.576168060302734
# action means and variances at step -10: [-0.07480647  0.20178951] [0.74745888 0.79190681]
# action means and variances at step -5: [-0.02713887 -0.14962189] [0.94437346 0.85389897]
# action statmeans and variances at step -10: [ 0.00283038 -0.05572575] [1. 1.]
# action statmeans and variances at step -5: [ 0.00283038 -0.05572575] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4687 * Episodic Reward is ==> -12.547182083129883
# action means and variances at step -10: [-0.13101952 -0.2173931 ] [0.62557651 1.22628607]
# action means and variances at step -5: [0.00047834 0.0997623 ] [0.90848162 0.79762221]
# action statmeans and variances at step -10: [ 0.00331887 -0.05544544] [1. 1.]
# action statmeans and variances at step -5: [ 0.00331887 -0.05544544] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4688 * Episodic Reward is ==> -12.534978866577148
# action means and variances at step -10: [ 0.20167862 -0.14226742] [0.84953661 0.67209915]
# action means and variances at step -5: [ 0.07482843 -0.20714529] [1.20832531 0.77753496]
# action statmeans and variances at step -10: [ 0.00330891 -0.05540886] [1. 1.]
# action statmeans and variances at step -5: [ 0.00330891 -0.05540886] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4689 * Episodic Reward is ==> -12.192609786987305
# action means and variances at step -10: [ 0.25877805 -0.17376465] [0.74899391 1.04841232]
# action means and variances at step -5: [0.21034841 0.05945682] [1.04703681 0.79529922]
# action statmeans and variances at step -10: [ 0.00298214 -0.05428791] [1. 1.]
# action statmeans and variances at step -5: [ 0.00298214 -0.05428791] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4690 * Episodic Reward is ==> -12.833502769470215
# action means and variances at step -10: [ 0.10380209 -0.14668942] [0.8494432  1.36673178]
# action means and variances at step -5: [-0.33925738 -0.02276413] [0.79978107 0.97084211]
# action statmeans and variances at step -10: [ 0.00296785 -0.0542459 ] [1. 1.]
# action statmeans and variances at step -5: [ 0.00296785 -0.0542459 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4691 * Episodic Reward is ==> -12.657733917236328
# action means and variances at step -10: [ 0.28678014 -0.2907163 ] [0.60880431 0.73679523]
# action means and variances at step -5: [-0.13231529  0.38703791] [0.73662306 1.23783324]
# action statmeans and variances at step -10: [ 0.00159303 -0.05293675] [1. 1.]
# action statmeans and variances at step -5: [ 0.00159303 -0.05293675] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4692 * Episodic Reward is ==> -11.995519638061523
# action means and variances at step -10: [-0.16633797 -0.5284798 ] [0.8086637  0.96031525]
# action means and variances at step -5: [-0.15675305 -0.26210842] [0.62256554 1.08871032]
# action statmeans and variances at step -10: [ 0.00048325 -0.05235995] [1. 1.]
# action statmeans and variances at step -5: [ 0.00048325 -0.05235995] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4693 * Episodic Reward is ==> -12.671224594116211
# action means and variances at step -10: [-0.15717334  0.09049188] [0.94693541 0.89907536]
# action means and variances at step -5: [ 0.18399706 -0.19283835] [0.91371683 0.68099933]
# action statmeans and variances at step -10: [-0.00121365 -0.05214168] [1. 1.]
# action statmeans and variances at step -5: [-0.00121365 -0.05214168] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4694 * Episodic Reward is ==> -12.540136337280273
# action means and variances at step -10: [-0.24253464  0.16395776] [0.94974648 0.65146374]
# action means and variances at step -5: [ 0.15210588 -0.06938967] [1.7427472  0.88309697]
# action statmeans and variances at step -10: [-0.00169876 -0.05141633] [1. 1.]
# action statmeans and variances at step -5: [-0.00169876 -0.05141633] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4695 * Episodic Reward is ==> -12.43114185333252
# action means and variances at step -10: [0.22132311 0.06449063] [1.50856379 1.06570849]
# action means and variances at step -5: [ 0.30822862 -0.31770583] [0.76561666 1.22841577]
# action statmeans and variances at step -10: [-0.00137331 -0.05162913] [1. 1.]
# action statmeans and variances at step -5: [-0.00137331 -0.05162913] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4696 * Episodic Reward is ==> -12.849854469299316
# action means and variances at step -10: [0.34959198 0.25822373] [0.85121    1.10084629]
# action means and variances at step -5: [0.08331623 0.17989669] [1.34001239 0.66364623]
# action statmeans and variances at step -10: [ 1.1443950e-05 -5.1578112e-02] [1. 1.]
# action statmeans and variances at step -5: [ 1.1443950e-05 -5.1578112e-02] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4697 * Episodic Reward is ==> -12.626429557800293
# action means and variances at step -10: [0.04687977 0.05030834] [1.04027599 1.13157579]
# action means and variances at step -5: [-0.00976642  0.33604018] [0.69013559 0.95911083]
# action statmeans and variances at step -10: [ 0.00045697 -0.05146328] [1. 1.]
# action statmeans and variances at step -5: [ 0.00045697 -0.05146328] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4698 * Episodic Reward is ==> -12.122797012329102
# action means and variances at step -10: [ 0.11599245 -0.09578645] [0.87186271 1.02883333]
# action means and variances at step -5: [-0.33624508 -0.01687503] [0.89164996 1.09321602]
# action statmeans and variances at step -10: [ 0.00044632 -0.05114258] [1. 1.]
# action statmeans and variances at step -5: [ 0.00044632 -0.05114258] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4699 * Episodic Reward is ==> -12.668086051940918
# action means and variances at step -10: [-0.10922316 -0.15009345] [1.17872623 1.59340789]
# action means and variances at step -5: [-0.07773169 -0.13021851] [0.50823397 0.82472156]
# action statmeans and variances at step -10: [ 0.0021469  -0.05252933] [1. 1.]
# action statmeans and variances at step -5: [ 0.0021469  -0.05252933] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4700 * Episodic Reward is ==> -12.605865478515625
# action means and variances at step -10: [ 0.35763407 -0.15503739] [1.11927298 1.14173647]
# action means and variances at step -5: [0.04153595 0.08710281] [1.38375553 0.72894942]
# action statmeans and variances at step -10: [ 0.00289138 -0.0539254 ] [1. 1.]
# action statmeans and variances at step -5: [ 0.00289138 -0.0539254 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4701 * Episodic Reward is ==> -12.34698486328125
# action means and variances at step -10: [-0.08772534  0.06904252] [0.51381512 0.99231218]
# action means and variances at step -5: [0.09451457 0.32309995] [0.87989929 1.00447293]
# action statmeans and variances at step -10: [ 0.0034076  -0.05428133] [1. 1.]
# action statmeans and variances at step -5: [ 0.0034076  -0.05428133] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4702 * Episodic Reward is ==> -12.089404106140137
# action means and variances at step -10: [-0.07623765 -0.03124927] [0.79931866 0.91250523]
# action means and variances at step -5: [0.16298181 0.02344211] [1.15036171 0.98797155]
# action statmeans and variances at step -10: [ 0.00383858 -0.05455489] [1. 1.]
# action statmeans and variances at step -5: [ 0.00383858 -0.05455489] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4703 * Episodic Reward is ==> -12.84373664855957
# action means and variances at step -10: [0.12810917 0.12128076] [0.61508786 0.89469822]
# action means and variances at step -5: [ 0.00599269 -0.09169297] [1.34199965 1.24616733]
# action statmeans and variances at step -10: [ 0.00458285 -0.0537824 ] [1. 1.]
# action statmeans and variances at step -5: [ 0.00458285 -0.0537824 ] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4704 * Episodic Reward is ==> -12.741015434265137
# action means and variances at step -10: [-0.01096481  0.31947509] [1.02201675 1.44509605]
# action means and variances at step -5: [-0.38339971  0.01164989] [0.76629393 1.66271708]
# action statmeans and variances at step -10: [ 0.00672865 -0.05167667] [1. 1.]
# action statmeans and variances at step -5: [ 0.00672865 -0.05167667] [1. 1.]
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_84500/4169944229.py in <module>
#      16     while True:
#      17
# ---> 18         deterministic_action, means,stdevs = agent.get_action(env.unflatten_observation(prev_state),
#      19                                                return_stats=True)
#      20         action = deterministic_action #hook in order to add noise if neccessary
#
# /home/bnapp/arivkindNet/neosyclop/pg_core.py in get_action(self, states, return_stats)
#      28
#      29     def get_action(self, states, return_stats=False):
# ---> 30         outputs = self.model.predict(states)
#      31         means = outputs[:, :self.action_dim]  # first two values are means
#      32         if self.std_deviation is None:  # learn std_dev
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1774       self._distribution_strategy = original_pss_strategy
#    1775
# -> 1776     return tf_utils.sync_to_numpy_or_python_type(all_outputs)
#    1777
#    1778   def reset_metrics(self):
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#     515
# --> 516   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     517
#     518
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     510   def _to_single_numpy_or_python_type(t):
#     511     if isinstance(t, tf.Tensor):
# --> 512       x = t.numpy()
#     513       return x.item() if np.ndim(x) == 0 else x
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1092     """
#    1093     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1094     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1095     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1096
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1058   def _numpy(self):
#    1059     try:
# -> 1060       return self._numpy_internal()
#    1061     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1062       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
reward_records_=np.mean(reward_records, axis=1)

# %%
np.array(action_statmean_records).shape
# Out:
# (159980, 32, 2)

# %%
plt.plot(reward_records_)

# %%
import misc

# %%
plt.plot(reward_records_)
plt.plot(misc.smooth(reward_records_,100))
plt.grid()

# %%
# plt.plot(reward_records_)
plt.plot(misc.smooth(reward_records_,100))
plt.grid()

# %%
plt.plot(np.array(action_statmean_records).reshape([-1,8])[:,0])

# %%
plt.plot(np.array(action_statmean_records).reshape([-1,8])[:,1])

# %%
_=plt.hist(np.array(action_statmean_records).reshape([-1,8])[:,1],bins=100)
