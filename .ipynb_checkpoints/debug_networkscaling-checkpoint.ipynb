# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # or any {'0', '1', '2'}
from imagenet_dataset import get_dataset
from retina_env import RetinaEnv, calculate_retinal_filter
from rl_networks import create_actor_model, create_critic_model, policy
from rl_core import Buffer, update_target
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

import types
config = types.SimpleNamespace()
config.batch_size = 32
config.margin = 20
config.image_h = 224
config.image_w = 224
config.image_hm = config.image_h+2*config.margin
config.image_wm = config.image_w+2*config.margin
config.foveate = None
config.do_grayscale = True
config.history_length = 16
config.t_ignore = 16
config.t_max =50
config.motion_mode = 'velocity'

config.gym_mode = False
t_vec = np.linspace(0,150,16)

balanced_filter = calculate_retinal_filter(t_vec, R=1.0)
config.filter = balanced_filter.reshape([1,1,-1,1])
config.min_freq = 1
config.max_freq = 13
config.action_upper_bound = np.array([2.0, 2.0])

dataset_dir = '/home/bnapp/datasets/tensorflow_datasets/imagenet2012/5.0.0/'

def epsilon_scheduler(episode, floor_episode=200, epsilon_floor=0.1):
    if episode < floor_episode:
        return 1.-(1.-epsilon_floor)*episode/floor_episode
    else:
        return epsilon_floor

dataset = get_dataset(dataset_dir,
                                     'validation',
                                     config.batch_size,
                                     image_h = config.image_hm,
                                     image_w = config.image_wm,
                                     preprocessing='identity',
                                     rggb_mode=False,
                                     central_squeeze_and_pad_factor=-1)

env = RetinaEnv(config, image_generator=dataset)

if config.gym_mode:
    num_states = env.observation_space.shape[0]
    num_actions = env.action_space.shape[0]

    upper_bound = env.action_space.high[0]
    lower_bound = env.action_space.low[0]
else:
    num_states = env.observation_size
    num_actions = env.action_size
    upper_bound = env.action_upper_bound
    lower_bound = env.action_lower_bound

# You might want to adjust the hyperparameters
actor_lr = 0.001
critic_lr = 0.002
gamma = 0.99
tau = 0.005

buffer_capacity = 1000
batch_size = 64



# Create actor and critic networks
actor_model = create_actor_model(env.image_h, env.image_w, env.spectral_density_size, env.location_history_size, env.timestep_size, env.action_size)
critic_model = create_critic_model(env.image_h, env.image_w, env.spectral_density_size, env.location_history_size, env.timestep_size, env.action_size)

# Create target actor and critic networks
target_actor = create_actor_model(env.image_h, env.image_w, env.spectral_density_size, env.location_history_size, env.timestep_size, env.action_size)
target_critic = create_critic_model(env.image_h, env.image_w, env.spectral_density_size, env.location_history_size, env.timestep_size, env.action_size)

# Making the weights equal initially
target_actor.set_weights(actor_model.get_weights())
target_critic.set_weights(critic_model.get_weights())

# Learning rate for actor-critic models
critic_optimizer = tf.keras.optimizers.Adam(critic_lr)
actor_optimizer = tf.keras.optimizers.Adam(actor_lr)

# Experience replay buffer
buffer = Buffer(buffer_capacity, config.batch_size, num_states=num_states, num_actions=num_actions,
                state_reshape_fn=env.unflatten_observation)
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.3.0 and strictly below 2.6.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.6.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# WARNING:tensorflow:From /home/bnapp/arivkindNet/neosyclop/imagenet_dataset.py:103: map_and_batch (from tensorflow.python.data.experimental.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map(map_func, num_parallel_calls)` followed by `tf.data.Dataset.batch(batch_size, drop_remainder)`. Static tf.data optimizations will take care of using the fused implementation.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.

# %%
# Training loop
reward_records = []
epsilon_records = []
episodes = 1000
for ep in range(episodes):
    prev_state = env.reset()
    episodic_reward = 0
    epsilon = epsilon_scheduler(ep)

    while True:
        # tf_prev_state = tf.expand_dims(tf.convert_to_tensor(prev_state), 0)
        
        deterministic_action = policy(env.unflatten_observation(prev_state), actor_model, lower_bound, upper_bound)
        random_action = -2+4*np.random.uniform(size=(config.batch_size,2))

        if env.warmup_done:
            action = epsilon*random_action + (1-epsilon)*deterministic_action
        else:
            action = random_action

        # Recieve state and reward from environment
        state, reward, done, info = env.step(action)
        
        if env.warmup_done:
            buffer.record((prev_state, action, reward, state))
            episodic_reward += reward

            buffer.learn(actor_model, target_actor, critic_model, target_critic, actor_optimizer, critic_optimizer, gamma, tau)
            update_target(target_actor.variables, actor_model.variables, tau)
            update_target(target_critic.variables, critic_model.variables, tau)
        # End this episode when `done` is True
        if done:
            break

        #prev_state = state avoid assingment by reference:
        prev_state = np.copy(state)
#         print('debug action: ', action[0])

    print(f"Episode * {ep} * exploration epsilon {epsilon} * Episodic Reward is ==> {episodic_reward.numpy().mean()}")
    reward_records.append(episodic_reward.numpy().mean())
    epsilon_records.append(epsilon)
# Out:
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 0 * exploration epsilon 1.0 * Episodic Reward is ==> -13.256477355957031
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 1 * exploration epsilon 0.9955 * Episodic Reward is ==> -11.734801292419434
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 2 * exploration epsilon 0.991 * Episodic Reward is ==> -12.156299591064453
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 3 * exploration epsilon 0.9865 * Episodic Reward is ==> -11.86495590209961
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 4 * exploration epsilon 0.982 * Episodic Reward is ==> -13.73459529876709
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 5 * exploration epsilon 0.9775 * Episodic Reward is ==> -9.283138275146484
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 6 * exploration epsilon 0.973 * Episodic Reward is ==> -11.089129447937012
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 7 * exploration epsilon 0.9685 * Episodic Reward is ==> -10.391003608703613
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 8 * exploration epsilon 0.964 * Episodic Reward is ==> -12.718650817871094
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 9 * exploration epsilon 0.9595 * Episodic Reward is ==> -12.84475326538086
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 10 * exploration epsilon 0.955 * Episodic Reward is ==> -13.325061798095703
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 11 * exploration epsilon 0.9505 * Episodic Reward is ==> -13.738883972167969
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 12 * exploration epsilon 0.946 * Episodic Reward is ==> -12.06785774230957
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 13 * exploration epsilon 0.9415 * Episodic Reward is ==> -11.084770202636719
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 14 * exploration epsilon 0.937 * Episodic Reward is ==> -12.795320510864258
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 15 * exploration epsilon 0.9325 * Episodic Reward is ==> -12.306924819946289
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 16 * exploration epsilon 0.9279999999999999 * Episodic Reward is ==> -13.159770011901855
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 17 * exploration epsilon 0.9235 * Episodic Reward is ==> -12.046667098999023
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 18 * exploration epsilon 0.919 * Episodic Reward is ==> -12.017395973205566
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 19 * exploration epsilon 0.9145 * Episodic Reward is ==> -12.940804481506348
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 20 * exploration epsilon 0.91 * Episodic Reward is ==> -16.45162582397461
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 21 * exploration epsilon 0.9055 * Episodic Reward is ==> -13.761493682861328
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 22 * exploration epsilon 0.901 * Episodic Reward is ==> -12.281024932861328
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 23 * exploration epsilon 0.8965 * Episodic Reward is ==> -10.729461669921875
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 24 * exploration epsilon 0.892 * Episodic Reward is ==> -11.88027572631836
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 25 * exploration epsilon 0.8875 * Episodic Reward is ==> -12.642321586608887
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 26 * exploration epsilon 0.883 * Episodic Reward is ==> -12.214693069458008
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 27 * exploration epsilon 0.8785000000000001 * Episodic Reward is ==> -10.71999740600586
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 28 * exploration epsilon 0.874 * Episodic Reward is ==> -15.027543067932129
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 29 * exploration epsilon 0.8694999999999999 * Episodic Reward is ==> -12.178756713867188
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 30 * exploration epsilon 0.865 * Episodic Reward is ==> -12.858113288879395
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 31 * exploration epsilon 0.8605 * Episodic Reward is ==> -11.769035339355469
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 32 * exploration epsilon 0.856 * Episodic Reward is ==> -12.52218246459961
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 33 * exploration epsilon 0.8515 * Episodic Reward is ==> -11.286684036254883
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode *
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 969 * exploration epsilon 0.1 * Episodic Reward is ==> -16.448436737060547
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 970 * exploration epsilon 0.1 * Episodic Reward is ==> -17.110759735107422
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 971 * exploration epsilon 0.1 * Episodic Reward is ==> -18.018531799316406
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 972 * exploration epsilon 0.1 * Episodic Reward is ==> -15.575284957885742
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 973 * exploration epsilon 0.1 * Episodic Reward is ==> -17.832698822021484
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 974 * exploration epsilon 0.1 * Episodic Reward is ==> -15.675081253051758
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 975 * exploration epsilon 0.1 * Episodic Reward is ==> -16.402986526489258
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 976 * exploration epsilon 0.1 * Episodic Reward is ==> -16.897258758544922
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 977 * exploration epsilon 0.1 * Episodic Reward is ==> -16.258996963500977
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 978 * exploration epsilon 0.1 * Episodic Reward is ==> -17.19841194152832
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 979 * exploration epsilon 0.1 * Episodic Reward is ==> -17.23133087158203
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 980 * exploration epsilon 0.1 * Episodic Reward is ==> -16.72309112548828
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 981 * exploration epsilon 0.1 * Episodic Reward is ==> -14.719193458557129
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 982 * exploration epsilon 0.1 * Episodic Reward is ==> -18.618568420410156
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 983 * exploration epsilon 0.1 * Episodic Reward is ==> -16.867137908935547
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 984 * exploration epsilon 0.1 * Episodic Reward is ==> -17.13280487060547
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 985 * exploration epsilon 0.1 * Episodic Reward is ==> -16.24868392944336
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 986 * exploration epsilon 0.1 * Episodic Reward is ==> -16.86065673828125
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 987 * exploration epsilon 0.1 * Episodic Reward is ==> -17.151355743408203
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 988 * exploration epsilon 0.1 * Episodic Reward is ==> -17.840538024902344
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 989 * exploration epsilon 0.1 * Episodic Reward is ==> -15.872976303100586
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 990 * exploration epsilon 0.1 * Episodic Reward is ==> -17.087814331054688
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 991 * exploration epsilon 0.1 * Episodic Reward is ==> -16.39052963256836
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 992 * exploration epsilon 0.1 * Episodic Reward is ==> -15.985889434814453
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 993 * exploration epsilon 0.1 * Episodic Reward is ==> -19.241531372070312
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 994 * exploration epsilon 0.1 * Episodic Reward is ==> -19.798810958862305
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 995 * exploration epsilon 0.1 * Episodic Reward is ==> -17.4532470703125
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 996 * exploration epsilon 0.1 * Episodic Reward is ==> -17.582674026489258
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 997 * exploration epsilon 0.1 * Episodic Reward is ==> -17.387426376342773
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 998 * exploration epsilon 0.1 * Episodic Reward is ==> -18.501018524169922
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 999 * exploration epsilon 0.1 * Episodic Reward is ==> -17.536582946777344

# %%
for ep in range(200,episodes):
    prev_state = env.reset()
    episodic_reward = 0
    epsilon = epsilon_scheduler(ep)

    while True:
        # tf_prev_state = tf.expand_dims(tf.convert_to_tensor(prev_state), 0)
        
        deterministic_action = policy(env.unflatten_observation(prev_state), actor_model, lower_bound, upper_bound)
        random_action = -2+4*np.random.uniform(size=(config.batch_size,2))

        if env.warmup_done:
            action = epsilon*random_action + (1-epsilon)*deterministic_action
        else:
            action = random_action

        # Recieve state and reward from environment
        state, reward, done, info = env.step(action)
        
        if env.warmup_done:
            buffer.record((prev_state, action, reward, state))
            episodic_reward += reward

            buffer.learn(actor_model, target_actor, critic_model, target_critic, actor_optimizer, critic_optimizer, gamma, tau)
            update_target(target_actor.variables, actor_model.variables, tau)
            update_target(target_critic.variables, critic_model.variables, tau)
        # End this episode when `done` is True
        if done:
            break

        #prev_state = state avoid assingment by reference:
        prev_state = np.copy(state)
#         print('debug action: ', action[0])

    print(f"Episode * {ep} * exploration epsilon {epsilon} * Episodic Reward is ==> {episodic_reward.numpy().mean()}")
    reward_records.append(episodic_reward.numpy().mean())
    epsilon_records.append(epsilon)
# Out:
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 200 * exploration epsilon 0.1 * Episodic Reward is ==> -17.638315200805664
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 201 * exploration epsilon 0.1 * Episodic Reward is ==> -17.732337951660156
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 202 * exploration epsilon 0.1 * Episodic Reward is ==> -18.11765480041504
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 203 * exploration epsilon 0.1 * Episodic Reward is ==> -16.431602478027344
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 204 * exploration epsilon 0.1 * Episodic Reward is ==> -14.978340148925781
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 205 * exploration epsilon 0.1 * Episodic Reward is ==> -16.089698791503906
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 206 * exploration epsilon 0.1 * Episodic Reward is ==> -17.348880767822266
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 207 * exploration epsilon 0.1 * Episodic Reward is ==> -18.795930862426758
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 208 * exploration epsilon 0.1 * Episodic Reward is ==> -17.985763549804688
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 209 * exploration epsilon 0.1 * Episodic Reward is ==> -16.866840362548828
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 210 * exploration epsilon 0.1 * Episodic Reward is ==> -17.27444839477539
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 211 * exploration epsilon 0.1 * Episodic Reward is ==> -16.197036743164062
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 212 * exploration epsilon 0.1 * Episodic Reward is ==> -19.002113342285156
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 213 * exploration epsilon 0.1 * Episodic Reward is ==> -15.938217163085938
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 214 * exploration epsilon 0.1 * Episodic Reward is ==> -16.94839859008789
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 215 * exploration epsilon 0.1 * Episodic Reward is ==> -17.0657958984375
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 216 * exploration epsilon 0.1 * Episodic Reward is ==> -17.47943115234375
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 217 * exploration epsilon 0.1 * Episodic Reward is ==> -16.255470275878906
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 218 * exploration epsilon 0.1 * Episodic Reward is ==> -18.2911376953125
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 219 * exploration epsilon 0.1 * Episodic Reward is ==> -18.38573455810547
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 220 * exploration epsilon 0.1 * Episodic Reward is ==> -16.186779022216797
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 221 * exploration epsilon 0.1 * Episodic Reward is ==> -17.44382095336914
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 222 * exploration epsilon 0.1 * Episodic Reward is ==> -16.776641845703125
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 223 * exploration epsilon 0.1 * Episodic Reward is ==> -17.679119110107422
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 224 * exploration epsilon 0.1 * Episodic Reward is ==> -16.18401336669922
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 225 * exploration epsilon 0.1 * Episodic Reward is ==> -18.142072677612305
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 226 * exploration epsilon 0.1 * Episodic Reward is ==> -17.471683502197266
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 227 * exploration epsilon 0.1 * Episodic Reward is ==> -16.792724609375
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 228 * exploration epsilon 0.1 * Episodic Reward is ==> -15.77454662322998
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 229 * exploration epsilon 0.1 * Episodic Reward is ==> -15.813170433044434
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 230 * exploration epsilon 0.1 * Episodic Reward is ==> -15.346019744873047
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 231 * exploration epsilon 0.1 * Episodic Reward is ==> -16.474807739257812
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 232 * exploration epsilon 0.1 * Episodic Reward is ==> -16.667343139648438
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 233 * exploration epsilon 0.1 * Episodic Reward is ==> -14.530574798583984
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 234 * exploration epsilon 0.1 * Episodic Reward is ==> -18.08293914794922
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 235 * exploration epsilon 0.1 * Episodic Reward is ==> -16.828001022338867
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 236 * exploration epsilon 0.1 * Episodic Reward is ==> -16.153915405273438
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 237 * exploration epsilon 0.1 * Episodic Reward is ==> -17.733383178710938
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 238 * exploration epsilon 0.1 * Episodic Reward is ==> -17.34459686279297
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 239 * exploration epsilon 0.1 * Episodic Reward is ==> -15.42003345489502
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 240 * exploration epsilon 0.1 * Episodic Reward is ==> -16.507997512817383
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 241 * exploration epsilon 0.1 * Episodic Reward is ==> -19.833280563354492
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 242 * exploration epsilon 0.1 * Episodic Reward is ==> -17.588035583496094
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 243 * exploration epsilon 0.1 * Episodic Reward is ==> -16.875530242919922
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 244 * exploration epsilon 0.1 * Episodic Reward is ==> -17.283443450927734
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 245 * exploration epsilon 0.1 * Episodic Reward is ==> -17.5107479095459
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 246 * exploration epsilon 0.1 * Episodic Reward is ==> -16.14301300048828
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 247 * exploration epsilon 0.1 * Episodic Reward is ==> -17.651123046875
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 248 * exploration epsilon 0.1 * Episodic Reward is ==> -16.36247444152832
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 249 * exploration epsilon 0.1 * Episodic Reward is ==> -17.020877838134766
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 250 * exploration epsilon 0.1 * Episodic Reward is ==> -17.21007537841797
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 251 * exploration epsilon 0.1 * Episodic Reward is ==> -16.03375244140625
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 252 * exploration epsilon 0.1 * Episodic Reward is ==> -19.515289306640625
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 253 * exploration epsilon 0.1 * Episodic Reward is ==> -17.988439559936523
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 254 * exploration epsilon 0.1 * Episodic Reward is ==> -17.19542121887207
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 255 * exploration epsilon 0.1 * Episodic Reward is ==> -16.19710922241211
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 256 * exploration epsilon 0.1 * Episodic Reward is ==> -16.31958770751953
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 257 * exploration epsilon 0.1 * Episodic Reward is ==> -18.746379852294922
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 258 * exploration epsilon 0.1 * Episodic Reward is ==> -17.698436737060547
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 259 * exploration epsilon 0.1 * Episodic Reward is ==> -17.644332885742188
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 260 * exploration epsilon 0.1 * Episodic Reward is ==> -19.135908126831055
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 261 * exploration epsilon 0.1 * Episodic Reward is ==> -15.837789535522461
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 262 * exploration epsilon 0.1 * Episodic Reward is ==> -15.984970092773438
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 263 * exploration epsilon 0.1 * Episodic Reward is ==> -17.86292839050293
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 264 * exploration epsilon 0.1 * Episodic Reward is ==> -15.949420928955078
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 265 * exploration epsilon 0.1 * Episodic Reward is ==> -17.983142852783203
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 266 * exploration epsilon 0.1 * Episodic Reward is ==> -15.449195861816406
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 267 * exploration epsilon 0.1 * Episodic Reward is ==> -17.415672302246094
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 268 * exploration epsilon 0.1 * Episodic Reward is ==> -15.815765380859375
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 269 * exploration epsilon 0.1 * Episodic Reward is ==> -16.710750579833984
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 270 * exploration epsilon 0.1 * Episodic Reward is ==> -17.7746524810791
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 271 * exploration epsilon 0.1 * Episodic Reward is ==> -17.236286163330078
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 272 * exploration epsilon 0.1 * Episodic Reward is ==> -18.073850631713867
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 273 * exploration epsilon 0.1 * Episodic Reward is ==> -16.307373046875
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 274 * exploration epsilon 0.1 * Episodic Reward is ==> -17.453210830688477
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 275 * exploration epsilon 0.1 * Episodic Reward is ==> -17.288925170898438
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 276 * exploration epsilon 0.1 * Episodic Reward is ==> -15.150355339050293
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 277 * exploration epsilon 0.1 * Episodic Reward is ==> -17.790559768676758
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 278 * exploration epsilon 0.1 * Episodic Reward is ==> -19.120098114013672
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 279 * exploration epsilon 0.1 * Episodic Reward is ==> -18.192317962646484
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 280 * exploration epsilon 0.1 * Episodic Reward is ==> -19.574705123901367
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 281 * exploration epsilon 0.1 * Episodic Reward is ==> -17.693317413330078
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 282 * exploration epsilon 0.1 * Episodic Reward is ==> -17.065330505371094
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 283 * exploration epsilon 0.1 * Episodic Reward is ==> -16.856239318847656
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 284 * exploration epsilon 0.1 * Episodic Reward is ==> -18.89328384399414
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 285 * exploration epsilon 0.1 * Episodic Reward is ==> -16.04454231262207
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 286 * exploration epsilon 0.1 * Episodic Reward is ==> -16.552444458007812
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 287 * exploration epsilon 0.1 * Episodic Reward is ==> -17.164867401123047
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 288 * exploration epsilon 0.1 * Episodic Reward is ==> -17.73398208618164
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 289 * exploration epsilon 0.1 * Episodic Reward is ==> -16.950786590576172
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 290 * exploration epsilon 0.1 * Episodic Reward is ==> -15.100812911987305
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 291 * exploration epsilon 0.1 * Episodic Reward is ==> -19.045875549316406
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 292 * exploration epsilon 0.1 * Episodic Reward is ==> -16.874807357788086
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 293 * exploration epsilon 0.1 * Episodic Reward is ==> -16.251026153564453
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 294 * exploration epsilon 0.1 * Episodic Reward is ==> -16.3983097076416
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 295 * exploration epsilon 0.1 * Episodic Reward is ==> -17.066078186035156
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 296 * exploration epsilon 0.1 * Episodic Reward is ==> -17.887657165527344
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 297 * exploration epsilon 0.1 * Episodic Reward is ==> -16.672958374023438
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 298 * exploration epsilon 0.1 * Episodic Reward is ==> -17.273277282714844
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 299 * exploration epsilon 0.1 * Episodic Reward is ==> -16.97010040283203
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 300 * exploration epsilon 0.1 * Episodic Reward is ==> -16.16237449645996
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 301 * exploration epsilon 0.1 * Episodic Reward is ==> -19.17173957824707
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 302 * exploration epsilon 0.1 * Episodic Reward is ==> -16.758655548095703
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 303 * exploration epsilon 0.1 * Episodic Reward is ==> -16.68543815612793
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 304 * exploration epsilon 0.1 * Episodic Reward is ==> -18.681659698486328
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 305 * exploration epsilon 0.1 * Episodic Reward is ==> -20.459003448486328
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 306 * exploration epsilon 0.1 * Episodic Reward is ==> -15.108060836791992
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 307 * exploration epsilon 0.1 * Episodic Reward is ==> -16.89579200744629
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 308 * exploration epsilon 0.1 * Episodic Reward is ==> -19.44692611694336
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 309 * exploration epsilon 0.1 * Episodic Reward is ==> -16.699016571044922
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 310 * exploration epsilon 0.1 * Episodic Reward is ==> -18.374996185302734
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 311 * exploration epsilon 0.1 * Episodic Reward is ==> -17.100791931152344
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 312 * exploration epsilon 0.1 * Episodic Reward is ==> -18.876728057861328
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 313 * exploration epsilon 0.1 * Episodic Reward is ==> -16.277359008789062
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 314 * exploration epsilon 0.1 * Episodic Reward is ==> -17.669525146484375
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 315 * exploration epsilon 0.1 * Episodic Reward is ==> -18.973426818847656
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 316 * exploration epsilon 0.1 * Episodic Reward is ==> -18.379610061645508
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 317 * exploration epsilon 0.1 * Episodic Reward is ==> -17.331762313842773
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 318 * exploration epsilon 0.1 * Episodic Reward is ==> -16.969118118286133
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 319 * exploration epsilon 0.1 * Episodic Reward is ==> -17.47533416748047
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 320 * exploration epsilon 0.1 * Episodic Reward is ==> -18.19196891784668
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 321 * exploration epsilon 0.1 * Episodic Reward is ==> -14.944538116455078
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 322 * exploration epsilon 0.1 * Episodic Reward is ==> -17.76305389404297
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 323 * exploration epsilon 0.1 * Episodic Reward is ==> -16.47431182861328
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 324 * exploration epsilon 0.1 * Episodic Reward is ==> -17.285579681396484
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 325 * exploration epsilon 0.1 * Episodic Reward is ==> -17.17715835571289
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 326 * exploration epsilon 0.1 * Episodic Reward is ==> -18.011428833007812
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 327 * exploration epsilon 0.1 * Episodic Reward is ==> -17.933794021606445
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 328 * exploration epsilon 0.1 * Episodic Reward is ==> -16.12714385986328
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 329 * exploration epsilon 0.1 * Episodic Reward is ==> -19.113821029663086
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 330 * exploration epsilon 0.1 * Episodic Reward is ==> -17.076820373535156
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 331 * exploration epsilon 0.1 * Episodic Reward is ==> -17.62118148803711
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 332 * exploration epsilon 0.1 * Episodic Reward is ==> -15.705568313598633
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 333 * exploration epsilon 0.1 * Episodic Reward is ==> -16.54759407043457
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 334 * exploration epsilon 0.1 * Episodic Reward is ==> -16.66817855834961
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 335 * exploration epsilon 0.1 * Episodic Reward is ==> -17.044992446899414
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 336 * exploration epsilon 0.1 * Episodic Reward is ==> -17.68729019165039
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 337 * exploration epsilon 0.1 * Episodic Reward is ==> -16.680709838867188
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 338 * exploration epsilon 0.1 * Episodic Reward is ==> -15.563552856445312
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 339 * exploration epsilon 0.1 * Episodic Reward is ==> -16.857637405395508
# ...
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 953 * exploration epsilon 0.1 * Episodic Reward is ==> -16.0677490234375
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 954 * exploration epsilon 0.1 * Episodic Reward is ==> -17.357908248901367
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 955 * exploration epsilon 0.1 * Episodic Reward is ==> -16.828689575195312
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 956 * exploration epsilon 0.1 * Episodic Reward is ==> -16.225215911865234
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 957 * exploration epsilon 0.1 * Episodic Reward is ==> -16.944843292236328
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 958 * exploration epsilon 0.1 * Episodic Reward is ==> -14.994823455810547
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 959 * exploration epsilon 0.1 * Episodic Reward is ==> -18.998476028442383
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 960 * exploration epsilon 0.1 * Episodic Reward is ==> -16.555500030517578
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 961 * exploration epsilon 0.1 * Episodic Reward is ==> -15.680922508239746
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 962 * exploration epsilon 0.1 * Episodic Reward is ==> -16.73265266418457
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 963 * exploration epsilon 0.1 * Episodic Reward is ==> -18.859092712402344
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 964 * exploration epsilon 0.1 * Episodic Reward is ==> -17.03249740600586
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 965 * exploration epsilon 0.1 * Episodic Reward is ==> -17.805631637573242
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 966 * exploration epsilon 0.1 * Episodic Reward is ==> -18.791759490966797
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 967 * exploration epsilon 0.1 * Episodic Reward is ==> -17.41667938232422
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 968 * exploration epsilon 0.1 * Episodic Reward is ==> -17.261301040649414
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 969 * exploration epsilon 0.1 * Episodic Reward is ==> -18.67000961303711
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 970 * exploration epsilon 0.1 * Episodic Reward is ==> -18.89995574951172
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 971 * exploration epsilon 0.1 * Episodic Reward is ==> -16.57394027709961
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 972 * exploration epsilon 0.1 * Episodic Reward is ==> -16.663055419921875
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 973 * exploration epsilon 0.1 * Episodic Reward is ==> -16.962142944335938
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 974 * exploration epsilon 0.1 * Episodic Reward is ==> -16.728721618652344
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 975 * exploration epsilon 0.1 * Episodic Reward is ==> -18.38695526123047
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 976 * exploration epsilon 0.1 * Episodic Reward is ==> -18.016517639160156
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 977 * exploration epsilon 0.1 * Episodic Reward is ==> -18.38525390625
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 978 * exploration epsilon 0.1 * Episodic Reward is ==> -16.447690963745117
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 979 * exploration epsilon 0.1 * Episodic Reward is ==> -18.0927677154541
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 980 * exploration epsilon 0.1 * Episodic Reward is ==> -19.219341278076172
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 981 * exploration epsilon 0.1 * Episodic Reward is ==> -17.377729415893555
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 982 * exploration epsilon 0.1 * Episodic Reward is ==> -18.202789306640625
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 983 * exploration epsilon 0.1 * Episodic Reward is ==> -16.153076171875
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 984 * exploration epsilon 0.1 * Episodic Reward is ==> -17.405223846435547
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 985 * exploration epsilon 0.1 * Episodic Reward is ==> -16.845945358276367
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 986 * exploration epsilon 0.1 * Episodic Reward is ==> -16.97217559814453
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 987 * exploration epsilon 0.1 * Episodic Reward is ==> -16.579662322998047
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 988 * exploration epsilon 0.1 * Episodic Reward is ==> -17.92168426513672
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 989 * exploration epsilon 0.1 * Episodic Reward is ==> -17.627315521240234
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 990 * exploration epsilon 0.1 * Episodic Reward is ==> -17.602737426757812
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 991 * exploration epsilon 0.1 * Episodic Reward is ==> -16.644649505615234
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 992 * exploration epsilon 0.1 * Episodic Reward is ==> -16.977718353271484
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 993 * exploration epsilon 0.1 * Episodic Reward is ==> -17.421932220458984
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 994 * exploration epsilon 0.1 * Episodic Reward is ==> -17.637889862060547
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 995 * exploration epsilon 0.1 * Episodic Reward is ==> -16.2630672454834
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 996 * exploration epsilon 0.1 * Episodic Reward is ==> -18.22834014892578
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 997 * exploration epsilon 0.1 * Episodic Reward is ==> -17.442642211914062
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 998 * exploration epsilon 0.1 * Episodic Reward is ==> -18.132286071777344
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# Episode * 999 * exploration epsilon 0.1 * Episodic Reward is ==> -16.683399200439453

# %%
plt.plot(reward_records)

# %%
action
# Out:
# <tf.Tensor: shape=(32, 2), dtype=float32, numpy=
# array([[ 1.6198729, -1.715992 ],
#        [ 1.6680094, -1.9417377],
#        [ 1.9935489, -1.9624455],
#        [ 1.8585812, -1.6228706],
#        [ 1.8998163, -1.9645022],
#        [ 1.7311704, -1.638402 ],
#        [ 1.7058376, -1.7912103],
#        [ 1.7378429, -1.8910908],
#        [ 1.7505305, -1.786499 ],
#        [ 1.8733753, -1.991431 ],
#        [ 1.7513803, -1.6453198],
#        [ 1.9673947, -1.9269539],
#        [ 1.7395144, -1.7448313],
#        [ 1.8576072, -1.6979641],
#        [ 1.9041294, -1.6838057],
#        [ 1.7552176, -1.7939788],
#        [ 1.6156722, -1.8982775],
#        [ 1.9178774, -1.9865155],
#        [ 1.7188518, -1.8711321],
#        [ 1.9718823, -1.7958322],
#        [ 1.6649176, -1.7230607],
#        [ 1.9665153, -1.9733447],
#        [ 1.7495356, -1.9948655],
#        [ 1.9883292, -1.8040391],
#        [ 1.7584288, -1.9641836],
#        [ 1.9375243, -1.7597991],
#        [ 1.6015188, -1.6404076],
#        [ 1.7070915, -1.9894903],
#        [ 1.9763626, -1.6080091],
#        [ 1.6678784, -1.9489055],
#        [ 1.7878232, -1.6786087],
#        [ 1.8033621, -1.8367836]], dtype=float32)>

# %%
deterministic_action
# Out:
# <tf.Tensor: shape=(32, 2), dtype=float32, numpy=
# array([[ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.],
#        [ 2., -2.]], dtype=float32)>
