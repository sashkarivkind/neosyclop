# %%
'''batched toy environment for testing the policy gradient with batches'''
# Out:
# 'batched toy environment for testing the policy gradient with batches'

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # or any {'0', '1', '2'}
from imagenet_dataset import get_dataset
from retina_env import RetinaEnv, calculate_retinal_filter
from rl_networks import create_actor_model, create_critic_model, policy
from rl_core import Buffer, update_target
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from pg_core import GaussianPolicyAgent
from rl_networks import create_actor_network_test_v1

from test_envs import BatchMountainCarContinuous 

import types
config = types.SimpleNamespace()
config.batch_size = 32
# config.margin = 20
# config.image_h = 224
# config.image_w = 224
# config.image_hm = config.image_h+2*config.margin
# config.image_wm = config.image_w+2*config.margin
# config.foveate = None
# config.do_grayscale = True
# config.history_length = 16
# config.t_ignore = 16
# config.t_max =50
# config.motion_mode = 'velocity'
# config.use_dones = False

# config.gym_mode = False
# t_vec = np.linspace(0,150,16)

# balanced_filter = calculate_retinal_filter(t_vec, R=1.0)
# config.filter = balanced_filter.reshape([1,1,-1,1])
# config.min_freq = 1
# config.max_freq = 13
# config.action_upper_bound = np.array([2.0, 2.0])
actor_lr = 1e-4
dataset_dir = '/home/bnapp/datasets/tensorflow_datasets/imagenet2012/5.0.0/'

def epsilon_scheduler(episode, floor_episode=200, epsilon_floor=0.1):
    if episode < floor_episode:
        return 1.-(1.-epsilon_floor)*episode/floor_episode
    else:
        return epsilon_floor

# dataset = get_dataset(dataset_dir,
#                                      'validation',
#                                      config.batch_size,
#                                      image_h = config.image_hm,
#                                      image_w = config.image_wm,
#                                      preprocessing='identity',
#                                      rggb_mode=False,
#                                      central_squeeze_and_pad_factor=-1)

# # env = RetinaEnv(config, image_generator=dataset)
# env = RetinaEnv(config) #freezing on first batch
# for images,_ in dataset:
#     break
    
env =  BatchMountainCarContinuous(batch_size=config.batch_size)




# actor_model = create_actor_model(env.image_h, env.image_w,
#                                  env.spectral_density_size, env.location_history_size,
#                                  env.timestep_size, env.action_size)
actor_model = create_actor_network_test_v1((2,), 15.0)

actor_optimizer = tf.keras.optimizers.Adam(actor_lr)
actor_model.optimizer = actor_optimizer
agent = GaussianPolicyAgent(std_deviation=10.,model=actor_model,action_dim=1)
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.3.0 and strictly below 2.6.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.6.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# Training loop
reward_records = []
epsilon_records = []
action_mean_records = []
action_var_records = []
action_statmean_records = []
action_statvar_records = []
episodes = 10000
for ep in range(episodes):
    prev_states = env.reset()
    episodic_rewards = 0
    states_rec, actions_rec, rewards_rec, masks_rec = [], [], [], []

#     epsilon = epsilon_scheduler(ep, floor_episode=1000)
    masks = np.ones(config.batch_size)
    while True:

        deterministic_actions, means,stdevs = agent.get_action(prev_states,
                                               return_stats=True)
        actions = deterministic_actions #hook in order to add noise if neccessary
#         state, reward, done, info = env.step(np.reshape(action,[1]))
        states, rewards, dones, infos = env.step(actions)
        
#         if env.warmup_done:
        states_rec.append(prev_states)
        actions_rec.append(actions)
        rewards_rec.append(rewards)
        masks_rec.append(masks)
        
        episodic_rewards += rewards*masks

        #after a single done step mask is being turned off
        masks = np.logical_and(np.logical_not(dones), masks)
        #after a single done step mask is being turned off


        action_mean_records.append(deterministic_actions.mean(axis=0))
        action_var_records.append(deterministic_actions.var(axis=0))
        action_statmean_records.append(means)
        action_statvar_records.append(stdevs)
        # End this episode when `done` is True
        if np.all(dones):
            break

        prev_states = np.copy(states)
    
    agent.train(np.array(states_rec), 
                np.array(actions_rec), 
                np.array(rewards_rec), 
                masks=np.array(masks_rec,dtype=np.bool),
               max_iterations = 1000,
               loud=True)
    reward_records.append(episodic_rewards)
    print(f"Episode * {ep} * Episodic Reward is ==> {np.mean([episodic_rewards])}")
# #     print(f"Episode * {ep} * exploration epsilon {epsilon} * Episodic Reward is ==> {episodic_reward.numpy().mean()}")
#     print("action means and variances at step -10:", action_mean_records[-10],action_var_records[-10])
#     print("action means and variances at step -5:", action_mean_records[-5],action_var_records[-5])
#     print("action statmeans and variances at step -10:", action_statmean_records[-10][0],action_statvar_records[-10][0])
#     print("action statmeans and variances at step -5:", action_statmean_records[-5][0],action_statvar_records[-5][0])
#     print(episodic_rewards)
# Out:
# Training for 121 iterations with batchsize 64
# Episode * 0 * Episodic Reward is ==> -198.5625
# Training for 107 iterations with batchsize 64
# Episode * 1 * Episodic Reward is ==> -158.875
# Training for 94 iterations with batchsize 64
# Episode * 2 * Episodic Reward is ==> -123.125
# Training for 91 iterations with batchsize 64
# Episode * 3 * Episodic Reward is ==> -114.46875
# Training for 77 iterations with batchsize 64
# Episode * 4 * Episodic Reward is ==> -73.375
# Training for 54 iterations with batchsize 64
# Episode * 5 * Episodic Reward is ==> -8.625
# Training for 44 iterations with batchsize 64
# Episode * 6 * Episodic Reward is ==> 12.09375
# Training for 41 iterations with batchsize 64
# Episode * 7 * Episodic Reward is ==> 17.3125
# Training for 35 iterations with batchsize 64
# Episode * 8 * Episodic Reward is ==> 29.96875
# Training for 35 iterations with batchsize 64
# Episode * 9 * Episodic Reward is ==> 29.34375
# Training for 30 iterations with batchsize 64
# Episode * 10 * Episodic Reward is ==> 40.46875
# Training for 27 iterations with batchsize 64
# Episode * 11 * Episodic Reward is ==> 46.0625
# Training for 24 iterations with batchsize 64
# Episode * 12 * Episodic Reward is ==> 52.09375
# Training for 22 iterations with batchsize 64
# Episode * 13 * Episodic Reward is ==> 55.46875
# Training for 20 iterations with batchsize 64
# Episode * 14 * Episodic Reward is ==> 60.78125
# Training for 19 iterations with batchsize 64
# Episode * 15 * Episodic Reward is ==> 61.25
# Training for 19 iterations with batchsize 64
# Episode * 16 * Episodic Reward is ==> 62.96875
# Training for 16 iterations with batchsize 64
# Episode * 17 * Episodic Reward is ==> 67.5
# Training for 18 iterations with batchsize 64
# Episode * 18 * Episodic Reward is ==> 63.03125
# Training for 16 iterations with batchsize 64
# Episode * 19 * Episodic Reward is ==> 67.3125
# Training for 16 iterations with batchsize 64
# Episode * 20 * Episodic Reward is ==> 67.625
# Training for 14 iterations with batchsize 64
# Episode * 21 * Episodic Reward is ==> 71.46875
# Training for 13 iterations with batchsize 64
# Episode * 22 * Episodic Reward is ==> 73.625
# Training for 14 iterations with batchsize 64
# Episode * 23 * Episodic Reward is ==> 71.71875
# Training for 14 iterations with batchsize 64
# Episode * 24 * Episodic Reward is ==> 72.34375
# Training for 13 iterations with batchsize 64
# Episode * 25 * Episodic Reward is ==> 74.125
# Training for 14 iterations with batchsize 64
# Episode * 26 * Episodic Reward is ==> 73.0
# Training for 13 iterations with batchsize 64
# Episode * 27 * Episodic Reward is ==> 73.9375
# Training for 13 iterations with batchsize 64
# Episode * 28 * Episodic Reward is ==> 74.875
# Training for 13 iterations with batchsize 64
# Episode * 29 * Episodic Reward is ==> 73.625
# Training for 15 iterations with batchsize 64
# Episode * 30 * Episodic Reward is ==> 69.96875
# Training for 12 iterations with batchsize 64
# Episode * 31 * Episodic Reward is ==> 75.4375
# Training for 13 iterations with batchsize 64
# Episode * 32 * Episodic Reward is ==> 74.25
# Training for 12 iterations with batchsize 64
# Episode * 33 * Episodic Reward is ==> 75.1875
# Training for 12 iterations with batchsize 64
# Episode * 34 * Episodic Reward is ==> 76.40625
# Training for 12 iterations with batchsize 64
# Episode * 35 * Episodic Reward is ==> 75.40625
# Training for 14 iterations with batchsize 64
# Episode * 36 * Episodic Reward is ==> 72.46875
# Training for 12 iterations with batchsize 64
# Episode * 37 * Episodic Reward is ==> 76.875
# Training for 13 iterations with batchsize 64
# Episode * 38 * Episodic Reward is ==> 74.96875
# Training for 14 iterations with batchsize 64
# Episode * 39 * Episodic Reward is ==> 72.84375
# Training for 11 iterations with batchsize 64
# Episode * 40 * Episodic Reward is ==> 77.1875
# Training for 11 iterations with batchsize 64
# Episode * 41 * Episodic Reward is ==> 77.0625
# Training for 12 iterations with batchsize 64
# Episode * 42 * Episodic Reward is ==> 76.03125
# Training for 11 iterations with batchsize 64
# Episode * 43 * Episodic Reward is ==> 77.40625
# Training for 11 iterations with batchsize 64
# Episode * 44 * Episodic Reward is ==> 77.65625
# Training for 10 iterations with batchsize 64
# Episode * 45 * Episodic Reward is ==> 79.3125
# Training for 11 iterations with batchsize 64
# Episode * 46 * Episodic Reward is ==> 78.25
# Training for 11 iterations with batchsize 64
# Episode * 47 * Episodic Reward is ==> 78.28125
# Training for 11 iterations with batchsize 64
# Episode * 48 * Episodic Reward is ==> 78.15625
# Training for 11 iterations with batchsize 64
# Episode * 49 * Episodic Reward is ==> 78.375
# Training for 11 iterations with batchsize 64
# Episode * 50 * Episodic Reward is ==> 78.03125
# Training for 11 iterations with batchsize 64
# Episode * 51 * Episodic Reward is ==> 78.4375
# Training for 11 iterations with batchsize 64
# Episode * 52 * Episodic Reward is ==> 77.5
# Training for 11 iterations with batchsize 64
# Episode * 53 * Episodic Reward is ==> 78.09375
# Training for 11 iterations with batchsize 64
# Episode * 54 * Episodic Reward is ==> 78.03125
# Training for 11 iterations with batchsize 64
# Episode * 55 * Episodic Reward is ==> 78.34375
# Training for 11 iterations with batchsize 64
# Episode * 56 * Episodic Reward is ==> 78.375
# Training for 11 iterations with batchsize 64
# Episode * 57 * Episodic Reward is ==> 77.65625
# Training for 11 iterations with batchsize 64
# Episode * 58 * Episodic Reward is ==> 78.71875
# Training for 10 iterations with batchsize 64
# Episode * 59 * Episodic Reward is ==> 79.5
# Training for 11 iterations with batchsize 64
# Episode * 60 * Episodic Reward is ==> 78.59375
# Training for 11 iterations with batchsize 64
# Episode * 61 * Episodic Reward is ==> 78.53125
# Training for 11 iterations with batchsize 64
# Episode * 62 * Episodic Reward is ==> 78.75
# Training for 11 iterations with batchsize 64
# Episode * 63 * Episodic Reward is ==> 78.8125
# Training for 10 iterations with batchsize 64
# Episode * 64 * Episodic Reward is ==> 79.28125
# Training for 10 iterations with batchsize 64
# Episode * 65 * Episodic Reward is ==> 80.0625
# Training for 10 iterations with batchsize 64
# Episode * 66 * Episodic Reward is ==> 79.125
# Training for 10 iterations with batchsize 64
# Episode * 67 * Episodic Reward is ==> 80.0
# Training for 10 iterations with batchsize 64
# Episode * 68 * Episodic Reward is ==> 80.3125
# Training for 10 iterations with batchsize 64
# Episode * 69 * Episodic Reward is ==> 80.5625
# Training for 10 iterations with batchsize 64
# Episode * 70 * Episodic Reward is ==> 79.6875
# Training for 10 iterations with batchsize 64
# Episode * 71 * Episodic Reward is ==> 79.84375
# Training for 10 iterations with batchsize 64
# Episode * 72 * Episodic Reward is ==> 79.15625
# Training for 10 iterations with batchsize 64
# Episode * 73 * Episodic Reward is ==> 79.25
# Training for 10 iterations with batchsize 64
# Episode * 74 * Episodic Reward is ==> 79.90625
# Training for 10 iterations with batchsize 64
# Episode * 75 * Episodic Reward is ==> 80.8125
# Training for 10 iterations with batchsize 64
# Episode * 76 * Episodic Reward is ==> 80.125
# Training for 10 iterations with batchsize 64
# Episode * 77 * Episodic Reward is ==> 79.28125
# Training for 10 iterations with batchsize 64
# Episode * 78 * Episodic Reward is ==> 80.75
# Training for 10 iterations with batchsize 64
# Episode * 79 * Episodic Reward is ==> 81.0
# Training for 10 iterations with batchsize 64
# Episode * 80 * Episodic Reward is ==> 80.21875
# Training for 10 iterations with batchsize 64
# Episode * 81 * Episodic Reward is ==> 79.59375
# Training for 9 iterations with batchsize 64
# Episode * 82 * Episodic Reward is ==> 81.40625
# Training for 10 iterations with batchsize 64
# Episode * 83 * Episodic Reward is ==> 80.84375
# Training for 10 iterations with batchsize 64
# Episode * 84 * Episodic Reward is ==> 80.71875
# Training for 10 iterations with batchsize 64
# Episode * 85 * Episodic Reward is ==> 80.875
# Training for 10 iterations with batchsize 64
# Episode * 86 * Episodic Reward is ==> 80.0
# Training for 10 iterations with batchsize 64
# Episode * 87 * Episodic Reward is ==> 80.65625
# Training for 10 iterations with batchsize 64
# Episode * 88 * Episodic Reward is ==> 80.6875
# Training for 9 iterations with batchsize 64
# Episode * 89 * Episodic Reward is ==> 81.0625
# Training for 10 iterations with batchsize 64
# Episode * 90 * Episodic Reward is ==> 80.96875
# Training for 9 iterations with batchsize 64
# Episode * 91 * Episodic Reward is ==> 81.03125
# Training for 10 iterations with batchsize 64
# Episode * 92 * Episodic Reward is ==> 80.6875
# Training for 9 iterations with batchsize 64
# Episode * 93 * Episodic Reward is ==> 81.21875
# Training for 9 iterations with batchsize 64
# Episode * 94 * Episodic Reward is ==> 81.0625
# Training for 9 iterations with batchsize 64
# Episode * 95 * Episodic Reward is ==> 81.03125
# Training for 10 iterations with batchsize 64
# Episode * 96 * Episodic Reward is ==> 80.78125
# Training for 10 iterations with batchsize 64
# Episode * 97 * Episodic Reward is ==> 80.90625
# Training for 9 iterations with batchsize 64
# Episode * 98 * Episodic Reward is ==> 81.15625
# Training for 10 iterations with batchsize 64
# Episode * 99 * Episodic Reward is ==> 80.84375
# Training for 9 iterations with batchsize 64
# Episode * 100 * Episodic Reward is ==> 81.96875
# Training for 9 iterations with batchsize 64
# Episode * 101 * Episodic Reward is ==> 81.15625
# Training for 9 iterations with batchsize 64
# Episode * 102 * Episodic Reward is ==> 81.4375
# Training for 9 iterations with batchsize 64
# Episode * 103 * Episodic Reward is ==> 81.78125
# Training for 9 iterations with batchsize 64
# Episode * 104 * Episodic Reward is ==> 81.5
# Training for 10 iterations with batchsize 64
# Episode * 105 * Episodic Reward is ==> 80.53125
# Training for 9 iterations with batchsize 64
# Episode * 106 * Episodic Reward is ==> 81.75
# Training for 9 iterations with batchsize 64
# Episode * 107 * Episodic Reward is ==> 81.21875
# Training for 9 iterations with batchsize 64
# Episode * 108 * Episodic Reward is ==> 81.21875
# Training for 9 iterations with batchsize 64
# Episode * 109 * Episodic Reward is ==> 81.625
# Training for 9 iterations with batchsize 64
# Episode * 110 * Episodic Reward is ==> 81.3125
# Training for 10 iterations with batchsize 64
# Episode * 111 * Episodic Reward is ==> 80.8125
# Training for 9 iterations with batchsize 64
# Episode * 112 * Episodic Reward is ==> 82.5
# Training for 9 iterations with batchsize 64
# Episode * 113 * Episodic Reward is ==> 81.78125
# Training for 9 iterations with batchsize 64
# Episode * 114 * Episodic Reward is ==> 81.90625
# Training for 9 iterations with batchsize 64
# Episode * 115 * Episodic Reward is ==> 82.125
# Training for 9 iterations with batchsize 64
# Episode * 116 * Episodic Reward is ==> 81.8125
# Training for 9 iterations with batchsize 64
# Episode * 117 * Episodic Reward is ==> 81.9375
# Training for 9 iterations with batchsize 64
# Episode * 118 * Episodic Reward is ==> 81.53125
# Training for 9 iterations with batchsize 64
# Episode * 119 * Episodic Reward is ==> 81.96875
# Training for 9 iterations with batchsize 64
# Episode * 120 * Episodic Reward is ==> 82.0625
# Training for 9 iterations with batchsize 64
# Episode * 121 * Episodic Reward is ==> 82.3125
# Training for 9 iterations with batchsize 64
# Episode * 122 * Episodic Reward is ==> 81.78125
# Training for 9 iterations with batchsize 64
# Episode * 123 * Episodic Reward is ==> 82.0
# Training for 9 iterations with batchsize 64
# Episode * 124 * Episodic Reward is ==> 81.8125
# Training for 9 iterations with batchsize 64
# Episode * 125 * Episodic Reward is ==> 82.34375
# Training for 9 iterations with batchsize 64
# Episode * 126 * Episodic Reward is ==> 81.5625
# Training for 9 iterations with batchsize 64
# Episode * 127 * Episodic Reward is ==> 81.9375
# Training for 9 iterations with batchsize 64
# Episode * 128 * Episodic Reward is ==> 82.40625
# Training for 9 iterations with batchsize 64
# Episode * 129 * Episodic Reward is ==> 82.125
# Training for 9 iterations with batchsize 64
# Episode * 130 * Episodic Reward is ==> 82.25
# Training for 9 iterations with batchsize 64
# Episode * 131 * Episodic Reward is ==> 81.6875
# Training for 9 iterations with batchsize 64
# Episode * 132 * Episodic Reward is ==> 82.59375
# Training for 9 iterations with batchsize 64
# Episode * 133 * Episodic Reward is ==> 82.5
# Training for 9 iterations with batchsize 64
# Episode * 134 * Episodic Reward is ==> 81.75
# Training for 9 iterations with batchsize 64
# Episode * 135 * Episodic Reward is ==> 82.25
# Training for 9 iterations with batchsize 64
# Episode * 136 * Episodic Reward is ==> 81.90625
# Training for 9 iterations with batchsize 64
# Episode * 137 * Episodic Reward is ==> 82.15625
# Training for 9 iterations with batchsize 64
# Episode * 138 * Episodic Reward is ==> 82.28125
# Training for 9 iterations with batchsize 64
# Episode * 139 * Episodic Reward is ==> 82.375
# Training for 9 iterations with batchsize 64
# Episode * 140 * Episodic Reward is ==> 82.78125
# Training for 9 iterations with batchsize 64
# Episode * 141 * Episodic Reward is ==> 81.5
# Training for 9 iterations with batchsize 64
# Episode * 142 * Episodic Reward is ==> 81.6875
# Training for 9 iterations with batchsize 64
# Episode * 143 * Episodic Reward is ==> 82.4375
# Training for 9 iterations with batchsize 64
# Episode * 144 * Episodic Reward is ==> 82.4375
# Training for 9 iterations with batchsize 64
# Episode * 145 * Episodic Reward is ==> 81.625
# Training for 9 iterations with batchsize 64
# Episode * 146 * Episodic Reward is ==> 82.5625
# Training for 9 iterations with batchsize 64
# Episode * 147 * Episodic Reward is ==> 81.90625
# Training for 9 iterations with batchsize 64
# Episode * 148 * Episodic Reward is ==> 82.65625
# Training for 9 iterations with batchsize 64
# Episode * 149 * Episodic Reward is ==> 82.28125
# Training for 9 iterations with batchsize 64
# Episode * 150 * Episodic Reward is ==> 82.25
# Training for 9 iterations with batchsize 64
# Episode * 151 * Episodic Reward is ==> 82.78125
# Training for 9 iterations with batchsize 64
# Episode * 152 * Episodic Reward is ==> 82.46875
# Training for 9 iterations with batchsize 64
# Episode * 153 * Episodic Reward is ==> 82.59375
# Training for 9 iterations with batchsize 64
# Episode * 154 * Episodic Reward is ==> 82.8125
# Training for 9 iterations with batchsize 64
# Episode * 155 * Episodic Reward is ==> 82.375
# Training for 9 iterations with batchsize 64
# Episode * 156 * Episodic Reward is ==> 82.75
# Training for 9 iterations with batchsize 64
# Episode * 157 * Episodic Reward is ==> 82.65625
# Training for 9 iterations with batchsize 64
# Episode * 158 * Episodic Reward is ==> 82.375
# Training for 9 iterations with batchsize 64
# Episode * 159 * Episodic Reward is ==> 82.4375
# Training for 9 iterations with batchsize 64
# Episode * 160 * Episodic Reward is ==> 82.8125
# Training for 9 iterations with batchsize 64
# Episode * 161 * Episodic Reward is ==> 82.0
# Training for 9 iterations with batchsize 64
# Episode * 162 * Episodic Reward is ==> 81.59375
# Training for 9 iterations with batchsize 64
# Episode * 163 * Episodic Reward is ==> 83.0
# Training for 9 iterations with batchsize 64
# Episode * 164 * Episodic Reward is ==> 82.0
# Training for 9 iterations with batchsize 64
# Episode * 165 * Episodic Reward is ==> 82.78125
# Training for 8 iterations with batchsize 64
# Episode * 166 * Episodic Reward is ==> 83.03125
# Training for 9 iterations with batchsize 64
# Episode * 167 * Episodic Reward is ==> 82.71875
# Training for 9 iterations with batchsize 64
# Episode * 168 * Episodic Reward is ==> 82.84375
# Training for 9 iterations with batchsize 64
# Episode * 169 * Episodic Reward is ==> 83.0
# Training for 9 iterations with batchsize 64
# Episode * 170 * Episodic Reward is ==> 82.46875
# Training for 9 iterations with batchsize 64
# Episode * 171 * Episodic Reward is ==> 82.4375
# Training for 9 iterations with batchsize 64
# Episode * 172 * Episodic Reward is ==> 82.84375
# Training for 9 iterations with batchsize 64
# Episode * 173 * Episodic Reward is ==> 82.53125
# Training for 9 iterations with batchsize 64
# Episode * 174 * Episodic Reward is ==> 82.5625
# Training for 9 iterations with batchsize 64
# Episode * 175 * Episodic Reward is ==> 82.71875
# Training for 9 iterations with batchsize 64
# Episode * 176 * Episodic Reward is ==> 82.46875
# Training for 8 iterations with batchsize 64
# Episode * 177 * Episodic Reward is ==> 83.03125
# Training for 9 iterations with batchsize 64
# Episode * 178 * Episodic Reward is ==> 82.65625
# Training for 9 iterations with batchsize 64
# Episode * 179 * Episodic Reward is ==> 82.78125
# Training for 9 iterations with batchsize 64
# Episode * 180 * Episodic Reward is ==> 82.0
# Training for 9 iterations with batchsize 64
# Episode * 181 * Episodic Reward is ==> 82.8125
# Training for 9 iterations with batchsize 64
# Episode * 182 * Episodic Reward is ==> 82.15625
# Training for 9 iterations with batchsize 64
# Episode * 183 * Episodic Reward is ==> 82.59375
# Training for 9 iterations with batchsize 64
# Episode * 184 * Episodic Reward is ==> 82.875
# Training for 9 iterations with batchsize 64
# Episode * 185 * Episodic Reward is ==> 82.9375
# Training for 8 iterations with batchsize 64
# Episode * 186 * Episodic Reward is ==> 83.03125
# Training for 8 iterations with batchsize 64
# Episode * 187 * Episodic Reward is ==> 83.03125
# Training for 9 iterations with batchsize 64
# Episode * 188 * Episodic Reward is ==> 82.6875
# Training for 8 iterations with batchsize 64
# Episode * 189 * Episodic Reward is ==> 83.125
# Training for 9 iterations with batchsize 64
# Episode * 190 * Episodic Reward is ==> 82.875
# Training for 8 iterations with batchsize 64
# Episode * 191 * Episodic Reward is ==> 83.125
# Training for 9 iterations with batchsize 64
# Episode * 192 * Episodic Reward is ==> 82.875
# Training for 8 iterations with batchsize 64
# Episode * 193 * Episodic Reward is ==> 83.28125
# Training for 9 iterations with batchsize 64
# Episode * 194 * Episodic Reward is ==> 82.96875
# Training for 8 iterations with batchsize 64
# Episode * 195 * Episodic Reward is ==> 83.28125
# Training for 9 iterations with batchsize 64
# Episode * 196 * Episodic Reward is ==> 83.0
# Training for 8 iterations with batchsize 64
# Episode * 197 * Episodic Reward is ==> 83.03125
# Training for 9 iterations with batchsize 64
# Episode * 198 * Episodic Reward is ==> 82.78125
# Training for 8 iterations with batchsize 64
# Episode * 199 * Episodic Reward is ==> 83.15625
# Training for 9 iterations with batchsize 64
# Episode * 200 * Episodic Reward is ==> 82.59375
# Training for 8 iterations with batchsize 64
# Episode * 201 * Episodic Reward is ==> 83.0625
# Training for 9 iterations with batchsize 64
# Episode * 202 * Episodic Reward is ==> 82.59375
# Training for 8 iterations with batchsize 64
# Episode * 203 * Episodic Reward is ==> 83.1875
# Training for 8 iterations with batchsize 64
# Episode * 204 * Episodic Reward is ==> 83.25
# Training for 9 iterations with batchsize 64
# Episode * 205 * Episodic Reward is ==> 82.25
# Training for 8 iterations with batchsize 64
# Episode * 206 * Episodic Reward is ==> 83.03125
# Training for 9 iterations with batchsize 64
# Episode * 207 * Episodic Reward is ==> 82.625
# Training for 8 iterations with batchsize 64
# Episode * 208 * Episodic Reward is ==> 83.5
# Training for 8 iterations with batchsize 64
# Episode * 209 * Episodic Reward is ==> 83.28125
# Training for 9 iterations with batchsize 64
# Episode * 210 * Episodic Reward is ==> 82.65625
# Training for 9 iterations with batchsize 64
# Episode * 211 * Episodic Reward is ==> 83.0
# Training for 9 iterations with batchsize 64
# Episode * 212 * Episodic Reward is ==> 82.75
# Training for 8 iterations with batchsize 64
# Episode * 213 * Episodic Reward is ==> 83.1875
# Training for 9 iterations with batchsize 64
# Episode * 214 * Episodic Reward is ==> 82.9375
# Training for 8 iterations with batchsize 64
# Episode * 215 * Episodic Reward is ==> 83.5625
# Training for 8 iterations with batchsize 64
# Episode * 216 * Episodic Reward is ==> 83.0625
# Training for 9 iterations with batchsize 64
# Episode * 217 * Episodic Reward is ==> 82.78125
# Training for 9 iterations with batchsize 64
# Episode * 218 * Episodic Reward is ==> 82.96875
# Training for 8 iterations with batchsize 64
# Episode * 219 * Episodic Reward is ==> 83.125
# Training for 9 iterations with batchsize 64
# Episode * 220 * Episodic Reward is ==> 82.625
# Training for 8 iterations with batchsize 64
# Episode * 221 * Episodic Reward is ==> 83.46875
# Training for 8 iterations with batchsize 64
# Episode * 222 * Episodic Reward is ==> 83.25
# Training for 8 iterations with batchsize 64
# Episode * 223 * Episodic Reward is ==> 83.1875
# Training for 8 iterations with batchsize 64
# Episode * 224 * Episodic Reward is ==> 83.21875
# Training for 8 iterations with batchsize 64
# Episode * 225 * Episodic Reward is ==> 83.5
# Training for 8 iterations with batchsize 64
# Episode * 226 * Episodic Reward is ==> 83.15625
# Training for 8 iterations with batchsize 64
# Episode * 227 * Episodic Reward is ==> 83.03125
# Training for 9 iterations with batchsize 64
# Episode * 228 * Episodic Reward is ==> 82.65625
# Training for 9 iterations with batchsize 64
# Episode * 229 * Episodic Reward is ==> 82.8125
# Training for 9 iterations with batchsize 64
# Episode * 230 * Episodic Reward is ==> 82.9375
# Training for 9 iterations with batchsize 64
# Episode * 231 * Episodic Reward is ==> 82.78125
# Training for 8 iterations with batchsize 64
# Episode * 232 * Episodic Reward is ==> 83.28125
# Training for 8 iterations with batchsize 64
# Episode * 233 * Episodic Reward is ==> 83.03125
# Training for 8 iterations with batchsize 64
# Episode * 234 * Episodic Reward is ==> 83.375
# Training for 8 iterations with batchsize 64
# Episode * 235 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 236 * Episodic Reward is ==> 83.34375
# Training for 8 iterations with batchsize 64
# Episode * 237 * Episodic Reward is ==> 83.09375
# Training for 8 iterations with batchsize 64
# Episode * 238 * Episodic Reward is ==> 83.46875
# Training for 9 iterations with batchsize 64
# Episode * 239 * Episodic Reward is ==> 83.0
# Training for 9 iterations with batchsize 64
# Episode * 240 * Episodic Reward is ==> 82.625
# Training for 8 iterations with batchsize 64
# Episode * 241 * Episodic Reward is ==> 83.0625
# Training for 8 iterations with batchsize 64
# Episode * 242 * Episodic Reward is ==> 83.65625
# Training for 8 iterations with batchsize 64
# Episode * 243 * Episodic Reward is ==> 83.03125
# Training for 8 iterations with batchsize 64
# Episode * 244 * Episodic Reward is ==> 83.4375
# Training for 8 iterations with batchsize 64
# Episode * 245 * Episodic Reward is ==> 83.125
# Training for 8 iterations with batchsize 64
# Episode * 246 * Episodic Reward is ==> 83.28125
# Training for 9 iterations with batchsize 64
# Episode * 247 * Episodic Reward is ==> 82.71875
# Training for 8 iterations with batchsize 64
# Episode * 248 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 249 * Episodic Reward is ==> 83.59375
# Training for 8 iterations with batchsize 64
# Episode * 250 * Episodic Reward is ==> 83.3125
# Training for 9 iterations with batchsize 64
# Episode * 251 * Episodic Reward is ==> 82.75
# Training for 9 iterations with batchsize 64
# Episode * 252 * Episodic Reward is ==> 82.96875
# Training for 8 iterations with batchsize 64
# Episode * 253 * Episodic Reward is ==> 83.15625
# Training for 8 iterations with batchsize 64
# Episode * 254 * Episodic Reward is ==> 83.125
# Training for 8 iterations with batchsize 64
# Episode * 255 * Episodic Reward is ==> 83.46875
# Training for 8 iterations with batchsize 64
# Episode * 256 * Episodic Reward is ==> 83.1875
# Training for 8 iterations with batchsize 64
# Episode * 257 * Episodic Reward is ==> 83.625
# Training for 8 iterations with batchsize 64
# Episode * 258 * Episodic Reward is ==> 83.40625
# Training for 8 iterations with batchsize 64
# Episode * 259 * Episodic Reward is ==> 83.53125
# Training for 8 iterations with batchsize 64
# Episode * 260 * Episodic Reward is ==> 83.625
# Training for 8 iterations with batchsize 64
# Episode * 261 * Episodic Reward is ==> 83.375
# Training for 8 iterations with batchsize 64
# Episode * 262 * Episodic Reward is ==> 83.03125
# Training for 8 iterations with batchsize 64
# Episode * 263 * Episodic Reward is ==> 83.5
# Training for 8 iterations with batchsize 64
# Episode * 264 * Episodic Reward is ==> 83.5625
# Training for 8 iterations with batchsize 64
# Episode * 265 * Episodic Reward is ==> 83.34375
# Training for 8 iterations with batchsize 64
# Episode * 266 * Episodic Reward is ==> 83.34375
# Training for 8 iterations with batchsize 64
# Episode * 267 * Episodic Reward is ==> 83.4375
# Training for 8 iterations with batchsize 64
# Episode * 268 * Episodic Reward is ==> 83.3125
# Training for 8 iterations with batchsize 64
# Episode * 269 * Episodic Reward is ==> 83.21875
# Training for 8 iterations with batchsize 64
# Episode * 270 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 271 * Episodic Reward is ==> 83.15625
# Training for 8 iterations with batchsize 64
# Episode * 272 * Episodic Reward is ==> 83.4375
# Training for 8 iterations with batchsize 64
# Episode * 273 * Episodic Reward is ==> 83.3125
# Training for 8 iterations with batchsize 64
# Episode * 274 * Episodic Reward is ==> 83.625
# Training for 8 iterations with batchsize 64
# Episode * 275 * Episodic Reward is ==> 83.34375
# Training for 8 iterations with batchsize 64
# Episode * 276 * Episodic Reward is ==> 83.3125
# Training for 8 iterations with batchsize 64
# Episode * 277 * Episodic Reward is ==> 83.03125
# Training for 9 iterations with batchsize 64
# Episode * 278 * Episodic Reward is ==> 83.0
# Training for 8 iterations with batchsize 64
# Episode * 279 * Episodic Reward is ==> 83.1875
# Training for 8 iterations with batchsize 64
# Episode * 280 * Episodic Reward is ==> 83.65625
# Training for 8 iterations with batchsize 64
# Episode * 281 * Episodic Reward is ==> 83.25
# Training for 8 iterations with batchsize 64
# Episode * 282 * Episodic Reward is ==> 83.46875
# Training for 8 iterations with batchsize 64
# Episode * 283 * Episodic Reward is ==> 83.4375
# Training for 8 iterations with batchsize 64
# Episode * 284 * Episodic Reward is ==> 83.5
# Training for 8 iterations with batchsize 64
# Episode * 285 * Episodic Reward is ==> 83.03125
# Training for 8 iterations with batchsize 64
# Episode * 286 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 287 * Episodic Reward is ==> 83.625
# Training for 8 iterations with batchsize 64
# Episode * 288 * Episodic Reward is ==> 83.5
# Training for 8 iterations with batchsize 64
# Episode * 289 * Episodic Reward is ==> 83.1875
# Training for 8 iterations with batchsize 64
# Episode * 290 * Episodic Reward is ==> 83.3125
# Training for 8 iterations with batchsize 64
# Episode * 291 * Episodic Reward is ==> 83.5
# Training for 8 iterations with batchsize 64
# Episode * 292 * Episodic Reward is ==> 83.25
# Training for 8 iterations with batchsize 64
# Episode * 293 * Episodic Reward is ==> 83.5
# Training for 8 iterations with batchsize 64
# Episode * 294 * Episodic Reward is ==> 83.34375
# Training for 8 iterations with batchsize 64
# Episode * 295 * Episodic Reward is ==> 83.46875
# Training for 8 iterations with batchsize 64
# Episode * 296 * Episodic Reward is ==> 83.4375
# Training for 8 iterations with batchsize 64
# Episode * 297 * Episodic Reward is ==> 83.3125
# Training for 8 iterations with batchsize 64
# Episode * 298 * Episodic Reward is ==> 83.46875
# Training for 8 iterations with batchsize 64
# Episode * 299 * Episodic Reward is ==> 83.875
# Training for 8 iterations with batchsize 64
# Episode * 300 * Episodic Reward is ==> 83.3125
# Training for 8 iterations with batchsize 64
# Episode * 301 * Episodic Reward is ==> 83.5
# Training for 8 iterations with batchsize 64
# Episode * 302 * Episodic Reward is ==> 83.28125
# Training for 8 iterations with batchsize 64
# Episode * 303 * Episodic Reward is ==> 83.1875
# Training for 8 iterations with batchsize 64
# Episode * 304 * Episodic Reward is ==> 84.0
# Training for 8 iterations with batchsize 64
# Episode * 305 * Episodic Reward is ==> 83.1875
# Training for 8 iterations with batchsize 64
# Episode * 306 * Episodic Reward is ==> 83.4375
# Training for 8 iterations with batchsize 64
# Episode * 307 * Episodic Reward is ==> 83.65625
# Training for 8 iterations with batchsize 64
# Episode * 308 * Episodic Reward is ==> 83.28125
# Training for 8 iterations with batchsize 64
# Episode * 309 * Episodic Reward is ==> 83.46875
# Training for 9 iterations with batchsize 64
# Episode * 310 * Episodic Reward is ==> 82.9375
# Training for 9 iterations with batchsize 64
# Episode * 311 * Episodic Reward is ==> 82.90625
# Training for 8 iterations with batchsize 64
# Episode * 312 * Episodic Reward is ==> 83.75
# Training for 8 iterations with batchsize 64
# Episode * 313 * Episodic Reward is ==> 83.375
# Training for 8 iterations with batchsize 64
# Episode * 314 * Episodic Reward is ==> 83.46875
# Training for 8 iterations with batchsize 64
# Episode * 315 * Episodic Reward is ==> 83.28125
# Training for 8 iterations with batchsize 64
# Episode * 316 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 317 * Episodic Reward is ==> 83.375
# Training for 8 iterations with batchsize 64
# Episode * 318 * Episodic Reward is ==> 83.59375
# Training for 8 iterations with batchsize 64
# Episode * 319 * Episodic Reward is ==> 83.5
# Training for 8 iterations with batchsize 64
# Episode * 320 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 321 * Episodic Reward is ==> 83.4375
# Training for 8 iterations with batchsize 64
# Episode * 322 * Episodic Reward is ==> 83.1875
# Training for 8 iterations with batchsize 64
# Episode * 323 * Episodic Reward is ==> 83.25
# Training for 8 iterations with batchsize 64
# Episode * 324 * Episodic Reward is ==> 83.15625
# Training for 8 iterations with batchsize 64
# Episode * 325 * Episodic Reward is ==> 83.65625
# Training for 8 iterations with batchsize 64
# Episode * 326 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 327 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 328 * Episodic Reward is ==> 83.40625
# Training for 8 iterations with batchsize 64
# Episode * 329 * Episodic Reward is ==> 83.53125
# Training for 8 iterations with batchsize 64
# Episode * 330 * Episodic Reward is ==> 83.46875
# Training for 8 iterations with batchsize 64
# Episode * 331 * Episodic Reward is ==> 83.59375
# Training for 8 iterations with batchsize 64
# Episode * 332 * Episodic Reward is ==> 83.40625
# Training for 8 iterations with batchsize 64
# Episode * 333 * Episodic Reward is ==> 83.34375
# Training for 8 iterations with batchsize 64
# Episode * 334 * Episodic Reward is ==> 83.21875
# Training for 8 iterations with batchsize 64
# Episode * 335 * Episodic Reward is ==> 83.71875
# Training for 8 iterations with batchsize 64
# Episode * 336 * Episodic Reward is ==> 83.75
# Training for 8 iterations with batchsize 64
# Episode * 337 * Episodic Reward is ==> 83.59375
# Training for 9 iterations with batchsize 64
# Episode * 338 * Episodic Reward is ==> 83.0
# Training for 8 iterations with batchsize 64
# Episode * 339 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 340 * Episodic Reward is ==> 83.09375
# Training for 9 iterations with batchsize 64
# Episode * 341 * Episodic Reward is ==> 82.96875
# Training for 8 iterations with batchsize 64
# Episode * 342 * Episodic Reward is ==> 83.71875
# Training for 8 iterations with batchsize 64
# Episode * 343 * Episodic Reward is ==> 83.09375
# Training for 8 iterations with batchsize 64
# Episode * 344 * Episodic Reward is ==> 83.71875
# Training for 8 iterations with batchsize 64
# Episode * 345 * Episodic Reward is ==> 83.84375
# Training for 8 iterations with batchsize 64
# Episode * 346 * Episodic Reward is ==> 83.5
# Training for 8 iterations with batchsize 64
# Episode * 347 * Episodic Reward is ==> 83.34375
# Training for 8 iterations with batchsize 64
# Episode * 348 * Episodic Reward is ==> 83.90625
# Training for 8 iterations with batchsize 64
# Episode * 349 * Episodic Reward is ==> 83.59375
# Training for 8 iterations with batchsize 64
# Episode * 350 * Episodic Reward is ==> 83.4375
# Training for 8 iterations with batchsize 64
# Episode * 351 * Episodic Reward is ==> 83.53125
# Training for 8 iterations with batchsize 64
# Episode * 352 * Episodic Reward is ==> 83.3125
# Training for 8 iterations with batchsize 64
# Episode * 353 * Episodic Reward is ==> 83.375
# Training for 8 iterations with batchsize 64
# Episode * 354 * Episodic Reward is ==> 83.875
# Training for 8 iterations with batchsize 64
# Episode * 355 * Episodic Reward is ==> 83.28125
# Training for 8 iterations with batchsize 64
# Episode * 356 * Episodic Reward is ==> 83.78125
# Training for 8 iterations with batchsize 64
# Episode * 357 * Episodic Reward is ==> 83.84375
# Training for 8 iterations with batchsize 64
# Episode * 358 * Episodic Reward is ==> 83.46875
# Training for 8 iterations with batchsize 64
# Episode * 359 * Episodic Reward is ==> 83.84375
# Training for 8 iterations with batchsize 64
# Episode * 360 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 361 * Episodic Reward is ==> 83.375
# Training for 8 iterations with batchsize 64
# Episode * 362 * Episodic Reward is ==> 83.59375
# Training for 8 iterations with batchsize 64
# Episode * 363 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 364 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 365 * Episodic Reward is ==> 83.28125
# Training for 8 iterations with batchsize 64
# Episode * 366 * Episodic Reward is ==> 83.59375
# Training for 8 iterations with batchsize 64
# Episode * 367 * Episodic Reward is ==> 83.90625
# Training for 8 iterations with batchsize 64
# Episode * 368 * Episodic Reward is ==> 83.25
# Training for 8 iterations with batchsize 64
# Episode * 369 * Episodic Reward is ==> 83.84375
# Training for 8 iterations with batchsize 64
# Episode * 370 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 371 * Episodic Reward is ==> 83.875
# Training for 8 iterations with batchsize 64
# Episode * 372 * Episodic Reward is ==> 83.75
# Training for 8 iterations with batchsize 64
# Episode * 373 * Episodic Reward is ==> 83.96875
# Training for 8 iterations with batchsize 64
# Episode * 374 * Episodic Reward is ==> 83.78125
# Training for 8 iterations with batchsize 64
# Episode * 375 * Episodic Reward is ==> 83.96875
# Training for 8 iterations with batchsize 64
# Episode * 376 * Episodic Reward is ==> 83.96875
# Training for 8 iterations with batchsize 64
# Episode * 377 * Episodic Reward is ==> 83.71875
# Training for 8 iterations with batchsize 64
# Episode * 378 * Episodic Reward is ==> 83.75
# Training for 8 iterations with batchsize 64
# Episode * 379 * Episodic Reward is ==> 83.875
# Training for 8 iterations with batchsize 64
# Episode * 380 * Episodic Reward is ==> 83.84375
# Training for 8 iterations with batchsize 64
# Episode * 381 * Episodic Reward is ==> 83.84375
# Training for 8 iterations with batchsize 64
# Episode * 382 * Episodic Reward is ==> 83.375
# Training for 8 iterations with batchsize 64
# Episode * 383 * Episodic Reward is ==> 83.53125
# Training for 8 iterations with batchsize 64
# Episode * 384 * Episodic Reward is ==> 83.59375
# Training for 8 iterations with batchsize 64
# Episode * 385 * Episodic Reward is ==> 83.34375
# Training for 8 iterations with batchsize 64
# Episode * 386 * Episodic Reward is ==> 83.96875
# Training for 8 iterations with batchsize 64
# Episode * 387 * Episodic Reward is ==> 83.625
# Training for 8 iterations with batchsize 64
# Episode * 388 * Episodic Reward is ==> 83.75
# Training for 8 iterations with batchsize 64
# Episode * 389 * Episodic Reward is ==> 83.28125
# Training for 8 iterations with batchsize 64
# Episode * 390 * Episodic Reward is ==> 83.5
# Training for 8 iterations with batchsize 64
# Episode * 391 * Episodic Reward is ==> 83.90625
# Training for 8 iterations with batchsize 64
# Episode * 392 * Episodic Reward is ==> 83.65625
# Training for 8 iterations with batchsize 64
# Episode * 393 * Episodic Reward is ==> 83.5
# Training for 8 iterations with batchsize 64
# Episode * 394 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 395 * Episodic Reward is ==> 83.46875
# Training for 8 iterations with batchsize 64
# Episode * 396 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 397 * Episodic Reward is ==> 83.96875
# Training for 8 iterations with batchsize 64
# Episode * 398 * Episodic Reward is ==> 84.0625
# Training for 8 iterations with batchsize 64
# Episode * 399 * Episodic Reward is ==> 83.59375
# Training for 8 iterations with batchsize 64
# Episode * 400 * Episodic Reward is ==> 83.59375
# Training for 8 iterations with batchsize 64
# Episode * 401 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 402 * Episodic Reward is ==> 83.59375
# Training for 8 iterations with batchsize 64
# Episode * 403 * Episodic Reward is ==> 83.40625
# Training for 8 iterations with batchsize 64
# Episode * 404 * Episodic Reward is ==> 83.59375
# Training for 8 iterations with batchsize 64
# Episode * 405 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 406 * Episodic Reward is ==> 84.03125
# Training for 8 iterations with batchsize 64
# Episode * 407 * Episodic Reward is ==> 83.875
# Training for 8 iterations with batchsize 64
# Episode * 408 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 409 * Episodic Reward is ==> 83.59375
# Training for 8 iterations with batchsize 64
# Episode * 410 * Episodic Reward is ==> 83.46875
# Training for 8 iterations with batchsize 64
# Episode * 411 * Episodic Reward is ==> 83.625
# Training for 8 iterations with batchsize 64
# Episode * 412 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 413 * Episodic Reward is ==> 83.59375
# Training for 8 iterations with batchsize 64
# Episode * 414 * Episodic Reward is ==> 83.71875
# Training for 8 iterations with batchsize 64
# Episode * 415 * Episodic Reward is ==> 84.03125
# Training for 8 iterations with batchsize 64
# Episode * 416 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 417 * Episodic Reward is ==> 83.59375
# Training for 8 iterations with batchsize 64
# Episode * 418 * Episodic Reward is ==> 83.5625
# Training for 8 iterations with batchsize 64
# Episode * 419 * Episodic Reward is ==> 83.625
# Training for 8 iterations with batchsize 64
# Episode * 420 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 421 * Episodic Reward is ==> 83.71875
# Training for 8 iterations with batchsize 64
# Episode * 422 * Episodic Reward is ==> 83.65625
# Training for 8 iterations with batchsize 64
# Episode * 423 * Episodic Reward is ==> 83.625
# Training for 8 iterations with batchsize 64
# Episode * 424 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 425 * Episodic Reward is ==> 84.0625
# Training for 8 iterations with batchsize 64
# Episode * 426 * Episodic Reward is ==> 83.65625
# Training for 8 iterations with batchsize 64
# Episode * 427 * Episodic Reward is ==> 83.53125
# Training for 8 iterations with batchsize 64
# Episode * 428 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 429 * Episodic Reward is ==> 83.1875
# Training for 8 iterations with batchsize 64
# Episode * 430 * Episodic Reward is ==> 83.71875
# Training for 8 iterations with batchsize 64
# Episode * 431 * Episodic Reward is ==> 83.90625
# Training for 8 iterations with batchsize 64
# Episode * 432 * Episodic Reward is ==> 83.78125
# Training for 8 iterations with batchsize 64
# Episode * 433 * Episodic Reward is ==> 83.5
# Training for 8 iterations with batchsize 64
# Episode * 434 * Episodic Reward is ==> 83.71875
# Training for 8 iterations with batchsize 64
# Episode * 435 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 436 * Episodic Reward is ==> 83.84375
# Training for 8 iterations with batchsize 64
# Episode * 437 * Episodic Reward is ==> 83.90625
# Training for 8 iterations with batchsize 64
# Episode * 438 * Episodic Reward is ==> 83.96875
# Training for 8 iterations with batchsize 64
# Episode * 439 * Episodic Reward is ==> 83.90625
# Training for 8 iterations with batchsize 64
# Episode * 440 * Episodic Reward is ==> 83.5625
# Training for 8 iterations with batchsize 64
# Episode * 441 * Episodic Reward is ==> 83.46875
# Training for 8 iterations with batchsize 64
# Episode * 442 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 443 * Episodic Reward is ==> 83.9375
# Training for 8 iterations with batchsize 64
# Episode * 444 * Episodic Reward is ==> 83.625
# Training for 8 iterations with batchsize 64
# Episode * 445 * Episodic Reward is ==> 83.625
# Training for 8 iterations with batchsize 64
# Episode * 446 * Episodic Reward is ==> 83.84375
# Training for 8 iterations with batchsize 64
# Episode * 447 * Episodic Reward is ==> 83.59375
# Training for 8 iterations with batchsize 64
# Episode * 448 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 449 * Episodic Reward is ==> 83.9375
# Training for 8 iterations with batchsize 64
# Episode * 450 * Episodic Reward is ==> 84.03125
# Training for 8 iterations with batchsize 64
# Episode * 451 * Episodic Reward is ==> 83.71875
# Training for 8 iterations with batchsize 64
# Episode * 452 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 453 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 454 * Episodic Reward is ==> 83.75
# Training for 8 iterations with batchsize 64
# Episode * 455 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 456 * Episodic Reward is ==> 83.96875
# Training for 8 iterations with batchsize 64
# Episode * 457 * Episodic Reward is ==> 83.96875
# Training for 8 iterations with batchsize 64
# Episode * 458 * Episodic Reward is ==> 83.5625
# Training for 8 iterations with batchsize 64
# Episode * 459 * Episodic Reward is ==> 83.5
# Training for 8 iterations with batchsize 64
# Episode * 460 * Episodic Reward is ==> 83.875
# Training for 8 iterations with batchsize 64
# Episode * 461 * Episodic Reward is ==> 83.84375
# Training for 8 iterations with batchsize 64
# Episode * 462 * Episodic Reward is ==> 83.875
# Training for 8 iterations with batchsize 64
# Episode * 463 * Episodic Reward is ==> 84.0625
# Training for 8 iterations with batchsize 64
# Episode * 464 * Episodic Reward is ==> 83.875
# Training for 8 iterations with batchsize 64
# Episode * 465 * Episodic Reward is ==> 83.5625
# Training for 8 iterations with batchsize 64
# Episode * 466 * Episodic Reward is ==> 83.625
# Training for 8 iterations with batchsize 64
# Episode * 467 * Episodic Reward is ==> 83.59375
# Training for 8 iterations with batchsize 64
# Episode * 468 * Episodic Reward is ==> 84.0625
# Training for 8 iterations with batchsize 64
# Episode * 469 * Episodic Reward is ==> 84.09375
# Training for 8 iterations with batchsize 64
# Episode * 470 * Episodic Reward is ==> 83.375
# Training for 8 iterations with batchsize 64
# Episode * 471 * Episodic Reward is ==> 83.65625
# Training for 8 iterations with batchsize 64
# Episode * 472 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 473 * Episodic Reward is ==> 83.5625
# Training for 8 iterations with batchsize 64
# Episode * 474 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 475 * Episodic Reward is ==> 83.90625
# Training for 8 iterations with batchsize 64
# Episode * 476 * Episodic Reward is ==> 83.78125
# Training for 8 iterations with batchsize 64
# Episode * 477 * Episodic Reward is ==> 83.71875
# Training for 8 iterations with batchsize 64
# Episode * 478 * Episodic Reward is ==> 83.90625
# Training for 8 iterations with batchsize 64
# Episode * 479 * Episodic Reward is ==> 83.5625
# Training for 8 iterations with batchsize 64
# Episode * 480 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 481 * Episodic Reward is ==> 83.65625
# Training for 8 iterations with batchsize 64
# Episode * 482 * Episodic Reward is ==> 83.84375
# Training for 8 iterations with batchsize 64
# Episode * 483 * Episodic Reward is ==> 83.875
# Training for 8 iterations with batchsize 64
# Episode * 484 * Episodic Reward is ==> 83.875
# Training for 8 iterations with batchsize 64
# Episode * 485 * Episodic Reward is ==> 83.5
# Training for 8 iterations with batchsize 64
# Episode * 486 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 487 * Episodic Reward is ==> 83.53125
# Training for 8 iterations with batchsize 64
# Episode * 488 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 489 * Episodic Reward is ==> 83.65625
# Training for 8 iterations with batchsize 64
# Episode * 490 * Episodic Reward is ==> 83.96875
# Training for 8 iterations with batchsize 64
# Episode * 491 * Episodic Reward is ==> 83.90625
# Training for 8 iterations with batchsize 64
# Episode * 492 * Episodic Reward is ==> 83.71875
# Training for 8 iterations with batchsize 64
# Episode * 493 * Episodic Reward is ==> 83.375
# Training for 8 iterations with batchsize 64
# Episode * 494 * Episodic Reward is ==> 83.625
# Training for 8 iterations with batchsize 64
# Episode * 495 * Episodic Reward is ==> 83.65625
# Training for 8 iterations with batchsize 64
# Episode * 496 * Episodic Reward is ==> 83.59375
# Training for 8 iterations with batchsize 64
# Episode * 497 * Episodic Reward is ==> 83.78125
# Training for 8 iterations with batchsize 64
# Episode * 498 * Episodic Reward is ==> 83.875
# Training for 8 iterations with batchsize 64
# Episode * 499 * Episodic Reward is ==> 83.90625
# Training for 8 iterations with batchsize 64
# Episode * 500 * Episodic Reward is ==> 84.0
# Training for 8 iterations with batchsize 64
# Episode * 501 * Episodic Reward is ==> 83.96875
# Training for 8 iterations with batchsize 64
# Episode * 502 * Episodic Reward is ==> 83.53125
# Training for 8 iterations with batchsize 64
# Episode * 503 * Episodic Reward is ==> 83.96875
# Training for 8 iterations with batchsize 64
# Episode * 504 * Episodic Reward is ==> 83.625
# Training for 8 iterations with batchsize 64
# Episode * 505 * Episodic Reward is ==> 83.84375
# Training for 8 iterations with batchsize 64
# Episode * 506 * Episodic Reward is ==> 83.90625
# Training for 8 iterations with batchsize 64
# Episode * 507 * Episodic Reward is ==> 84.03125
# Training for 8 iterations with batchsize 64
# Episode * 508 * Episodic Reward is ==> 83.96875
# Training for 8 iterations with batchsize 64
# Episode * 509 * Episodic Reward is ==> 83.90625
# Training for 8 iterations with batchsize 64
# Episode * 510 * Episodic Reward is ==> 83.5
# Training for 8 iterations with batchsize 64
# Episode * 511 * Episodic Reward is ==> 83.625
# Training for 8 iterations with batchsize 64
# Episode * 512 * Episodic Reward is ==> 83.75
# Training for 8 iterations with batchsize 64
# Episode * 513 * Episodic Reward is ==> 83.78125
# Training for 8 iterations with batchsize 64
# Episode * 514 * Episodic Reward is ==> 83.34375
# Training for 8 iterations with batchsize 64
# Episode * 515 * Episodic Reward is ==> 83.53125
# Training for 8 iterations with batchsize 64
# Episode * 516 * Episodic Reward is ==> 83.59375
# Training for 8 iterations with batchsize 64
# Episode * 517 * Episodic Reward is ==> 83.625
# Training for 8 iterations with batchsize 64
# Episode * 518 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 519 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 520 * Episodic Reward is ==> 83.875
# Training for 8 iterations with batchsize 64
# Episode * 521 * Episodic Reward is ==> 83.65625
# Training for 8 iterations with batchsize 64
# Episode * 522 * Episodic Reward is ==> 83.84375
# Training for 8 iterations with batchsize 64
# Episode * 523 * Episodic Reward is ==> 83.9375
# Training for 8 iterations with batchsize 64
# Episode * 524 * Episodic Reward is ==> 83.96875
# Training for 8 iterations with batchsize 64
# Episode * 525 * Episodic Reward is ==> 83.71875
# Training for 8 iterations with batchsize 64
# Episode * 526 * Episodic Reward is ==> 83.78125
# ...
# Training for 8 iterations with batchsize 64
# Episode * 4179 * Episodic Reward is ==> 83.71875
# Training for 8 iterations with batchsize 64
# Episode * 4180 * Episodic Reward is ==> 84.0625
# Training for 8 iterations with batchsize 64
# Episode * 4181 * Episodic Reward is ==> 83.53125
# Training for 8 iterations with batchsize 64
# Episode * 4182 * Episodic Reward is ==> 83.90625
# Training for 8 iterations with batchsize 64
# Episode * 4183 * Episodic Reward is ==> 83.71875
# Training for 8 iterations with batchsize 64
# Episode * 4184 * Episodic Reward is ==> 83.71875
# Training for 8 iterations with batchsize 64
# Episode * 4185 * Episodic Reward is ==> 84.34375
# Training for 8 iterations with batchsize 64
# Episode * 4186 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 4187 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 4188 * Episodic Reward is ==> 84.15625
# Training for 8 iterations with batchsize 64
# Episode * 4189 * Episodic Reward is ==> 83.96875
# Training for 8 iterations with batchsize 64
# Episode * 4190 * Episodic Reward is ==> 83.9375
# Training for 8 iterations with batchsize 64
# Episode * 4191 * Episodic Reward is ==> 84.21875
# Training for 8 iterations with batchsize 64
# Episode * 4192 * Episodic Reward is ==> 84.0
# Training for 8 iterations with batchsize 64
# Episode * 4193 * Episodic Reward is ==> 84.1875
# Training for 8 iterations with batchsize 64
# Episode * 4194 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 4195 * Episodic Reward is ==> 83.90625
# Training for 8 iterations with batchsize 64
# Episode * 4196 * Episodic Reward is ==> 83.78125
# Training for 8 iterations with batchsize 64
# Episode * 4197 * Episodic Reward is ==> 83.84375
# Training for 8 iterations with batchsize 64
# Episode * 4198 * Episodic Reward is ==> 83.96875
# Training for 8 iterations with batchsize 64
# Episode * 4199 * Episodic Reward is ==> 83.75
# Training for 8 iterations with batchsize 64
# Episode * 4200 * Episodic Reward is ==> 84.28125
# Training for 8 iterations with batchsize 64
# Episode * 4201 * Episodic Reward is ==> 84.125
# Training for 8 iterations with batchsize 64
# Episode * 4202 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 4203 * Episodic Reward is ==> 84.0
# Training for 8 iterations with batchsize 64
# Episode * 4204 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 4205 * Episodic Reward is ==> 84.03125
# Training for 8 iterations with batchsize 64
# Episode * 4206 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 4207 * Episodic Reward is ==> 84.0625
# Training for 8 iterations with batchsize 64
# Episode * 4208 * Episodic Reward is ==> 84.0625
# Training for 8 iterations with batchsize 64
# Episode * 4209 * Episodic Reward is ==> 84.46875
# Training for 8 iterations with batchsize 64
# Episode * 4210 * Episodic Reward is ==> 84.25
# Training for 8 iterations with batchsize 64
# Episode * 4211 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 4212 * Episodic Reward is ==> 83.75
# Training for 8 iterations with batchsize 64
# Episode * 4213 * Episodic Reward is ==> 83.875
# Training for 8 iterations with batchsize 64
# Episode * 4214 * Episodic Reward is ==> 84.3125
# Training for 8 iterations with batchsize 64
# Episode * 4215 * Episodic Reward is ==> 83.875
# Training for 8 iterations with batchsize 64
# Episode * 4216 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 4217 * Episodic Reward is ==> 84.03125
# Training for 8 iterations with batchsize 64
# Episode * 4218 * Episodic Reward is ==> 83.84375
# Training for 8 iterations with batchsize 64
# Episode * 4219 * Episodic Reward is ==> 84.125
# Training for 8 iterations with batchsize 64
# Episode * 4220 * Episodic Reward is ==> 84.15625
# Training for 8 iterations with batchsize 64
# Episode * 4221 * Episodic Reward is ==> 84.15625
# Training for 8 iterations with batchsize 64
# Episode * 4222 * Episodic Reward is ==> 84.0
# Training for 8 iterations with batchsize 64
# Episode * 4223 * Episodic Reward is ==> 84.0
# Training for 8 iterations with batchsize 64
# Episode * 4224 * Episodic Reward is ==> 83.9375
# Training for 8 iterations with batchsize 64
# Episode * 4225 * Episodic Reward is ==> 83.9375
# Training for 8 iterations with batchsize 64
# Episode * 4226 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 4227 * Episodic Reward is ==> 84.09375
# Training for 8 iterations with batchsize 64
# Episode * 4228 * Episodic Reward is ==> 84.28125
# Training for 8 iterations with batchsize 64
# Episode * 4229 * Episodic Reward is ==> 83.96875
# Training for 8 iterations with batchsize 64
# Episode * 4230 * Episodic Reward is ==> 84.0625
# Training for 8 iterations with batchsize 64
# Episode * 4231 * Episodic Reward is ==> 84.09375
# Training for 8 iterations with batchsize 64
# Episode * 4232 * Episodic Reward is ==> 84.0625
# Training for 8 iterations with batchsize 64
# Episode * 4233 * Episodic Reward is ==> 83.875
# Training for 8 iterations with batchsize 64
# Episode * 4234 * Episodic Reward is ==> 84.15625
# Training for 8 iterations with batchsize 64
# Episode * 4235 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 4236 * Episodic Reward is ==> 83.84375
# Training for 8 iterations with batchsize 64
# Episode * 4237 * Episodic Reward is ==> 84.25
# Training for 8 iterations with batchsize 64
# Episode * 4238 * Episodic Reward is ==> 84.125
# Training for 8 iterations with batchsize 64
# Episode * 4239 * Episodic Reward is ==> 83.84375
# Training for 8 iterations with batchsize 64
# Episode * 4240 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 4241 * Episodic Reward is ==> 83.90625
# Training for 8 iterations with batchsize 64
# Episode * 4242 * Episodic Reward is ==> 84.34375
# Training for 8 iterations with batchsize 64
# Episode * 4243 * Episodic Reward is ==> 83.90625
# Training for 8 iterations with batchsize 64
# Episode * 4244 * Episodic Reward is ==> 84.0
# Training for 8 iterations with batchsize 64
# Episode * 4245 * Episodic Reward is ==> 84.1875
# Training for 8 iterations with batchsize 64
# Episode * 4246 * Episodic Reward is ==> 84.0
# Training for 8 iterations with batchsize 64
# Episode * 4247 * Episodic Reward is ==> 83.8125
# Training for 8 iterations with batchsize 64
# Episode * 4248 * Episodic Reward is ==> 84.40625
# Training for 8 iterations with batchsize 64
# Episode * 4249 * Episodic Reward is ==> 84.3125
# Training for 8 iterations with batchsize 64
# Episode * 4250 * Episodic Reward is ==> 83.90625
# Training for 8 iterations with batchsize 64
# Episode * 4251 * Episodic Reward is ==> 84.0625
# Training for 8 iterations with batchsize 64
# Episode * 4252 * Episodic Reward is ==> 83.9375
# Training for 8 iterations with batchsize 64
# Episode * 4253 * Episodic Reward is ==> 84.03125
# Training for 8 iterations with batchsize 64
# Episode * 4254 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 4255 * Episodic Reward is ==> 83.78125
# Training for 8 iterations with batchsize 64
# Episode * 4256 * Episodic Reward is ==> 84.15625
# Training for 8 iterations with batchsize 64
# Episode * 4257 * Episodic Reward is ==> 83.875
# Training for 8 iterations with batchsize 64
# Episode * 4258 * Episodic Reward is ==> 83.34375
# Training for 8 iterations with batchsize 64
# Episode * 4259 * Episodic Reward is ==> 84.125
# Training for 8 iterations with batchsize 64
# Episode * 4260 * Episodic Reward is ==> 83.6875
# Training for 8 iterations with batchsize 64
# Episode * 4261 * Episodic Reward is ==> 83.96875
# Training for 8 iterations with batchsize 64
# Episode * 4262 * Episodic Reward is ==> 84.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2552173/1913465329.py in <module>
#      16     while True:
#      17
# ---> 18         deterministic_actions, means,stdevs = agent.get_action(prev_states,
#      19                                                return_stats=True)
#      20         actions = deterministic_actions #hook in order to add noise if neccessary
#
# /home/bnapp/arivkindNet/neosyclop/pg_core.py in get_action(self, states, return_stats)
#      28
#      29     def get_action(self, states, return_stats=False):
# ---> 30         outputs = self.model.predict(states)
#      31         means = outputs[:, :self.action_dim]  # first two values are means
#      32         if self.std_deviation is None:  # learn std_dev
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1718                         '. Consider setting it to AutoShardPolicy.DATA.')
#    1719
# -> 1720       data_handler = data_adapter.get_data_handler(
#    1721           x=x,
#    1722           batch_size=batch_size,
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1381   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1382     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1383   return DataHandler(*args, **kwargs)
#    1384
#    1385
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1136
#    1137     adapter_cls = select_data_adapter(x, y)
# -> 1138     self._adapter = adapter_cls(
#    1139         x,
#    1140         y,
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     318       return flat_dataset
#     319
# --> 320     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     321
#     322     dataset = self.slice_inputs(indices_dataset, inputs)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/dataset_ops.py in flat_map(self, map_func)
#    1901       Dataset: A `Dataset`.
#    1902     """
# -> 1903     return FlatMapDataset(self, map_func)
#    1904
#    1905   def interleave(self,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, map_func)
#    5060     """See `Dataset.flat_map()` for details."""
#    5061     self._input_dataset = input_dataset
# -> 5062     self._map_func = StructuredFunctionWrapper(
#    5063         map_func, self._transformation_name(), dataset=input_dataset)
#    5064     if not isinstance(self._map_func.output_structure, DatasetSpec):
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    4216         fn_factory = trace_tf_function(defun_kwargs)
#    4217
# -> 4218     self._function = fn_factory()
#    4219     # There is no graph to add in eager mode.
#    4220     add_to_graph &= not context.executing_eagerly()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in get_concrete_function(self, *args, **kwargs)
#    3148          or `tf.Tensor` or `tf.TensorSpec`.
#    3149     """
# -> 3150     graph_function = self._get_concrete_function_garbage_collected(
#    3151         *args, **kwargs)
#    3152     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3114       args, kwargs = None, None
#    3115     with self._lock:
# -> 3116       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3117       seen_names = set()
#    3118       captured = object_identity.ObjectIdentitySet(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3461
#    3462           self._function_cache.missed.add(call_context_key)
# -> 3463           graph_function = self._create_graph_function(args, kwargs)
#    3464           self._function_cache.primary[cache_key] = graph_function
#    3465
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3296     arg_names = base_arg_names + missing_arg_names
#    3297     graph_function = ConcreteFunction(
# -> 3298         func_graph_module.func_graph_from_py_func(
#    3299             self._name,
#    3300             self._python_function,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1046         if x is not None)
#    1047
# -> 1048     func_graph.variables = variables
#    1049
#    1050   if add_control_dependencies:
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/auto_control_deps.py in __exit__(self, unused_type, unused_value, unused_traceback)
#     534           # function outputs.
#     535           if idx == 0:
# --> 536             control_output_op = control_flow_ops.no_op()
#     537             control_output_op._set_attr("_acd_function_control_output",
#     538                                         attr_value_pb2.AttrValue(b=True))
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_control_flow_ops.py in no_op(name)
#     498   # Add nodes to the TensorFlow graph.
#     499   try:
# --> 500     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#     501         "NoOp", name=name)
#     502   except (TypeError, ValueError):
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     763         outputs = callback_outputs
#     764
# --> 765     return output_structure, op_def.is_stateful, op, outputs
#     766
#     767
#
# /usr/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/func_graph.py in inner_cm()
#     423             self._device_function_stack = old_device_stack
#     424             self._variable_creator_stack = old_creator_stack
# --> 425             self._graph_key = old_graph_key
#     426     return inner_cm()
#     427
#
# /usr/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in get_controller(self, default)
#    5621       with super(_DefaultGraphStack,
#    5622                  self).get_controller(default) as g, context.graph_mode():
# -> 5623         yield g
#    5624     finally:
#    5625       # If an exception is raised here it may be hiding a related exception in
#
# /usr/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/context.py in _mode(self, mode)
#     843       yield
#     844     finally:
# --> 845       ctx.is_eager = old_is_eager
#     846       if mode == EAGER_MODE:
#     847         self.context_switches.pop()
#
# KeyboardInterrupt:

# %%
import misc

# %%
reward_records = np.array(reward_records)
plt.plot(reward_records.mean(axis=1))
plt.plot(misc.smooth(reward_records.mean(axis=1),100))
plt.grid()

# %%
# plt.plot(reward_records)
plt.plot(misc.smooth(reward_records.mean(axis=1),100))
plt.grid()
plt.ylim([50,100])
# Out:
# (50.0, 100.0)
